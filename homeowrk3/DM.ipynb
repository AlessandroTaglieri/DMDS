# %% [markdown]
# #### installare mongodb community sulla prorpia macchina
#
# #### installare pymongo su python
#
# Far partire mongo db
#
# ES: Utilizzare brew:
#
# #### installare:
#
# brew tap mongodb/brew
#
# brew install mongodb-community
#
# #### start:
#
# brew services run mongodb-community
#
# #### vedere se funsiona correttamente :
#
# brew services list
#
# #### aprire shell mongodb
#
# mongo
#
# #### vedere tutti i db
#
# show dbs (nella shell di mongo)
#
# #### stop mongodb
#
# brew services stop mongodb-community

# %%
import csv
from pymongo import MongoClient
from pprint import pprint

# %% [markdown]
# # CREARE JSON CON I DATI  DA INSERIRE NEL DB

# %%
#Create bson


# PLAYER

player_list = []

with open("/Users/digitalfirst/Desktop/dmds-3hw/csv_DMDS/dataset/players.csv","r") as f:
    player = csv.reader(f,delimiter=";")
    for row in player:
        player_list.append(row)
 
       
player_bson_dict = {}
player_bson = []

for i in range(1,len(player_list)):
    player_dict = {}
    for j in range(len(player_list[0])):
        if j == 0:
            player_dict["_id"] = player_list[i][j]
        else:
            player_dict[player_list[0][j]] = player_list[i][j]
    player_bson.append(player_dict)
    player_bson_dict[player_dict["_id"]] = player_dict




# TEAM

team_list = []

with open("/Users/digitalfirst/Desktop/dmds-3hw/csv_DMDS/dataset/teams.csv","r") as f:
    team = csv.reader(f,delimiter=";")
    for row in team:
        team_list.append(row)
 
       
team_bson_dict = {}
team_bson = []

for i in range(1,len(team_list)):
    team_dict = {}
    for j in range(len(team_list[0])):
        if j == 2:
            team_dict["_id"] = team_list[i][j]
        else:
            team_dict[team_list[0][j]] = team_list[i][j]
    team_bson.append(team_dict)
    team_bson_dict[team_dict["_id"]] = team_dict






# PLAYER TEAM

player_team_list = []
with open("/Users/digitalfirst/Desktop/dmds-3hw/csv_DMDS/dataset/players_teams.csv","r") as f:
    players_teams = csv.reader(f,delimiter=";")
    for row in players_teams:
        player_team_list.append(row)



player_teams_bson = []

for i in range(1,len(player_team_list)):
    player_teams_dict = {}
    for j in range(len(player_team_list[0])):
        if j == 0:
            player_teams_dict["_id"] = player_team_list[i][j]
        elif player_team_list[0][j] == "playerID":
            player_teams_dict["playerID"] = player_bson_dict[player_team_list[i][j]]
        elif player_team_list[0][j] == "tmID":
            player_teams_dict["tmID"] = team_bson_dict[player_team_list[i][j]]
        else:
            player_teams_dict[player_team_list[0][j]] = player_team_list[i][j]
    player_teams_dict["points"]=int(player_teams_dict["points"])
    player_teams_dict["rebounds"]=int(player_teams_dict["rebounds"])
    player_teams_dict["assists"]=int(player_teams_dict["assists"])
    player_teams_dict["blocks"]=int(player_teams_dict["blocks"])
    player_teams_dict["steals"]=int(player_teams_dict["steals"])
    player_teams_dict["turnovers"]=int(player_teams_dict["turnovers"])
    player_teams_dict["year"]=int(player_teams_dict["year_pt"])
    player_teams_bson.append(player_teams_dict)






# DRAFT

draft_list = []

with open("/Users/digitalfirst/Desktop/dmds-3hw/csv_DMDS/dataset/draft.csv","r") as f:
    draft = csv.reader(f,delimiter=";")
    for row in draft:
        draft_list.append(row)
 
       
draft_bson_dict = {}
draft_bson = []

for i in range(1,len(draft_list)):
    draft_dict = {}
    for j in range(len(draft_list[0])):
        if j == 0:
            draft_dict["_id"] = draft_list[i][j]
        elif draft_list[0][j] == "tmID":
            draft_dict["tmID"] = team_bson_dict[draft_list[i][j]]
        else:
            draft_dict[draft_list[0][j]] = draft_list[i][j]
    draft_dict["draftYear"] = int(draft_dict["draftYear"])
    draft_bson.append(draft_dict)
    draft_bson_dict[draft_dict["_id"]] = draft_dict




# SERIES POST
series_post_list = []

with open("/Users/digitalfirst/Desktop/dmds-3hw/csv_DMDS/dataset/series_post.csv","r") as f:
    series_post = csv.reader(f,delimiter=";")
    for row in series_post:
        series_post_list.append(row)
 
       
series_post_bson_dict = {}
series_post_bson = []

for i in range(1,len(series_post_list)):
    series_post_dict = {}
    for j in range(len(series_post_list[0])):
        if j == 0:
            series_post_dict["_id"] = series_post_list[i][j]
        elif series_post_list[0][j] == "tmIDWinner":
            series_post_dict["tmIDWinner"] = team_bson_dict[series_post_list[i][j]]
        elif series_post_list[0][j] == "tmIDLoser":
            try:
                series_post_dict["tmIDLoser"] = team_bson_dict[series_post_list[i][j]]
            except:
                pass
        else:
            series_post_dict[series_post_list[0][j]] = series_post_list[i][j]
    series_post_bson.append(series_post_dict)
    series_post_bson_dict[series_post_dict["_id"]] = series_post_dict




# COACHES

coaches_list = []

with open("/Users/digitalfirst/Desktop/dmds-3hw/csv_DMDS/dataset/coaches.csv","r") as f:
    coaches = csv.reader(f,delimiter=";")
    for row in coaches:
        coaches_list.append(row)
 
       
coaches_bson_dict = {}
coaches_bson = []

for i in range(1,len(coaches_list)):
    coaches_dict = {}
    coaches_dict["_id"] = (coaches_list[i][0],coaches_list[i][1])
    for j in range(len(coaches_list[0])):
        if coaches_list[0][j] == "tmID":
            coaches_dict["tmID"] = team_bson_dict[coaches_list[i][j]]
        else:
            coaches_dict[coaches_list[0][j]] = coaches_list[i][j]
    coaches_bson.append(coaches_dict)
    coaches_bson_dict[coaches_dict["_id"]] = coaches_dict
    
    

# COACHES AWARDS

coaches_awards_list = []

with open("/Users/digitalfirst/Desktop/dmds-3hw/csv_DMDS/dataset/awards_coaches.csv","r") as f:
    coaches_awards = csv.reader(f,delimiter=";")
    for row in coaches_awards:
        coaches_awards_list.append(row)
 
       
coaches_awards_bson_dict = {}
coaches_awards_bson = []

for i in range(1,len(coaches_awards_list)):
    coaches_awards_dict = {}
    for j in range(len(coaches_awards_list[0])):
        if j == 0:
            coaches_awards_dict["_id"] = coaches_awards_list[i][j]
        elif coaches_awards_list[0][j] == "coachID":
            coaches_awards_dict["coachID"] = coaches_bson_dict[(coaches_awards_list[i][j],coaches_awards_list[i][1])]
        else:
            coaches_awards_dict[coaches_awards_list[0][j]] = coaches_awards_list[i][j]
    coaches_awards_bson.append(coaches_awards_dict)
    coaches_awards_bson_dict[coaches_awards_dict["_id"]] = coaches_awards_dict
    
    
    
    
    
    
    
    
# AWARD PLAYERS

awards_players_list = []

with open("/Users/digitalfirst/Desktop/dmds-3hw/csv_DMDS/dataset/awards_players.csv","r") as f:
    awards_players = csv.reader(f,delimiter=";")
    for row in awards_players:
        awards_players_list.append(row)
 
       
awards_players_bson_dict = {}
awards_players_bson = []

for i in range(1,len(awards_players_list)):
    awards_players_dict = {}
    awards_players_dict["_id"] = i
    for j in range(len(awards_players_list[0])):

        if awards_players_list[0][j] == "playerID":
            awards_players_dict["playerID"] = player_bson_dict[awards_players_list[i][j]]
        else:
            awards_players_dict[awards_players_list[0][j]] = awards_players_list[i][j]
    awards_players_bson.append(awards_players_dict)
    awards_players_bson_dict[awards_players_dict["_id"]] = awards_players_dict
    
    
    
   


    
# PLAYER ALL STAR

player_all_star_list = []

with open("/Users/digitalfirst/Desktop/dmds-3hw/csv_DMDS/dataset/player_allstar.csv","r") as f:
    player_all_star = csv.reader(f,delimiter=";")
    for row in player_all_star:
        player_all_star_list.append(row)
 
       
player_all_star_bson_dict = {}
player_all_star_bson = []

for i in range(1,len(player_all_star_list)):
    player_all_star_dict = {}
    player_all_star_dict["_id"] = i
    for j in range(len(player_all_star_list[0])):

        if player_all_star_list[0][j] == "playerID":
            player_all_star_dict["playerID"] = player_bson_dict[player_all_star_list[i][j]]
        else:
            player_all_star_dict[player_all_star_list[0][j]] = player_all_star_list[i][j]
    player_all_star_dict["season_id"] = int(player_all_star_dict["season_id"])
    player_all_star_dict["points"] = int(player_all_star_dict["points"])
    player_all_star_bson.append(player_all_star_dict)
    player_all_star_bson_dict[player_all_star_dict["_id"]] = player_all_star_dict

# %% [markdown]
# #### we have 6 collections:
# - collection_players_teams: it contains data about players, teams and players_teams table
# - collection_draft : It contains all data about draft and team
# - collection_series_post: It contains data about series_post and all data abvoiut team winner and team that lost
# - collection_awards_coaches: it contains data about awards_coach and coach
# - collection_awards_players: It contains all data about awards_player  and player
# - collection_player_all_star:  It contains all data about players_all and and player

# %% [markdown]
# # CREARE DB DOPO AVER CREATO LA CONNESSIONE AL CLIENT MONGODB, CREARE TABELLE

# %%
# Connect to Mongo
client = MongoClient('localhost', 27017)


# Create database 
db = client["Basketball"]

# %%
# Create collections
collection_players_teams= db["players_teams"]
collection_draft= db["draft"]
collection_series_post= db["series_post"]
collection_awards_coaches= db["awards_coaches"]
collection_awards_players= db["awards_players"]
collection_player_all_star= db["player_all_star"]

# %%
collection_player= db["player"]

# %% [markdown]
# # INSERIRE JSON NEL DB

# %%
# Insert data into collections
db.collection_players_teams.insert_many(player_teams_bson)
db.collection_draft.insert_many(draft_bson)
db.collection_series_post.insert_many(series_post_bson)
db.collection_awards_coaches.insert_many(coaches_awards_bson)
db.collection_awards_players.insert_many(awards_players_bson)
db.collection_player_all_star.insert_many(player_all_star_bson)

# %%
db.collection_player.insert_many(player_bson)

# %% [markdown]
# ###### if there is any errors in insert bson in collections. In this way you can see the log of the error

# %%
import pymongo
from pymongo import MongoClient

try:
  result = db.collection_teams.insert_many(team_bson)

except pymongo.errors.BulkWriteError as e:
  print (e.details['writeErrors'])

# %% [markdown]
# ## query 5

# %%
#Michael Jordan team mate


temp = db.collection_players_teams.find(
        {"playerID.firstName":"Michael","playerID.lastName":"Jordan"},
        projection={"tmID.name_team":1,"year":1,"_id":0})

team_aux = []
year_aux = []
for i in temp:
    team_aux.append(i["tmID"]["name_team"])
    year_aux.append(i["year"])
    

    
cursor = db.collection_players_teams.aggregate([
        {"$match":{"tmID.name_team":{"$in":team_aux},"year":{"$in":year_aux},"playerID.lastName":{"$ne":"Bryant"}}},
        {"$group":{"_id":"$playerID.lastName"}},
        {"$project":{"playerID.lastName":1}}
        ])

for i in cursor:
    pprint(i)
# Out:
# {'_id': 'Green'}
# {'_id': 'Booth'}
# {'_id': 'Parish'}
# {'_id': 'Macy'}
# {'_id': 'Vaughn'}
# {'_id': 'Dixon'}
# {'_id': 'Eackles'}
# {'_id': 'Myers'}
# {'_id': 'Ham'}
# {'_id': 'Hansen'}
# {'_id': 'Jones'}
# {'_id': 'Kerr'}
# {'_id': 'Burrell'}
# {'_id': 'Ollie'}
# {'_id': 'Pippen'}
# {'_id': 'Sparrow'}
# {'_id': 'Turner'}
# {'_id': 'Poquette'}
# {'_id': 'Dailey'}
# {'_id': 'Cheaney'}
# {'_id': 'Johnson'}
# {'_id': 'Courtney'}
# {'_id': 'Nesby'}
# {'_id': 'Wallace'}
# {'_id': 'Buechler'}
# {'_id': 'Hodges'}
# {'_id': 'Alexander'}
# {'_id': 'Haywood'}
# {'_id': 'Marshall'}
# {'_id': 'Walker'}
# {'_id': 'Brown'}
# {'_id': 'World Peace'}
# {'_id': 'McCray'}
# {'_id': 'Harper'}
# {'_id': 'Gilmore'}
# {'_id': 'Strickland'}
# {'_id': 'Corzine'}
# {'_id': 'Matthews'}
# {'_id': 'Wood'}
# {'_id': 'Longley'}
# {'_id': 'English'}
# {'_id': 'Jordan'}
# {'_id': 'Oliver'}
# {'_id': 'Threatt'}
# {'_id': 'Sanders'}
# {'_id': 'Goldwire'}
# {'_id': 'Best'}
# {'_id': 'Fizer'}
# {'_id': 'Guyton'}
# {'_id': 'Tucker'}
# {'_id': 'Lett'}
# {'_id': 'Russell'}
# {'_id': 'McKinney'}
# {'_id': 'Grant'}
# {'_id': 'Smrek'}
# {'_id': 'Waiters'}
# {'_id': 'Rodman'}
# {'_id': 'Armstrong'}
# {'_id': 'Mercer'}
# {'_id': 'Hoiberg'}
# {'_id': 'Perdue'}
# {'_id': 'Cofield'}
# {'_id': 'Whitney'}
# {'_id': 'Williams'}
# {'_id': 'King'}
# {'_id': 'Crawford'}
# {'_id': 'Bagaric'}
# {'_id': 'Lue'}
# {'_id': 'Wennington'}
# {'_id': 'White'}
# {'_id': 'Nevitt'}
# {'_id': 'Sellers'}
# {'_id': 'Shammgod'}
# {'_id': 'Young'}
# {'_id': 'Simpkins'}
# {'_id': 'Krystkowiak'}
# {'_id': 'Murray'}
# {'_id': 'Brewer'}
# {'_id': 'Robinson'}
# {'_id': 'Paxson'}
# {'_id': 'Caffey'}
# {'_id': 'Curry'}
# {'_id': 'Banks'}
# {'_id': 'Davis'}
# {'_id': 'Laettner'}
# {'_id': 'Brunson'}
# {'_id': 'Mason'}
# {'_id': 'Edwards'}
# {'_id': 'Richardson'}
# {'_id': 'Hassell'}
# {'_id': 'Blount'}
# {'_id': 'Pressley'}
# {'_id': 'Daye'}
# {'_id': 'Anthony'}
# {'_id': 'Cardinal'}
# {'_id': 'Steigenga'}
# {'_id': 'Baxter'}
# {'_id': 'Randall'}
# {'_id': 'Foster'}
# {'_id': 'Dele'}
# {'_id': 'Thomas'}
# {'_id': 'Holton'}
# {'_id': 'Levingston'}
# {'_id': 'Vincent'}
# {'_id': 'Webber'}
# {'_id': 'Hamilton'}
# {'_id': 'Blanton'}
# {'_id': 'Kleine'}
# {'_id': 'Legler'}
# {'_id': 'Moten'}
# {'_id': 'Nealy'}
# {'_id': 'Stackhouse'}
# {'_id': 'Cartwright'}
# {'_id': 'Greenwood'}
# {'_id': 'Higgins'}
# {'_id': 'Hopson'}
# {'_id': 'Whatley'}
# {'_id': 'Kukoc'}
# {'_id': 'Oakley'}
# {'_id': 'LaRue'}
# {'_id': 'Cureton'}
# {'_id': 'Oldham'}
# {'_id': 'Rose'}
# {'_id': 'Jeffries'}
# {'_id': 'Gervin'}
# {'_id': 'Woolridge'}
# {'_id': 'Haley'}
# {'_id': 'Miller'}
# {'_id': 'Engler'}
# {'_id': 'Salley'}
# {'_id': 'Colter'}
# {'_id': 'Simmons'}

# %% [markdown]
# ## query 1

# %%
cursor = db.collection_players_teams.aggregate([
        {"$group":{"_id":"$playerID.highSchool","count":{"$sum":1}}},
        {"$project":{"_id":1,"count":1}},
        {"$sort":{"count":-1}},
        ])
    
for i in cursor:
    pprint(i)
# Out:
# {'_id': '', 'count': 1329}
# {'_id': 'Central', 'count': 202}
# {'_id': 'Roosevelt', 'count': 145}
# {'_id': 'East', 'count': 138}
# {'_id': 'Dunbar', 'count': 133}
# {'_id': 'Lincoln', 'count': 123}
# {'_id': 'Washington', 'count': 121}
# {'_id': 'McKinley', 'count': 116}
# {'_id': 'Thomas Jefferson', 'count': 89}
# {'_id': 'Overbrook', 'count': 88}
# {'_id': 'DeWitt Clinton', 'count': 86}
# {'_id': 'Booker T. Washington', 'count': 77}
# {'_id': 'Carver', 'count': 74}
# {'_id': 'George Washington', 'count': 74}
# {'_id': 'James Madison', 'count': 73}
# {'_id': 'Central Catholic', 'count': 73}
# {'_id': 'McClymonds', 'count': 69}
# {'_id': 'Skyline', 'count': 66}
# {'_id': 'DeMatha Catholic', 'count': 66}
# {'_id': 'Proviso East', 'count': 63}
# {'_id': 'Crenshaw', 'count': 62}
# {'_id': 'Mount Vernon', 'count': 61}
# {'_id': 'Inglewood', 'count': 59}
# {'_id': 'North', 'count': 56}
# {'_id': 'Pershing', 'count': 54}
# {'_id': 'LaSalle Academy', 'count': 53}
# {'_id': 'Archbishop Molloy', 'count': 52}
# {'_id': 'Power Memorial', 'count': 50}
# {'_id': 'Woodward', 'count': 50}
# {'_id': 'Dominguez', 'count': 50}
# {'_id': 'Romulus', 'count': 50}
# {'_id': 'Desha Central', 'count': 50}
# {'_id': 'St. Augustine', 'count': 48}
# {'_id': 'West', 'count': 47}
# {'_id': 'Southwest', 'count': 47}
# {'_id': 'Manual', 'count': 47}
# {'_id': 'Boys', 'count': 46}
# {'_id': 'Roman Catholic', 'count': 46}
# {'_id': 'Jefferson', 'count': 46}
# {'_id': 'Withrow', 'count': 45}
# {'_id': "St. Michael's", 'count': 44}
# {'_id': 'Woodrow Wilson', 'count': 44}
# {'_id': 'Riverside Polytech', 'count': 43}
# {'_id': 'Hamilton', 'count': 41}
# {'_id': 'Petersburg', 'count': 41}
# {'_id': 'Spingarn', 'count': 41}
# {'_id': 'Morningside', 'count': 40}
# {'_id': 'Oak Hill Academy', 'count': 40}
# {'_id': 'Hillcrest', 'count': 40}
# {'_id': 'Pacific Palisades', 'count': 40}
# {'_id': 'DuSable', 'count': 39}
# {'_id': 'Lafayette', 'count': 39}
# {'_id': 'Eastern', 'count': 39}
# {'_id': 'Simon Gratz', 'count': 39}
# {'_id': 'Franklin', 'count': 38}
# {'_id': 'Newtown', 'count': 38}
# {'_id': 'Southwestern', 'count': 38}
# {'_id': 'Melrose', 'count': 37}
# {'_id': 'Mt. Carmel', 'count': 37}
# {'_id': 'Northwestern', 'count': 37}
# {'_id': 'Treadwell', 'count': 37}
# {'_id': 'Long Beach Polytech', 'count': 37}
# {'_id': 'John Muir', 'count': 36}
# {'_id': 'Verbum Dei', 'count': 36}
# {'_id': 'Edison', 'count': 36}
# {'_id': 'Benton Harbor', 'count': 35}
# {'_id': 'Canarsie', 'count': 35}
# {'_id': 'Central Hower', 'count': 35}
# {'_id': 'Benjamin Franklin', 'count': 35}
# {'_id': 'Westinghouse Vocational', 'count': 34}
# {'_id': 'De La Salle Catholic', 'count': 34}
# {'_id': 'Thornton Township', 'count': 34}
# {'_id': 'Everett', 'count': 34}
# {'_id': 'A.C. Flora', 'count': 33}
# {'_id': 'South', 'count': 33}
# {'_id': 'Cleveland', 'count': 33}
# {'_id': 'John Jay', 'count': 33}
# {'_id': 'Kennedy', 'count': 33}
# {'_id': 'Marshall', 'count': 33}
# {'_id': 'Cardinal Hayes', 'count': 32}
# {'_id': 'Palos Verdes', 'count': 32}
# {'_id': 'Weaver', 'count': 32}
# {'_id': 'Mitchell', 'count': 32}
# {'_id': 'Brandon', 'count': 32}
# {'_id': "St. Joseph's", 'count': 31}
# {'_id': 'Vocational', 'count': 31}
# {'_id': 'Lowell', 'count': 31}
# {'_id': 'Belmont', 'count': 31}
# {'_id': 'Enloe', 'count': 31}
# {'_id': 'Elgin', 'count': 31}
# {'_id': 'Columbia', 'count': 31}
# {'_id': 'Ballard', 'count': 31}
# {'_id': 'Murrah', 'count': 31}
# {'_id': 'Thornridge', 'count': 30}
# {'_id': 'Christian Brothers', 'count': 30}
# {'_id': 'Detroit Country Day', 'count': 30}
# {'_id': 'Schenley', 'count': 30}
# {'_id': 'Highland Park', 'count': 30}
# {'_id': 'John Hay', 'count': 30}
# {'_id': 'Middletown', 'count': 30}
# {'_id': 'Douglass', 'count': 30}
# {'_id': 'Rainier Beach', 'count': 30}
# {'_id': 'Rogers', 'count': 29}
# {'_id': 'Garfield', 'count': 29}
# {'_id': 'Jordan', 'count': 29}
# {'_id': 'Centralia', 'count': 29}
# {'_id': 'Holy Cross', 'count': 29}
# {'_id': 'Hillside', 'count': 29}
# {'_id': 'Torrey Pines', 'count': 28}
# {'_id': 'Springfield', 'count': 28}
# {'_id': 'Parker', 'count': 28}
# {'_id': 'Omaha Tech', 'count': 28}
# {'_id': 'Zachary', 'count': 28}
# {'_id': 'Hancock Central', 'count': 28}
# {'_id': 'South Mecklenburg', 'count': 28}
# {'_id': 'Muncie Central', 'count': 27}
# {'_id': 'Wichita Heights', 'count': 27}
# {'_id': 'Harrison', 'count': 27}
# {'_id': 'Brantley', 'count': 27}
# {'_id': 'Ashbrook', 'count': 27}
# {'_id': 'John Bartram', 'count': 27}
# {'_id': 'Alexander Hamilton', 'count': 27}
# {'_id': 'West Catholic', 'count': 27}
# {'_id': 'Lindbloom', 'count': 27}
# {'_id': 'Tilden', 'count': 27}
# {'_id': 'Christ the King', 'count': 26}
# {'_id': "St. Anthony's", 'count': 26}
# {'_id': 'Grant', 'count': 26}
# {'_id': 'Mackin', 'count': 26}
# {'_id': 'De La Salle', 'count': 26}
# {'_id': 'Murray-Wright', 'count': 26}
# {'_id': 'Male', 'count': 26}
# {'_id': 'Lanier', 'count': 26}
# {'_id': 'Riverside', 'count': 26}
# {'_id': 'Northwestern Community', 'count': 26}
# {'_id': 'Hobbs', 'count': 25}
# {'_id': 'Dobbins Tech', 'count': 25}
# {'_id': 'Brother Rice', 'count': 25}
# {'_id': 'Xaverian', 'count': 25}
# {'_id': 'Clarksville', 'count': 25}
# {'_id': 'Berkeley', 'count': 25}
# {'_id': 'Rocky Mount', 'count': 25}
# {'_id': 'Wyandotte', 'count': 25}
# {'_id': 'Edgewood', 'count': 25}
# {'_id': 'St. Xavier', 'count': 25}
# {'_id': 'Arsenal Tech', 'count': 24}
# {'_id': 'Monaca Senior', 'count': 24}
# {'_id': 'Lexington', 'count': 24}
# {'_id': 'Cambridge Rindge & Latin', 'count': 24}
# {'_id': 'St. Joseph Academy', 'count': 24}
# {'_id': 'Benson Polytechnic', 'count': 24}
# {'_id': 'Seton Hall Prep', 'count': 24}
# {'_id': 'Altoona Area', 'count': 24}
# {'_id': 'Benjamin Cardozo', 'count': 24}
# {'_id': 'Notre Dame', 'count': 24}
# {'_id': 'Westinghouse', 'count': 23}
# {'_id': 'Westchester', 'count': 23}
# {'_id': 'Harvard-Westlake Prep', 'count': 23}
# {'_id': 'Rancho', 'count': 23}
# {'_id': 'West Memphis', 'count': 23}
# {'_id': 'Martin Luther King', 'count': 23}
# {'_id': 'Erasmus Hall', 'count': 23}
# {'_id': 'Fort Hamilton', 'count': 23}
# {'_id': 'Sumner', 'count': 23}
# {'_id': 'Alfred Lawless', 'count': 23}
# {'_id': 'Archbishop Alter', 'count': 23}
# {'_id': 'Woodlawn', 'count': 23}
# {'_id': 'John C. Fremont', 'count': 22}
# {'_id': 'Pasadena', 'count': 22}
# {'_id': 'Split', 'count': 22}
# {'_id': 'Jim Hill', 'count': 22}
# {'_id': 'William B. Murrah', 'count': 22}
# {'_id': 'Martinsville', 'count': 22}
# {'_id': 'Morehouse', 'count': 22}
# {'_id': 'Concord', 'count': 22}
# {'_id': 'Lanphier', 'count': 22}
# {'_id': 'Collins', 'count': 22}
# {'_id': 'Holland', 'count': 22}
# {'_id': 'All Hallows', 'count': 21}
# {'_id': 'Garland', 'count': 21}
# {'_id': 'Warren Harding', 'count': 21}
# {'_id': 'Monrovia', 'count': 21}
# {'_id': 'Peekskill', 'count': 21}
# {'_id': 'Enid', 'count': 21}
# {'_id': 'Hirsch Metro', 'count': 21}
# {'_id': 'Northern', 'count': 21}
# {'_id': 'Cathedral', 'count': 21}
# {'_id': 'Marietta', 'count': 21}
# {'_id': 'Galileo', 'count': 21}
# {'_id': 'Jefferson Davis', 'count': 21}
# {'_id': 'Lake Weir', 'count': 21}
# {'_id': 'Jamesville-DeWitt', 'count': 21}
# {'_id': 'West Philadelphia', 'count': 21}
# {'_id': 'Maury', 'count': 21}
# {'_id': 'Abraham Lincoln', 'count': 21}
# {'_id': 'Pearl', 'count': 20}
# {'_id': 'North Shore', 'count': 20}
# {'_id': 'Tilden Tech', 'count': 20}
# {'_id': 'South Lakes', 'count': 20}
# {'_id': 'Union', 'count': 20}
# {'_id': 'Paterson Catholic', 'count': 20}
# {'_id': 'LaSalle', 'count': 20}
# {'_id': 'Calvert Hall', 'count': 20}
# {'_id': 'Kinston', 'count': 20}
# {'_id': 'Gonzaga Prep', 'count': 20}
# {'_id': 'Commerce', 'count': 20}
# {'_id': 'Foothill', 'count': 20}
# {'_id': 'Weequahic', 'count': 20}
# {'_id': 'Marion Franklin', 'count': 20}
# {'_id': 'Cole', 'count': 20}
# {'_id': 'Stillwater', 'count': 20}
# {'_id': 'Demopolis', 'count': 20}
# {'_id': 'South Oak Cliff', 'count': 20}
# {'_id': 'Artesia', 'count': 20}
# {'_id': 'St. Joseph of Notre Dame', 'count': 20}
# {'_id': 'Glendora', 'count': 20}
# {'_id': 'Hibbing', 'count': 20}
# {'_id': 'McCall', 'count': 20}
# {'_id': 'Farrell', 'count': 20}
# {'_id': 'Truman/Oak Hill', 'count': 20}
# {'_id': 'Parkview', 'count': 19}
# {'_id': 'Bishop Loughlin Memorial', 'count': 19}
# {'_id': 'Macomber-Whitney', 'count': 19}
# {'_id': 'Fairview', 'count': 19}
# {'_id': 'Institute Boboto', 'count': 19}
# {'_id': 'South Garland', 'count': 19}
# {'_id': 'Coolidge', 'count': 19}
# {'_id': 'Wingate', 'count': 19}
# {'_id': 'Eau Claire', 'count': 19}
# {'_id': 'Rice', 'count': 19}
# {'_id': 'Summerfield', 'count': 19}
# {'_id': "St. Joseph's Prep", 'count': 19}
# {'_id': 'St. Francis DeSales', 'count': 19}
# {'_id': 'Finney', 'count': 19}
# {'_id': 'Lebanon', 'count': 19}
# {'_id': 'Lake Worth Community', 'count': 19}
# {'_id': 'Kenwood', 'count': 19}
# {'_id': 'Crane Tech', 'count': 19}
# {'_id': 'Thomas Edison', 'count': 19}
# {'_id': 'Shelby', 'count': 18}
# {'_id': 'Forest Hills', 'count': 18}
# {'_id': 'Shaker', 'count': 18}
# {'_id': 'Henry Ford', 'count': 18}
# {'_id': 'Lawrence North', 'count': 18}
# {'_id': "St. Mary's", 'count': 18}
# {'_id': 'Hartford Public / Conard', 'count': 18}
# {'_id': 'Roulhac / Carver', 'count': 18}
# {'_id': 'Huguenot', 'count': 18}
# {'_id': 'Reading', 'count': 18}
# {'_id': 'Hamburg', 'count': 18}
# {'_id': 'Muslim Teachers College', 'count': 18}
# {'_id': 'Long Island Lutheran', 'count': 18}
# {'_id': 'Slater', 'count': 18}
# {'_id': 'Fontana', 'count': 18}
# {'_id': 'Lower Merion', 'count': 18}
# {'_id': 'Carroll', 'count': 18}
# {'_id': 'Crisp County', 'count': 18}
# {'_id': "Bishop O'Dowd", 'count': 18}
# {'_id': 'Laurinburg Institute', 'count': 18}
# {'_id': 'Bastrop', 'count': 18}
# {'_id': 'Kinston / Oak Hill', 'count': 18}
# {'_id': 'University', 'count': 18}
# {'_id': 'Glen A. Wilson', 'count': 17}
# {'_id': 'Bellaire', 'count': 17}
# {'_id': 'J.T. Barber', 'count': 17}
# {'_id': 'Walt Whitman', 'count': 17}
# {'_id': 'Northeast', 'count': 17}
# {'_id': 'Mansfield', 'count': 17}
# {'_id': 'Washington Union', 'count': 17}
# {'_id': 'St. Pius X', 'count': 17}
# {'_id': 'Rolling Meadows', 'count': 17}
# {'_id': 'Tuley', 'count': 17}
# {'_id': 'Hamtramck', 'count': 17}
# {'_id': 'Bloomfield Senior', 'count': 17}
# {'_id': 'St. Bernard', 'count': 17}
# {'_id': 'Owensboro', 'count': 17}
# {'_id': 'Stephens County', 'count': 17}
# {'_id': 'South Side', 'count': 17}
# {'_id': 'Shadow Mountain', 'count': 17}
# {'_id': 'Stall', 'count': 17}
# {'_id': 'Camden', 'count': 17}
# {'_id': 'Andalusia', 'count': 17}
# {'_id': 'Oshkosh', 'count': 17}
# {'_id': 'South Division', 'count': 17}
# {'_id': 'St. Francis Prep', 'count': 17}
# {'_id': 'John Marshall', 'count': 17}
# {'_id': 'Lakewood', 'count': 17}
# {'_id': 'Mauldin / Farragut Academy', 'count': 17}
# {'_id': 'David T. Howard', 'count': 17}
# {'_id': 'North Brunswick', 'count': 17}
# {'_id': 'Broad Ripple', 'count': 17}
# {'_id': 'Shawnee', 'count': 17}
# {'_id': 'Chrysler', 'count': 17}
# {'_id': 'Bluestone Senior', 'count': 17}
# {'_id': 'Fairfax', 'count': 17}
# {'_id': 'Quitman', 'count': 17}
# {'_id': 'River Dell', 'count': 17}
# {'_id': 'Masuk', 'count': 17}
# {'_id': 'Bennett', 'count': 17}
# {'_id': 'Sussex Central', 'count': 17}
# {'_id': 'Walter Cohen', 'count': 17}
# {'_id': 'Ecorse', 'count': 17}
# {'_id': 'Ben Smith', 'count': 17}
# {'_id': 'Bethel', 'count': 17}
# {'_id': 'St. Johns Military', 'count': 17}
# {'_id': 'Lawrence County', 'count': 16}
# {'_id': 'Buchholz', 'count': 16}
# {'_id': 'Leeds', 'count': 16}
# {'_id': 'Hartford Public', 'count': 16}
# {'_id': 'Hunter Huss', 'count': 16}
# {'_id': 'Ramona', 'count': 16}
# {'_id': 'Mount Zion Christian Academy / Auburndale', 'count': 16}
# {'_id': 'Sterling', 'count': 16}
# {'_id': 'Compton', 'count': 16}
# {'_id': 'Wilmer-Hutchins', 'count': 16}
# {'_id': 'Luther Burbank Sr.', 'count': 16}
# {'_id': 'Hoover', 'count': 16}
# {'_id': 'Cupertino', 'count': 16}
# {'_id': 'Temple', 'count': 16}
# {'_id': 'Dreher', 'count': 16}
# {'_id': "Hudson's Bay", 'count': 16}
# {'_id': 'Longview', 'count': 16}
# {'_id': 'Macomber', 'count': 16}
# {'_id': 'Greenbriar East', 'count': 16}
# {'_id': 'Ames', 'count': 16}
# {'_id': 'Rich Central', 'count': 16}
# {'_id': 'Fair Park', 'count': 16}
# {'_id': 'St. Martin De Porres', 'count': 16}
# {'_id': 'Mercer Island', 'count': 16}
# {'_id': 'Columbus', 'count': 16}
# {'_id': 'Daytona Beach Mainland', 'count': 16}
# {'_id': 'Elizabeth', 'count': 16}
# {'_id': 'Kiser', 'count': 16}
# {'_id': 'Power Memorial / Xaverian', 'count': 16}
# {'_id': 'Page / Lawrence', 'count': 16}
# {'_id': 'Middleton', 'count': 16}
# {'_id': 'Fort Defiance', 'count': 16}
# {'_id': 'Eula D. Britton', 'count': 16}
# {'_id': 'St. Anthony', 'count': 16}
# {'_id': 'Therrell', 'count': 16}
# {'_id': 'Jackson', 'count': 16}
# {'_id': 'Eastside', 'count': 16}
# {'_id': 'Bloomington North', 'count': 16}
# {'_id': 'Belgrade', 'count': 16}
# {'_id': 'John Harris', 'count': 16}
# {'_id': "Roselle / St. Patrick's", 'count': 16}
# {'_id': 'Farragut', 'count': 16}
# {'_id': 'Blackburg', 'count': 16}
# {'_id': 'Flushing', 'count': 16}
# {'_id': 'Bridgeport', 'count': 16}
# {'_id': 'Kashmere', 'count': 16}
# {'_id': 'Dunbar (DNP)', 'count': 16}
# {'_id': 'East Noble / Maine Central Institute', 'count': 16}
# {'_id': 'Glenn Hills', 'count': 16}
# {'_id': 'Indian River', 'count': 16}
# {'_id': 'Nichols School', 'count': 15}
# {'_id': 'Wheeler', 'count': 15}
# {'_id': 'Poway', 'count': 15}
# {'_id': 'Southwestern / Chadsey', 'count': 15}
# {'_id': 'Richmond', 'count': 15}
# {'_id': 'Lyons Township', 'count': 15}
# {'_id': 'Western', 'count': 15}
# {'_id': 'Cherry Creek', 'count': 15}
# {'_id': 'North Eugene', 'count': 15}
# {'_id': 'Blue Springs', 'count': 15}
# {'_id': 'Winchendon School', 'count': 15}
# {'_id': 'Ely', 'count': 15}
# {'_id': 'Cooley/Northern', 'count': 15}
# {'_id': 'Lincoln / Oak Hill Academy', 'count': 15}
# {'_id': 'M.X. Shabazz', 'count': 15}
# {'_id': 'Emsley A. Laney', 'count': 15}
# {'_id': 'Archbishop Carroll', 'count': 15}
# {'_id': 'Batavia', 'count': 15}
# {'_id': "St. John's Prep", 'count': 15}
# {'_id': 'West Side', 'count': 15}
# {'_id': 'Killian', 'count': 15}
# {'_id': 'Vincent', 'count': 15}
# {'_id': "St. Dunstan's Episcopal", 'count': 15}
# {'_id': 'Dematha Catholic', 'count': 15}
# {'_id': 'Dunbar / Southern', 'count': 15}
# {'_id': 'St. Anne', 'count': 15}
# {'_id': 'Old Saybrook', 'count': 15}
# {'_id': 'Independence', 'count': 15}
# {'_id': 'Elk Grove', 'count': 15}
# {'_id': 'Bethel Park Senior', 'count': 15}
# {'_id': 'Putnam City', 'count': 15}
# {'_id': 'Motley', 'count': 15}
# {'_id': 'El Cerrito', 'count': 15}
# {'_id': 'Madison Heights', 'count': 15}
# {'_id': 'Northside', 'count': 15}
# {'_id': 'Andrew Jackson', 'count': 15}
# {'_id': 'Alief Elsik', 'count': 15}
# {'_id': 'Nazareth Regional', 'count': 15}
# {'_id': 'Maynard Evans', 'count': 15}
# {'_id': 'Franklin D. Roosevelt', 'count': 15}
# {'_id': 'Blair Academy', 'count': 15}
# {'_id': 'Willowridge', 'count': 15}
# {'_id': 'Crossroads', 'count': 15}
# {'_id': 'West End', 'count': 15}
# {'_id': 'Oceanside', 'count': 15}
# {'_id': 'Meridian', 'count': 15}
# {'_id': 'Winnfield Senior', 'count': 15}
# {'_id': 'Cooley', 'count': 15}
# {'_id': 'Waukegan Twsp.', 'count': 15}
# {'_id': 'Flint Hill Prep', 'count': 15}
# {'_id': 'Snyder', 'count': 15}
# {'_id': 'Mount St. Michael', 'count': 15}
# {'_id': 'Fremont', 'count': 15}
# {'_id': 'Moline', 'count': 15}
# {'_id': 'Boyd Anderson', 'count': 15}
# {'_id': 'Russellville', 'count': 15}
# {'_id': 'St. Ignatius', 'count': 15}
# {'_id': 'Providence', 'count': 15}
# {'_id': 'Edwardsville', 'count': 14}
# {'_id': 'Maggie Walker', 'count': 14}
# {'_id': 'Crispus Attucks', 'count': 14}
# {'_id': 'Monterey', 'count': 14}
# {'_id': 'Crespi Carmelite', 'count': 14}
# {'_id': 'Rontgen Gymnasium', 'count': 14}
# {'_id': 'DeRidder', 'count': 14}
# {'_id': 'Cardinal Ritter', 'count': 14}
# {'_id': 'Harding', 'count': 14}
# {'_id': 'Wheatley', 'count': 14}
# {'_id': 'Forest', 'count': 14}
# {'_id': 'St. Joseph', 'count': 14}
# {'_id': 'Traverse City Sr.', 'count': 14}
# {'_id': 'Williamstown', 'count': 14}
# {'_id': 'Leo', 'count': 14}
# {'_id': 'Cedar Grove', 'count': 14}
# {'_id': 'Stevens', 'count': 14}
# {'_id': 'Locust Valley', 'count': 14}
# {'_id': 'Kempsville', 'count': 14}
# {'_id': 'Cass Tech', 'count': 14}
# {'_id': 'Blair', 'count': 14}
# {'_id': 'Monticello', 'count': 14}
# {'_id': 'Bradley', 'count': 14}
# {'_id': 'Nachitoches Central', 'count': 14}
# {'_id': 'Samuel Clemens', 'count': 14}
# {'_id': 'Adelphi Academy', 'count': 14}
# {'_id': 'Marshfield', 'count': 14}
# {'_id': 'Rochester', 'count': 14}
# {'_id': 'Mullen', 'count': 14}
# {'_id': 'Clifford J. Scott', 'count': 14}
# {'_id': 'Homestead', 'count': 14}
# {'_id': 'Corvallis', 'count': 14}
# {'_id': 'Roselle Park', 'count': 14}
# {'_id': 'Saginaw', 'count': 14}
# {'_id': 'Huntington Beach', 'count': 14}
# {'_id': 'Greenway', 'count': 14}
# {'_id': 'Blackford', 'count': 14}
# {'_id': 'Catholic', 'count': 14}
# {'_id': 'Rock Island', 'count': 14}
# {'_id': 'Simeon', 'count': 14}
# {'_id': 'Hayward', 'count': 14}
# {'_id': 'South Oak Cliff (DNP)', 'count': 14}
# {'_id': 'Spingarn / Phelps Vocational', 'count': 14}
# {'_id': 'Georgetown', 'count': 14}
# {'_id': 'Adlai E. Stevenson', 'count': 14}
# {'_id': 'Messmer', 'count': 14}
# {'_id': 'Bellefontaine', 'count': 14}
# {'_id': 'Alonzo A. Crim', 'count': 14}
# {'_id': 'McDuffie', 'count': 14}
# {'_id': 'Center', 'count': 14}
# {'_id': 'Sandusky', 'count': 14}
# {'_id': 'Portage', 'count': 14}
# {'_id': 'McNair/Pershing', 'count': 14}
# {'_id': 'San Bernardino', 'count': 14}
# {'_id': 'Braddock', 'count': 14}
# {'_id': 'Clairton', 'count': 14}
# {'_id': 'David Carter', 'count': 14}
# {'_id': 'John H. Francis Polytechnic', 'count': 14}
# {'_id': 'Austin / Westinghouse Voc.', 'count': 14}
# {'_id': 'Bladensburg', 'count': 14}
# {'_id': 'Raytown', 'count': 14}
# {'_id': 'Mainland', 'count': 14}
# {'_id': 'Osbourn Park', 'count': 14}
# {'_id': 'Bingham', 'count': 14}
# {'_id': 'Arthur Hill', 'count': 14}
# {'_id': 'Plymouth', 'count': 14}
# {'_id': 'Cornerstone Christian Academy', 'count': 14}
# {'_id': 'Emery County', 'count': 14}
# {'_id': 'Blaine', 'count': 14}
# {'_id': 'Springfield Gardens', 'count': 14}
# {'_id': 'Evans', 'count': 14}
# {'_id': 'East Bank', 'count': 14}
# {'_id': 'South Catholic', 'count': 14}
# {'_id': 'Fenwick', 'count': 14}
# {'_id': 'Carbondale', 'count': 14}
# {'_id': 'Paseo', 'count': 14}
# {'_id': 'Oakland Technical', 'count': 14}
# {'_id': 'Madison', 'count': 14}
# {'_id': 'Amityville', 'count': 14}
# {'_id': 'Gulledge', 'count': 14}
# {'_id': 'AllSaints  / Mansfield', 'count': 14}
# {'_id': 'Lake Braddock Secondary', 'count': 14}
# {'_id': 'Silver Creek', 'count': 14}
# {'_id': 'Tulsa Central', 'count': 14}
# {'_id': 'Gentry', 'count': 14}
# {'_id': 'Telfair County', 'count': 14}
# {'_id': 'Athens Area', 'count': 13}
# {'_id': 'Haywood', 'count': 13}
# {'_id': 'Seneca', 'count': 13}
# {'_id': 'Erasmus Hall / Linbloom / Atkins', 'count': 13}
# {'_id': 'Encina', 'count': 13}
# {'_id': 'Austin Catholic', 'count': 13}
# {'_id': 'Flint Central / Washington', 'count': 13}
# {'_id': 'St. Amant', 'count': 13}
# {'_id': 'Fifth Avenue', 'count': 13}
# {'_id': 'Crestview', 'count': 13}
# {'_id': 'Gordon Military H.S.', 'count': 13}
# {'_id': 'Ethel Knight', 'count': 13}
# {'_id': 'Washington Park', 'count': 13}
# {'_id': 'Apollo', 'count': 13}
# {'_id': 'Linton', 'count': 13}
# {'_id': 'William E. Grady Vocational', 'count': 13}
# {'_id': 'Kohler', 'count': 13}
# {'_id': 'Mays Academy', 'count': 13}
# {'_id': 'Manual Arts', 'count': 13}
# {'_id': 'Mt. Vernon', 'count': 13}
# {'_id': 'Athens', 'count': 13}
# {'_id': 'Simmons', 'count': 13}
# {'_id': 'Salisbury', 'count': 13}
# {'_id': 'Sacramento', 'count': 13}
# {'_id': 'San Pedro', 'count': 13}
# {'_id': 'Norwalk', 'count': 13}
# {'_id': 'West Charlotte / Oak Hill Academy', 'count': 13}
# {'_id': 'Childersburg', 'count': 13}
# {'_id': 'Wilson (DNP)', 'count': 13}
# {'_id': '4 School', 'count': 13}
# {'_id': 'Soldan', 'count': 13}
# {'_id': 'Hudson Catholic', 'count': 13}
# {'_id': 'Taft', 'count': 13}
# {'_id': 'Alhambra (DNP)', 'count': 13}
# {'_id': 'Ball', 'count': 13}
# {'_id': 'Brookwood / Colegio Santiago Apostol', 'count': 13}
# {'_id': 'Carlisle', 'count': 13}
# {'_id': 'Woodside', 'count': 13}
# {'_id': 'St. Francis', 'count': 13}
# {'_id': 'Warsaw Community', 'count': 13}
# {'_id': 'Capitol Hill', 'count': 13}
# {'_id': 'St. Dominic', 'count': 13}
# {'_id': 'El Paso / Albuquerque', 'count': 13}
# {'_id': "O'Fallon Tech/Vashon/McKinley", 'count': 13}
# {'_id': 'West New York Memorial', 'count': 13}
# {'_id': 'El Segundo', 'count': 13}
# {'_id': 'Shortridge', 'count': 13}
# {'_id': 'Dupont', 'count': 13}
# {'_id': 'Eastern School of Commerce', 'count': 13}
# {'_id': 'Crossland', 'count': 13}
# {'_id': 'Valley', 'count': 13}
# {'_id': 'Balboa', 'count': 13}
# {'_id': 'Flushing (DNP)', 'count': 13}
# {'_id': 'Stonewall Jackson', 'count': 13}
# {'_id': 'Akron West', 'count': 13}
# {'_id': 'Groveport Madison', 'count': 13}
# {'_id': 'Dudley Senior', 'count': 13}
# {'_id': 'The Bolles School', 'count': 13}
# {'_id': 'Bellport', 'count': 13}
# {'_id': 'Suncoast', 'count': 13}
# {'_id': 'Springs Valley', 'count': 13}
# {'_id': 'Mater Dei', 'count': 13}
# {'_id': 'Stuyvesant', 'count': 13}
# {'_id': 'Kozchagin', 'count': 13}
# {'_id': 'Block', 'count': 13}
# {'_id': 'John Hersey', 'count': 13}
# {'_id': 'Coatesville Area', 'count': 13}
# {'_id': 'San Joaquin Memorial', 'count': 13}
# {'_id': 'Prosser Vocational / Neal F. Simeon', 'count': 13}
# {'_id': 'Crossroads School', 'count': 13}
# {'_id': 'Thornwood', 'count': 13}
# {'_id': 'Corbin', 'count': 13}
# {'_id': 'Christian Redemption Acad / Christ the King / St Thomas Aquinas',
#  'count': 13}
# {'_id': 'Princeton', 'count': 13}
# {'_id': 'Rhinelander', 'count': 13}
# {'_id': 'Southern', 'count': 13}
# {'_id': 'R.B. Chamberlain', 'count': 13}
# {'_id': 'Merritt Island', 'count': 13}
# {'_id': 'Delbarton', 'count': 13}
# {'_id': 'Dollarway', 'count': 13}
# {'_id': 'Raines', 'count': 13}
# {'_id': 'Marion', 'count': 13}
# {'_id': 'McLeansboro', 'count': 13}
# {'_id': 'Suffield Academy', 'count': 13}
# {'_id': 'Seward Park', 'count': 13}
# {'_id': 'Livermore', 'count': 12}
# {'_id': 'Rich East', 'count': 12}
# {'_id': 'Sequoia', 'count': 12}
# {'_id': 'Patrick Henry / Flint Hill Prep', 'count': 12}
# {'_id': 'Bowen(DNP)', 'count': 12}
# {'_id': 'New Utrecht', 'count': 12}
# {'_id': 'Salem', 'count': 12}
# {'_id': 'Southside', 'count': 12}
# {'_id': 'E.E. Worthing', 'count': 12}
# {'_id': 'Williston', 'count': 12}
# {'_id': 'McKeesport', 'count': 12}
# {'_id': 'Scott', 'count': 12}
# {'_id': 'Johnstown', 'count': 12}
# {'_id': 'George Wythe', 'count': 12}
# {'_id': 'Wickliffe', 'count': 12}
# {'_id': 'Shady Grove', 'count': 12}
# {'_id': 'Cholla', 'count': 12}
# {'_id': 'Laurel Heights', 'count': 12}
# {'_id': 'Long Island City', 'count': 12}
# {'_id': 'Castlemont', 'count': 12}
# {'_id': 'East Lansing', 'count': 12}
# {'_id': 'Strawberry Mansion', 'count': 12}
# {'_id': 'Seattle Prep', 'count': 12}
# {'_id': 'Teaneck', 'count': 12}
# {'_id': 'Cardozo', 'count': 12}
# {'_id': 'Winter Haven', 'count': 12}
# {'_id': 'Tecumseh', 'count': 12}
# {'_id': 'Moon Valley', 'count': 12}
# {'_id': 'East Kentwood', 'count': 12}
# {'_id': 'Pershing / Southeastern', 'count': 12}
# {'_id': 'Enloe / W. Columbus / Whitefield', 'count': 12}
# {'_id': 'Woodbridge', 'count': 12}
# {'_id': 'American School', 'count': 12}
# {'_id': 'Aviation', 'count': 12}
# {'_id': 'Milford Academy', 'count': 12}
# {'_id': 'Frayser', 'count': 12}
# {'_id': 'Little Rock Central', 'count': 12}
# {'_id': 'Granite City', 'count': 12}
# {'_id': 'Glynn Academy', 'count': 12}
# {'_id': 'Williamson', 'count': 12}
# {'_id': 'Mater Christi', 'count': 12}
# {'_id': 'Baton Rouge', 'count': 12}
# {'_id': 'Christian County', 'count': 12}
# {'_id': 'Almonta', 'count': 12}
# {'_id': 'Perth Amboy', 'count': 12}
# {'_id': 'Holy Spirit', 'count': 12}
# {'_id': 'Narbonne/Porterville', 'count': 12}
# {'_id': 'Englewood', 'count': 12}
# {'_id': 'Case Western Reserve English Language', 'count': 12}
# {'_id': 'Bryan Adams', 'count': 12}
# {'_id': 'Southport', 'count': 12}
# {'_id': 'Unity', 'count': 12}
# {'_id': 'William Grant', 'count': 12}
# {'_id': 'Woodville', 'count': 12}
# {'_id': 'Ullman', 'count': 12}
# {'_id': 'Frankfort', 'count': 12}
# {'_id': 'Dudley', 'count': 12}
# {'_id': 'Phillips', 'count': 12}
# {'_id': 'Doss', 'count': 12}
# {'_id': 'Malverne', 'count': 12}
# {'_id': 'Price', 'count': 12}
# {'_id': 'Thomasville Central', 'count': 12}
# {'_id': 'Broaddus', 'count': 12}
# {'_id': 'Glendale', 'count': 12}
# {'_id': 'Kettering', 'count': 12}
# {'_id': 'New Kensington', 'count': 12}
# {'_id': 'Chadsey', 'count': 12}
# {'_id': 'Southwest Atlanta Christian Academy', 'count': 12}
# {'_id': 'Western Hills', 'count': 12}
# {'_id': 'South Marshall', 'count': 12}
# {'_id': 'Kimball', 'count': 12}
# {'_id': 'Bonner Springs', 'count': 12}
# {'_id': 'Farmington', 'count': 12}
# {'_id': 'Tuscaloosa Academy', 'count': 12}
# {'_id': 'Gymnasium', 'count': 12}
# {'_id': 'Cardinal Dougherty / Maine Central Inst.', 'count': 12}
# {'_id': 'San Gorgonio', 'count': 12}
# {'_id': 'Dillard', 'count': 12}
# {'_id': 'Montgomery Blair', 'count': 12}
# {'_id': 'Atkins', 'count': 12}
# {'_id': 'Stuyvesant / Laurinburg', 'count': 12}
# {'_id': 'Corliss', 'count': 12}
# {'_id': 'Cold Spring Harbor', 'count': 12}
# {'_id': 'Minoa', 'count': 12}
# {'_id': 'Whitney Young', 'count': 12}
# {'_id': 'Duncanville', 'count': 12}
# {'_id': 'Lester', 'count': 12}
# {'_id': 'Waukegan', 'count': 12}
# {'_id': 'Ventura/SantaBarbara', 'count': 12}
# {'_id': 'Brebeuf Prep', 'count': 12}
# {'_id': 'Plymouth Whitemarsh', 'count': 12}
# {'_id': 'John Adams / East', 'count': 11}
# {'_id': 'George Washington Carver', 'count': 11}
# {'_id': 'J.R. Shields', 'count': 11}
# {'_id': 'Brunswick', 'count': 11}
# {'_id': 'Benilde-St. Margaret', 'count': 11}
# {'_id': 'Springfield Central', 'count': 11}
# {'_id': 'Jeffersonville', 'count': 11}
# {'_id': 'Metropolitan', 'count': 11}
# {'_id': 'David Lipscomb', 'count': 11}
# {'_id': 'Germantown Academy', 'count': 11}
# {'_id': 'G.A.R. Memorial', 'count': 11}
# {'_id': 'Scotch College', 'count': 11}
# {'_id': 'Rangitoto School', 'count': 11}
# {'_id': 'Gov. Drummer Academy', 'count': 11}
# {'_id': 'Rufus King', 'count': 11}
# {'_id': 'South Fulton', 'count': 11}
# {'_id': 'John Randolph Tucker', 'count': 11}
# {'_id': 'Pueblo', 'count': 11}
# {'_id': 'Gardena', 'count': 11}
# {'_id': 'Jackson-Olin', 'count': 11}
# {'_id': 'John Kennedy', 'count': 11}
# {'_id': 'Franklin K. Lane', 'count': 11}
# {'_id': 'Technical', 'count': 11}
# {'_id': 'Kokomo', 'count': 11}
# {'_id': "St. John's Prep / LaSalle Academy", 'count': 11}
# {'_id': 'Palo Alto', 'count': 11}
# {'_id': 'Killian / Miami Senior / Oak Hill Academy', 'count': 11}
# {'_id': 'Greene Central', 'count': 11}
# {'_id': 'Instituto Alvaro Guiao', 'count': 11}
# {'_id': 'Eleanor Roosevelt', 'count': 11}
# {'_id': 'Dresden', 'count': 11}
# {'_id': 'Riordan', 'count': 11}
# {'_id': 'Wilkie', 'count': 11}
# {'_id': 'Crim', 'count': 11}
# {'_id': 'Akron South', 'count': 11}
# {'_id': 'Samuel F.B. Morse', 'count': 11}
# {'_id': 'Overton', 'count': 11}
# {'_id': 'East Central', 'count': 11}
# {'_id': 'Xenia', 'count': 11}
# {'_id': 'Lower Richland', 'count': 11}
# {'_id': 'Westminster', 'count': 11}
# {'_id': 'Wichita Collegiate', 'count': 11}
# {'_id': 'Cimarron Memorial', 'count': 11}
# {'_id': 'South Philadelphia', 'count': 11}
# {'_id': 'Cardinal Gibbons', 'count': 11}
# {'_id': 'Hemiska', 'count': 11}
# {'_id': 'Park / Maine Central Institute', 'count': 11}
# {'_id': 'Jack Yates', 'count': 11}
# {'_id': 'Hall', 'count': 11}
# {'_id': 'Barberton', 'count': 11}
# {'_id': 'Marist School', 'count': 11}
# {'_id': 'East St. Louis', 'count': 11}
# {'_id': 'Waxahachie', 'count': 11}
# {'_id': 'Bryant', 'count': 11}
# {'_id': 'Garey', 'count': 11}
# {'_id': 'Bridgewater-Raritan', 'count': 11}
# {'_id': 'Wauwatosa East', 'count': 11}
# {'_id': 'Hammond', 'count': 11}
# {'_id': 'Woodham', 'count': 11}
# {'_id': 'Benton', 'count': 11}
# {'_id': 'Midland', 'count': 11}
# {'_id': 'Hatsboro-Horsham', 'count': 11}
# {'_id': 'Robeson', 'count': 11}
# {'_id': 'Mar-Mac', 'count': 11}
# {'_id': 'Burlington', 'count': 11}
# {'_id': 'Camden Catholic (DNP)', 'count': 11}
# {'_id': 'Lithonia', 'count': 11}
# {'_id': 'Enumclaw', 'count': 11}
# {'_id': 'Diamond Bar', 'count': 11}
# {'_id': 'Fort Smith', 'count': 11}
# {'_id': 'Newman', 'count': 11}
# {'_id': 'South Division (DNP)', 'count': 11}
# {'_id': 'Florida A&M Univ. H.S.', 'count': 11}
# {'_id': 'Savannah', 'count': 11}
# {'_id': 'Maria Regina M.A.V.O.', 'count': 11}
# {'_id': 'Northwestern / Central', 'count': 11}
# {'_id': 'Northwestern Comm.', 'count': 11}
# {'_id': 'DeWitt Clinton (DNP)', 'count': 11}
# {'_id': 'Jesuit / University School of Milwaukee', 'count': 11}
# {'_id': 'Needham Broughton / Daniels / Edwards', 'count': 11}
# {'_id': 'Dowling', 'count': 11}
# {'_id': 'Oak Hill Academy / Sacred Heart / Dobbs Ferry', 'count': 11}
# {'_id': 'East Union', 'count': 11}
# {'_id': 'Atlantic City', 'count': 11}
# {'_id': 'Countryside', 'count': 11}
# {'_id': 'Mira Costa', 'count': 11}
# {'_id': 'Magruder', 'count': 11}
# {'_id': 'Wilbur Cross', 'count': 11}
# {'_id': 'Phelps Vocational', 'count': 11}
# {'_id': 'Overbrook / Moton', 'count': 11}
# {'_id': 'East Brunswick', 'count': 10}
# {'_id': 'Huntington', 'count': 10}
# {'_id': 'Temple / Benjamin Franklin / Roman Catholic', 'count': 10}
# {'_id': 'Cem Sultan', 'count': 10}
# {'_id': 'Las Plumas', 'count': 10}
# {'_id': 'University Heights Academy', 'count': 10}
# {'_id': 'Crystal City', 'count': 10}
# {'_id': 'Ben Davis', 'count': 10}
# {'_id': 'Yonkers', 'count': 10}
# {'_id': 'St. Louis Univ. High', 'count': 10}
# {'_id': 'Wallace Rose Hill', 'count': 10}
# {'_id': 'Starkville', 'count': 10}
# {'_id': 'Lawton', 'count': 10}
# {'_id': 'Perry', 'count': 10}
# {'_id': 'Charles Evans Hughes', 'count': 10}
# {'_id': 'Memorial / Lake Oswego', 'count': 10}
# {'_id': 'Fort Madison', 'count': 10}
# {'_id': 'Linden McKinley', 'count': 10}
# {'_id': 'Whitehall', 'count': 10}
# {'_id': 'Miller/Northeastern', 'count': 10}
# {'_id': 'Bishop Ford / Lawrenceville Prep', 'count': 10}
# {'_id': 'Hiram Johnson', 'count': 10}
# {'_id': 'Wichita East', 'count': 10}
# {'_id': 'The Colony', 'count': 10}
# {'_id': 'Pella', 'count': 10}
# {'_id': 'Frunzenskaya Sport School', 'count': 10}
# {'_id': 'Newlands Manorium', 'count': 10}
# {'_id': 'Marina', 'count': 10}
# {'_id': 'Frederick Douglass', 'count': 10}
# {'_id': 'Southfield', 'count': 10}
# {'_id': 'Scipio Jones', 'count': 10}
# {'_id': 'Kittitas', 'count': 10}
# {'_id': 'Lewis Palmer', 'count': 10}
# {'_id': 'Clifton J. Ozen', 'count': 10}
# {'_id': 'Roxana', 'count': 10}
# {'_id': 'Wahlert', 'count': 10}
# {'_id': 'Breckenridge County', 'count': 10}
# {'_id': 'Sioux City West', 'count': 10}
# {'_id': 'Altoona / Shaler', 'count': 10}
# {'_id': 'Thornton', 'count': 10}
# {'_id': 'Southampton', 'count': 10}
# {'_id': 'Del Campo', 'count': 10}
# {'_id': 'Henrico', 'count': 10}
# {'_id': 'South Milwaukee', 'count': 10}
# {'_id': 'Cleveland / DuBourg', 'count': 10}
# {'_id': 'Glenn / Hargrave', 'count': 10}
# {'_id': 'Harrisonburg', 'count': 10}
# {'_id': 'Joliet Catholic', 'count': 10}
# {'_id': 'Peabody', 'count': 10}
# {'_id': 'LaSalle (DNP)', 'count': 10}
# {'_id': 'Askov', 'count': 10}
# {'_id': 'Hogansville', 'count': 10}
# {'_id': 'Juneau-Douglas', 'count': 10}
# {'_id': 'St.Patricks / Surenpagge', 'count': 10}
# {'_id': 'Cypress Creek', 'count': 10}
# {'_id': 'Laurinburg', 'count': 10}
# {'_id': 'Potomac', 'count': 10}
# {'_id': 'Brentwood', 'count': 10}
# {'_id': 'Countryside Senior', 'count': 10}
# {'_id': 'St. George', 'count': 10}
# {'_id': 'Zanesville', 'count': 10}
# {'_id': 'Lane Tech', 'count': 10}
# {'_id': 'Sprayberry', 'count': 10}
# {'_id': 'Caldwell County', 'count': 10}
# {'_id': 'Helix', 'count': 10}
# {'_id': 'Charleston', 'count': 10}
# {'_id': 'Clark', 'count': 10}
# {'_id': 'Schurz', 'count': 10}
# {'_id': 'Towson Catholic / Oak Hill Academy', 'count': 10}
# {'_id': 'Kapaun-Mt.Carmel', 'count': 10}
# {'_id': 'Iola', 'count': 10}
# {'_id': 'Goldsboro / Laurinburg Inst.', 'count': 10}
# {'_id': 'Person-Albion', 'count': 10}
# {'_id': 'South Sanwest Campus', 'count': 10}
# {'_id': 'Richard T. Crane', 'count': 10}
# {'_id': 'Chillicothe', 'count': 10}
# {'_id': 'Joliet Catholic / Quigley Prep', 'count': 10}
# {'_id': 'Archbishop Stepinac', 'count': 10}
# {'_id': 'Washington Park / St. Catherines', 'count': 10}
# {'_id': 'Coosa', 'count': 10}
# {'_id': 'McGavock', 'count': 10}
# {'_id': 'Groveland', 'count': 10}
# {'_id': 'Watsonville Union', 'count': 10}
# {'_id': 'Millensburg Military Academy', 'count': 10}
# {'_id': 'Holy Name', 'count': 10}
# {'_id': 'Scottsville', 'count': 10}
# {'_id': 'Euclid Shore', 'count': 10}
# {'_id': 'Wheeling', 'count': 10}
# {'_id': 'Sims', 'count': 10}
# {'_id': 'Benson', 'count': 10}
# {'_id': 'Federal Way', 'count': 10}
# {'_id': 'Santa Maria', 'count': 10}
# {'_id': 'Edmondson', 'count': 10}
# {'_id': 'East Atlanta', 'count': 10}
# {'_id': 'Hamilton Township', 'count': 10}
# {'_id': 'Burgin', 'count': 10}
# {'_id': 'Jamaica', 'count': 9}
# {'_id': 'Jonesboro', 'count': 9}
# {'_id': 'Piedmont Hills / Independence', 'count': 9}
# {'_id': 'Booker', 'count': 9}
# {'_id': 'Taylor County / Durham', 'count': 9}
# {'_id': 'Southern Univ. Lab', 'count': 9}
# {'_id': 'Glenn', 'count': 9}
# {'_id': 'Westlake', 'count': 9}
# {'_id': "St. Vincent-St. Mary's", 'count': 9}
# {'_id': 'New Hanover', 'count': 9}
# {'_id': 'Springfield South', 'count': 9}
# {'_id': 'San Ramon Valley', 'count': 9}
# {'_id': 'LeFlore', 'count': 9}
# {'_id': 'Bishop Timon', 'count': 9}
# {'_id': 'Crest', 'count': 9}
# {'_id': 'Merchantville', 'count': 9}
# {'_id': 'Mission Viejo', 'count': 9}
# {'_id': 'Davidson', 'count': 9}
# {'_id': 'Pentacostal Christian Academy', 'count': 9}
# {'_id': 'Friends Central', 'count': 9}
# {'_id': 'Big Sky', 'count': 9}
# {'_id': 'Bethel Park', 'count': 9}
# {'_id': 'Good Counsel', 'count': 9}
# {'_id': 'Myers Park', 'count': 9}
# {'_id': 'Franklin Township', 'count': 9}
# {'_id': 'Rainier Beach / Logan', 'count': 9}
# {'_id': 'Miami Senior', 'count': 9}
# {'_id': 'Gulfport', 'count': 9}
# {'_id': 'Grambling', 'count': 9}
# {'_id': 'Brentwood Academy', 'count': 9}
# {'_id': 'Parker-Gray', 'count': 9}
# {'_id': 'Taylor Allderdice', 'count': 9}
# {'_id': 'Pascagoula', 'count': 9}
# {'_id': 'Tamms', 'count': 9}
# {'_id': 'Steinert', 'count': 9}
# {'_id': 'Newport', 'count': 9}
# {'_id': 'Encinal', 'count': 9}
# {'_id': 'Pennsylvania Manor', 'count': 9}
# {'_id': 'Providence-St. Mel', 'count': 9}
# {'_id': 'Modesto', 'count': 9}
# {'_id': 'Richwoods / Central', 'count': 9}
# {'_id': 'Germantown', 'count': 9}
# {'_id': 'Hilo (DNP)', 'count': 9}
# {'_id': 'Cathedral Prep', 'count': 9}
# {'_id': 'Amundsen', 'count': 9}
# {'_id': 'Seagoville', 'count': 9}
# {'_id': 'Moon', 'count': 9}
# {'_id': 'Simi Valley', 'count': 9}
# {'_id': 'Dwight Morrow', 'count': 9}
# {'_id': 'Patrick Henry', 'count': 9}
# {'_id': 'Westside', 'count': 9}
# {'_id': "St. Rose's", 'count': 9}
# {'_id': 'Largo', 'count': 9}
# {'_id': 'East Tech', 'count': 9}
# {'_id': 'Richards', 'count': 9}
# {'_id': 'Chester', 'count': 9}
# {'_id': 'Strake Jesuit College Prep', 'count': 9}
# {'_id': 'Carr Creek', 'count': 9}
# {'_id': 'Miami Beach', 'count': 9}
# {'_id': 'Clarkston', 'count': 9}
# {'_id': 'East Peoria', 'count': 9}
# {'_id': 'Santa Barbara', 'count': 9}
# {'_id': 'Mt. Zion Christian Academy', 'count': 9}
# {'_id': 'McNair', 'count': 9}
# {'_id': 'Rindge & Latin', 'count': 9}
# {'_id': 'Teaneck / Garner Senior / Hargrave Military Academy', 'count': 9}
# {'_id': 'Memorial', 'count': 9}
# {'_id': 'Niles', 'count': 9}
# {'_id': 'Australian Institute of Sport', 'count': 9}
# {'_id': 'Newport Catholic', 'count': 9}
# {'_id': 'St. Nicholas of Tolentine', 'count': 9}
# {'_id': 'Mackenzie / Northwestern', 'count': 9}
# {'_id': 'Colbert County', 'count': 9}
# {'_id': 'Simon Bolivar', 'count': 9}
# {'_id': "O'Dea", 'count': 9}
# {'_id': 'American Senior', 'count': 9}
# {'_id': 'Hopkins', 'count': 9}
# {'_id': 'Willits/Reading', 'count': 9}
# {'_id': 'Lompoc', 'count': 9}
# {'_id': 'Bishop Eustace / Pennsauken', 'count': 9}
# {'_id': 'Hamden', 'count': 9}
# {'_id': 'Tri-Unity Christian', 'count': 9}
# {'_id': 'Del Mar', 'count': 9}
# {'_id': 'Airline', 'count': 9}
# {'_id': 'Bainbridge', 'count': 9}
# {'_id': 'Blair Academy /  Cardozo', 'count': 9}
# {'_id': 'Catasauqua', 'count': 9}
# {'_id': 'Madisonville', 'count': 9}
# {'_id': 'Lamar', 'count': 9}
# {'_id': 'Uniontown', 'count': 9}
# {'_id': 'Crane', 'count': 9}
# {'_id': 'Ballard-Hudson', 'count': 9}
# {'_id': 'Tilden (DNP)', 'count': 9}
# {'_id': 'East Alton-Wood River', 'count': 9}
# {'_id': 'San Diego', 'count': 9}
# {'_id': 'Freehold', 'count': 9}
# {'_id': 'Barringer', 'count': 9}
# {'_id': 'Santa Monica', 'count': 9}
# {'_id': 'Compton Union', 'count': 9}
# {'_id': 'Dusable', 'count': 9}
# {'_id': 'Balboa Newport Harbor', 'count': 9}
# {'_id': 'Brother Martin', 'count': 9}
# {'_id': 'Southside / Fork Union', 'count': 9}
# {'_id': 'Sewanaka', 'count': 9}
# {'_id': 'Southwestern Academy', 'count': 8}
# {'_id': 'Uniondale', 'count': 8}
# {'_id': 'Amanda Elzy', 'count': 8}
# {'_id': 'Prairie', 'count': 8}
# {'_id': 'Oak Hill Academy / McEachern', 'count': 8}
# {'_id': 'Hancock North Central', 'count': 8}
# {'_id': 'Midwest City', 'count': 8}
# {'_id': 'Humboldt', 'count': 8}
# {'_id': 'Prentiss', 'count': 8}
# {'_id': 'Dixon', 'count': 8}
# {'_id': 'Linden-Kildare', 'count': 8}
# {'_id': 'Jasper', 'count': 8}
# {'_id': 'Carmel', 'count': 8}
# {'_id': 'Laramie', 'count': 8}
# {'_id': 'Winfield', 'count': 8}
# {'_id': 'Jefferson Township', 'count': 8}
# {'_id': 'Salmen', 'count': 8}
# {'_id': 'Austin-East', 'count': 8}
# {'_id': 'Clay', 'count': 8}
# {'_id': 'Renton', 'count': 8}
# {'_id': 'Mahanoy City', 'count': 8}
# {'_id': 'Weirton', 'count': 8}
# {'_id': 'Far Rockaway', 'count': 8}
# {'_id': 'Higgins', 'count': 8}
# {'_id': 'Friendly', 'count': 8}
# {'_id': 'Harris/Minden', 'count': 8}
# {'_id': 'Barlow', 'count': 8}
# {'_id': 'Charlotte Christian', 'count': 8}
# {'_id': 'Eastdale', 'count': 8}
# {'_id': 'St. Peters', 'count': 8}
# {'_id': 'Montrose Christian', 'count': 8}
# {'_id': 'House', 'count': 8}
# {'_id': 'Fayetteville', 'count': 8}
# {'_id': 'St. Louis Park', 'count': 8}
# {'_id': 'Worthing', 'count': 8}
# {'_id': 'Fermin Lausen', 'count': 8}
# {'_id': 'Charles D. Owen', 'count': 8}
# {'_id': 'Durham', 'count': 8}
# {'_id': 'Scienceville', 'count': 8}
# {'_id': 'Brooklyn Tech', 'count': 8}
# {'_id': 'Dr. Phillips / St. Johns Prospect Hall', 'count': 8}
# {'_id': 'Iowa Falls', 'count': 8}
# {'_id': 'Justin F. Kimball', 'count': 8}
# {'_id': 'Picayune Memorial', 'count': 8}
# {'_id': 'Clarksdale', 'count': 8}
# {'_id': 'Sachem', 'count': 8}
# {'_id': 'Boulder', 'count': 8}
# {'_id': 'St. Benedicts Prep / Lakewood', 'count': 8}
# {'_id': 'Queen Anne', 'count': 8}
# {'_id': 'Burncoat', 'count': 8}
# {'_id': 'Worcester Acad / Mt Zion / St. Vincent Pallotti/ DeMatha', 'count': 8}
# {'_id': "St. Rita's", 'count': 8}
# {'_id': "Institut National du Sport et de l'Education Physique", 'count': 8}
# {'_id': 'Moss Point', 'count': 8}
# {'_id': 'Flint Northern', 'count': 8}
# {'_id': 'Textile (DNP)', 'count': 8}
# {'_id': 'Arcadia Valley', 'count': 8}
# {'_id': 'Pembroke Hill', 'count': 8}
# {'_id': 'Birmingham/Kuttawa', 'count': 8}
# {'_id': 'DNP', 'count': 8}
# {'_id': 'Mounds View', 'count': 8}
# {'_id': 'Dunbar / Archbishop Carroll', 'count': 8}
# {'_id': 'Scarsdale', 'count': 8}
# {'_id': 'Buena Vista', 'count': 8}
# {'_id': 'Union Hill', 'count': 8}
# {'_id': 'Valters Basketball School', 'count': 8}
# {'_id': 'New Hampton Prep', 'count': 8}
# {'_id': 'Overland', 'count': 8}
# {'_id': 'Atherton', 'count': 8}
# {'_id': 'Freeport', 'count': 8}
# {'_id': 'Zion-Benton', 'count': 8}
# {'_id': 'Ligon', 'count': 8}
# {'_id': 'Spingarn/Fairmont Hts', 'count': 8}
# {'_id': 'Mitchell-Baker', 'count': 8}
# {'_id': 'Forest Hills Northern', 'count': 8}
# {'_id': 'Jefferson ', 'count': 8}
# {'_id': 'East Bakersfield', 'count': 8}
# {'_id': 'Winona', 'count': 8}
# {'_id': 'Bishop Gorman / Santa Monica/Fresno', 'count': 8}
# {'_id': 'Spring Valley', 'count': 8}
# {'_id': 'Lycee Aristide Briand', 'count': 8}
# {'_id': 'American Christian', 'count': 8}
# {'_id': 'North Side', 'count': 8}
# {'_id': 'Centennial', 'count': 8}
# {'_id': 'Oakwood', 'count': 8}
# {'_id': 'Auburn', 'count': 8}
# {'_id': 'Maryvale', 'count': 8}
# {'_id': 'Griggsville', 'count': 8}
# {'_id': 'Wendell Phillips (DNP)', 'count': 8}
# {'_id': 'Northwestern / Clinton', 'count': 8}
# {'_id': 'DePaul Academy', 'count': 8}
# {'_id': 'Latta', 'count': 8}
# {'_id': 'Houston', 'count': 8}
# {'_id': 'South Kent Prep / Leuzinger', 'count': 8}
# {'_id': 'Camelback', 'count': 8}
# {'_id': 'Gerstmeyer', 'count': 7}
# {'_id': 'Bolsa Grande', 'count': 7}
# {'_id': 'Hillsboro', 'count': 7}
# {'_id': 'Chaparral', 'count': 7}
# {'_id': 'Brown Deer', 'count': 7}
# {'_id': 'Randolph Clay', 'count': 7}
# {'_id': 'Newman Smith', 'count': 7}
# {'_id': 'Modesto Christian', 'count': 7}
# {'_id': 'Allen County', 'count': 7}
# {'_id': 'Hayes', 'count': 7}
# {'_id': 'St. Catherine', 'count': 7}
# {'_id': 'Crawford County', 'count': 7}
# {'_id': 'West Forsyth', 'count': 7}
# {'_id': 'Riverdale', 'count': 7}
# {'_id': 'Blanchet', 'count': 7}
# {'_id': 'Warrensville Heights', 'count': 7}
# {'_id': 'South Kent Prep / Henninger', 'count': 7}
# {'_id': 'M.X. Shabbaz', 'count': 7}
# {'_id': 'South Charleston', 'count': 7}
# {'_id': 'Julia Richman', 'count': 7}
# {'_id': 'Samuel Gompers', 'count': 7}
# {'_id': 'Grover Cleveland', 'count': 7}
# {'_id': 'McPherson', 'count': 7}
# {'_id': 'Biloxi', 'count': 7}
# {'_id': 'Austin', 'count': 7}
# {'_id': 'Henry Weather', 'count': 7}
# {'_id': 'Webster Groves', 'count': 7}
# {'_id': 'Lawrence Academy', 'count': 7}
# {'_id': 'Anderson', 'count': 7}
# {'_id': 'Warren Central', 'count': 7}
# {'_id': 'Keokee (DNP)', 'count': 7}
# {'_id': 'South Canton', 'count': 7}
# {'_id': 'Mount Dora', 'count': 7}
# {'_id': 'Wilby', 'count': 7}
# {'_id': 'Wilson Memorial', 'count': 7}
# {'_id': 'Westover', 'count': 7}
# {'_id': 'Mt. Diablo', 'count': 7}
# {'_id': 'Proviso East (DNP)', 'count': 7}
# {'_id': 'Hazard', 'count': 7}
# {'_id': 'Manley Career Academy', 'count': 7}
# {'_id': 'Avery County', 'count': 7}
# {'_id': 'Westchester / Verbum Dei / Pacific Heights', 'count': 7}
# {'_id': 'Cardinal Dougherty', 'count': 7}
# {'_id': 'Boulder / Monarch', 'count': 7}
# {'_id': 'Bishop Ward', 'count': 7}
# {'_id': 'Callaway', 'count': 7}
# {'_id': 'St. Philip', 'count': 7}
# {'_id': 'Heritage Christian / Laurinburg / Paschal / Pineview', 'count': 7}
# {'_id': 'Capitol', 'count': 7}
# {'_id': 'Martins Ferry', 'count': 7}
# {'_id': 'South Gwinnett', 'count': 7}
# {'_id': 'Alta', 'count': 7}
# {'_id': 'Greenview', 'count': 7}
# {'_id': 'Montgomery / Anacostia / Hargrave', 'count': 7}
# {'_id': 'Brooklyn Prep', 'count': 7}
# {'_id': 'San Clemente', 'count': 7}
# {'_id': 'Worthington / Wehrle', 'count': 7}
# {'_id': 'St. Joseph / Solebury Prep', 'count': 7}
# {'_id': 'Clearbrook', 'count': 7}
# {'_id': 'Pike', 'count': 7}
# {'_id': 'Greece-Athena', 'count': 7}
# {'_id': 'Washington-Lee', 'count': 7}
# {'_id': 'Lee', 'count': 7}
# {'_id': 'South Bend Central', 'count': 7}
# {'_id': 'Ellenboro', 'count': 7}
# {'_id': 'Landon', 'count': 7}
# {'_id': 'Chaminade Prep', 'count': 7}
# {'_id': 'Forrest', 'count': 7}
# {'_id': 'Duxbury', 'count': 7}
# {'_id': 'Griffin', 'count': 7}
# {'_id': 'Highland', 'count': 7}
# {'_id': 'Aliquippa', 'count': 7}
# {'_id': 'Allentown Prep', 'count': 7}
# {'_id': 'Jones County', 'count': 7}
# {'_id': 'Bladensburg/Parkdale/Newport/Maine Central', 'count': 7}
# {'_id': 'Newport Harbor', 'count': 7}
# {'_id': 'Norcross', 'count': 7}
# {'_id': 'Missoula', 'count': 7}
# {'_id': 'Trenton', 'count': 7}
# {'_id': 'Talbottom', 'count': 7}
# {'_id': 'Hearne', 'count': 7}
# {'_id': 'George Washington (DNP)', 'count': 7}
# {'_id': 'Grace King', 'count': 7}
# {'_id': 'Rancho Alamitos', 'count': 7}
# {'_id': 'Olympic', 'count': 7}
# {'_id': 'Holy Trinity/Seton Hall Prep', 'count': 7}
# {'_id': 'St. Bonaventure Academy', 'count': 7}
# {'_id': 'Comstock', 'count': 7}
# {'_id': 'Coosa Central', 'count': 7}
# {'_id': 'Mullens', 'count': 7}
# {'_id': 'Union Center', 'count': 7}
# {'_id': 'West Oso', 'count': 7}
# {'_id': 'Nacogdoches', 'count': 7}
# {'_id': 'Leland', 'count': 7}
# {'_id': 'Binghamton Central / Peekskill Military Acad', 'count': 7}
# {'_id': 'Bartram', 'count': 7}
# {'_id': 'Bremerton', 'count': 7}
# {'_id': 'Jackson / Oak Hill / Laurinburg / Jefferson', 'count': 7}
# {'_id': 'Broadmoor', 'count': 7}
# {'_id': 'St. Vincent-St. Mary', 'count': 7}
# {'_id': 'Wilbur Wright', 'count': 7}
# {'_id': 'Peru', 'count': 7}
# {'_id': 'Laurinburg / IMG Academy / Blake / Armwood', 'count': 7}
# {'_id': 'Morton', 'count': 7}
# {'_id': 'Aberdeen', 'count': 7}
# {'_id': 'Trico Consolidated', 'count': 7}
# {'_id': 'Boston College H.S.', 'count': 7}
# {'_id': 'Tuskegee', 'count': 7}
# {'_id': 'Gonvick', 'count': 7}
# {'_id': 'Danville', 'count': 7}
# {'_id': 'Bowen', 'count': 6}
# {'_id': 'Myrtle Beach', 'count': 6}
# {'_id': 'Lew Wallace', 'count': 6}
# {'_id': 'Oak Hill Academy / Eastern', 'count': 6}
# {'_id': 'Stafford', 'count': 6}
# {'_id': 'Aurora', 'count': 6}
# {'_id': 'Mayfair', 'count': 6}
# {'_id': 'Gulf Shores Academy / Dobie', 'count': 6}
# {'_id': 'Goshen', 'count': 6}
# {'_id': 'Maine Central / Delafosse', 'count': 6}
# {'_id': 'Stivers', 'count': 6}
# {'_id': 'Xavier', 'count': 6}
# {'_id': 'Arcadia', 'count': 6}
# {'_id': 'Gustavo Martinez Zuviria', 'count': 6}
# {'_id': 'Hamilton / Laurinburg Inst.', 'count': 6}
# {'_id': 'Battleground Academy / Linden', 'count': 6}
# {'_id': 'Houston Academy', 'count': 6}
# {'_id': 'East  (DNP) / Carver', 'count': 6}
# {'_id': 'Kentwood', 'count': 6}
# {'_id': 'Long Beach / Hargrave Mil Acad', 'count': 6}
# {'_id': 'North Providence', 'count': 6}
# {'_id': 'Broughton', 'count': 6}
# {'_id': 'Gary Prep / Lew Wallace', 'count': 6}
# {'_id': 'Cave Spring', 'count': 6}
# {'_id': 'Hughes', 'count': 6}
# {'_id': 'Calumet', 'count': 6}
# {'_id': 'Brainerd / Washington', 'count': 6}
# {'_id': 'Barbour County Training School', 'count': 6}
# {'_id': 'Northwest ', 'count': 6}
# {'_id': 'Nederland', 'count': 6}
# {'_id': 'St. James', 'count': 6}
# {'_id': 'East Side', 'count': 6}
# {'_id': 'Friona', 'count': 6}
# {'_id': 'Riley', 'count': 6}
# {'_id': 'West Fulton', 'count': 6}
# {'_id': 'Clinton', 'count': 6}
# {'_id': 'San Dieguito Academy', 'count': 6}
# {'_id': 'Whites Creek', 'count': 6}
# {'_id': 'Horizon', 'count': 6}
# {'_id': 'E. Flora', 'count': 6}
# {'_id': 'Vashon', 'count': 6}
# {'_id': 'Portland', 'count': 6}
# {'_id': 'Newark', 'count': 6}
# {'_id': 'Kensington', 'count': 6}
# {'_id': 'St. Louis University H.S.', 'count': 6}
# {'_id': 'Emmaus', 'count': 6}
# {'_id': 'Aurora West', 'count': 6}
# {'_id': 'Oak Ridge', 'count': 6}
# {'_id': 'Salem Academy', 'count': 6}
# {'_id': 'Fashion Industries', 'count': 6}
# {'_id': 'Bishop DuBourg', 'count': 6}
# {'_id': 'St. Patrick', 'count': 6}
# {'_id': 'Bishop Borgess', 'count': 6}
# {'_id': 'Wilson', 'count': 6}
# {'_id': 'Highland Park / Monrovia', 'count': 6}
# {'_id': 'Ridgeview', 'count': 6}
# {'_id': 'Effingham', 'count': 6}
# {'_id': 'St. Augustine Prep', 'count': 6}
# {'_id': 'Jones', 'count': 6}
# {'_id': 'Phillips-Exeter Academy', 'count': 6}
# {'_id': 'Long Beach Polytech / Dominguez', 'count': 6}
# {'_id': 'Palatine', 'count': 6}
# {'_id': "St. Leo's", 'count': 6}
# {'_id': 'Gans', 'count': 6}
# {'_id': 'Archbishop Spalding', 'count': 6}
# {'_id': 'Kirkpatrick', 'count': 6}
# {'_id': 'Montverde Academy', 'count': 6}
# {'_id': 'Community', 'count': 6}
# {'_id': 'Goodrich', 'count': 6}
# {'_id': 'Taft / Birmingham', 'count': 6}
# {'_id': 'Hanford', 'count': 6}
# {'_id': 'West Warwick', 'count': 6}
# {'_id': 'Penn Hills', 'count': 6}
# {'_id': 'Emerson', 'count': 6}
# {'_id': 'Beaumont', 'count': 6}
# {'_id': 'Puxico', 'count': 6}
# {'_id': '58 Sports School', 'count': 6}
# {'_id': 'Cass', 'count': 6}
# {'_id': 'Miami Christian', 'count': 6}
# {'_id': 'Valparaiso', 'count': 6}
# {'_id': 'South Cache', 'count': 6}
# {'_id': 'E.L. Bowsher', 'count': 6}
# {'_id': 'Littleton', 'count': 6}
# {'_id': 'Meade', 'count': 6}
# {'_id': 'North Lenoir', 'count': 6}
# {'_id': 'Luzerne', 'count': 6}
# {'_id': 'Worcester Academy / Fairfax', 'count': 6}
# {'_id': 'Hillhouse', 'count': 6}
# {'_id': "St. John's", 'count': 6}
# {'_id': 'Richwood/Western', 'count': 6}
# {'_id': 'Hopkinsville', 'count': 6}
# {'_id': 'West ', 'count': 6}
# {'_id': 'Purcell', 'count': 6}
# {'_id': 'Bristow', 'count': 6}
# {'_id': 'St. Agnes', 'count': 6}
# {'_id': 'Upland', 'count': 6}
# {'_id': 'The Episcopal Academy', 'count': 6}
# {'_id': 'Denby', 'count': 5}
# {'_id': 'Eastern District', 'count': 5}
# {'_id': 'Brophy Prep', 'count': 5}
# {'_id': 'A.E. Beach', 'count': 5}
# {'_id': 'West Brunswick', 'count': 5}
# {'_id': 'Daviess Co.', 'count': 5}
# {'_id': 'Township', 'count': 5}
# {'_id': 'Lehman', 'count': 5}
# {'_id': 'Wilbur Wright / Chaminade', 'count': 5}
# {'_id': 'Belle Glade', 'count': 5}
# {'_id': 'Bishop Gorman', 'count': 5}
# {'_id': 'Marshall County', 'count': 5}
# {'_id': 'Star-Spencer', 'count': 5}
# {'_id': 'Casper', 'count': 5}
# {'_id': 'Quincy Senior', 'count': 5}
# {'_id': 'South Haven', 'count': 5}
# {'_id': 'Creswell', 'count': 5}
# {'_id': 'Crocket', 'count': 5}
# {'_id': 'Wichita North', 'count': 5}
# {'_id': 'North Springs', 'count': 5}
# {'_id': 'DeSmet', 'count': 5}
# {'_id': 'Morgan Co. Trng School', 'count': 5}
# {'_id': 'East ', 'count': 5}
# {'_id': 'Elkhart', 'count': 5}
# {'_id': 'Claremont', 'count': 5}
# {'_id': 'Oak Hill Academy / Montrose Christian', 'count': 5}
# {'_id': 'Webb School', 'count': 5}
# {'_id': 'Waterman', 'count': 5}
# ...
# {'_id': 'Colegro Objectivo', 'count': 1}
# {'_id': 'Lorain', 'count': 1}
# {'_id': 'DeSales', 'count': 1}
# {'_id': 'Bryceland', 'count': 1}
# {'_id': 'Portsmouth', 'count': 1}
# {'_id': "Scotch Plains-Fanwood / St. Benedict's  Prep", 'count': 1}
# {'_id': 'Windward School', 'count': 1}
# {'_id': 'Flint Central/Flint Southwestern', 'count': 1}
# {'_id': 'Milwaukee Tech', 'count': 1}
# {'_id': 'Headrick', 'count': 1}
# {'_id': 'Richmond Academy', 'count': 1}
# {'_id': 'Lisbon', 'count': 1}
# {'_id': 'Grossmont', 'count': 1}
# {'_id': 'Beebe', 'count': 1}
# {'_id': 'Paul L. Dunbar', 'count': 1}
# {'_id': 'Appleton', 'count': 1}
# {'_id': 'North ', 'count': 1}
# {'_id': 'West Forsyth / Anderson / Atkins', 'count': 1}
# {'_id': 'Half Hollow Hills West / Long Island Lutheran / Half Hollow',
#  'count': 1}
# {'_id': 'Stadium', 'count': 1}
# {'_id': 'Torrington', 'count': 1}
# {'_id': 'Widefield', 'count': 1}
# {'_id': 'Downey', 'count': 1}
# {'_id': "Christian Brothers Academy / St. John's", 'count': 1}
# {'_id': 'Benedictine Military Academy', 'count': 1}
# {'_id': 'C.W. Hayes', 'count': 1}
# {'_id': 'Belleview', 'count': 1}
# {'_id': 'Benedictine Academy', 'count': 1}
# {'_id': 'Bennettsville', 'count': 1}
# {'_id': 'Bolton', 'count': 1}
# {'_id': 'St. Thomas More', 'count': 1}
# {'_id': 'Flint Central', 'count': 1}
# {'_id': 'Oklahoma City Central', 'count': 1}
# {'_id': 'McIntosh', 'count': 1}
# {'_id': 'Central / Murray-Wright / Cody', 'count': 1}
# {'_id': 'Scottsburgh', 'count': 1}
# {'_id': 'James J. Ferris', 'count': 1}
# {'_id': 'Grove', 'count': 1}
# {'_id': 'Franklin D Roosevelt', 'count': 1}
# {'_id': 'Gallatin Union', 'count': 1}
# {'_id': 'Academy of Holy Angels', 'count': 1}
# {'_id': 'Menasha', 'count': 1}
# {'_id': 'Woodway', 'count': 1}
# {'_id': 'Apache', 'count': 1}
# {'_id': 'Fairdale', 'count': 1}
# {'_id': 'Sandia', 'count': 1}
# {'_id': 'Mill Creek', 'count': 1}
# {'_id': 'Colton', 'count': 1}
# {'_id': 'Jambol', 'count': 1}
# {'_id': "St. Patrick's /Scotch Plains-Fanwood/ Notre Dame Prep", 'count': 1}
# {'_id': 'Rockford East', 'count': 1}
# {'_id': 'Orono', 'count': 1}
# {'_id': 'Pomona', 'count': 1}
# {'_id': 'Trotwood-Madison', 'count': 1}
# {'_id': 'Port Richmond', 'count': 1}
# {'_id': 'Jane Lew', 'count': 1}
# {'_id': 'Wichita East / Hargrave Military Academy', 'count': 1}
# {'_id': 'Eudora', 'count': 1}
# {'_id': 'Wamego', 'count': 1}
# {'_id': 'Tolleson', 'count': 1}
# {'_id': 'Beaver County Day', 'count': 1}
# {'_id': 'Weaver (DNP?)', 'count': 1}
# {'_id': 'Centennial Secondary', 'count': 1}
# {'_id': 'Shaw', 'count': 1}
# {'_id': 'Thornton Fractional', 'count': 1}
# {'_id': 'Fremont-Mills', 'count': 1}
# {'_id': 'Madison/Glen Springs', 'count': 1}
# {'_id': 'Fort Lee', 'count': 1}
# {'_id': 'Sheldon', 'count': 1}
# {'_id': 'Marist', 'count': 1}
# {'_id': 'Engineering&Sciences', 'count': 1}
# {'_id': 'Montclair Kimberley / St, Patricks', 'count': 1}
# {'_id': 'Pulaski County', 'count': 1}
# {'_id': 'Duluth Central', 'count': 1}
# {'_id': 'Stephen F. Palmer', 'count': 1}
# {'_id': 'Santa Margarita Catholic / Stoneridge Prep', 'count': 1}
# {'_id': 'Hargrave Mil. Acad. / Gwynn Park', 'count': 1}
# {'_id': 'Warren County', 'count': 1}
# {'_id': 'Dawson-Boyd', 'count': 1}
# {'_id': 'Eli Whitney/Cooley', 'count': 1}
# {'_id': 'John W. North', 'count': 1}
# {'_id': 'Greens Fork', 'count': 1}
# {'_id': 'Paul Robeson', 'count': 1}
# {'_id': 'Laurinburg Prep /Maine Cent/Lynn Vocl / Lynn English', 'count': 1}
# {'_id': 'West Union', 'count': 1}
# {'_id': 'Paxon', 'count': 1}
# {'_id': 'Washington Irving', 'count': 1}
# {'_id': 'Port Perry', 'count': 1}
# {'_id': 'Ardenne', 'count': 1}
# {'_id': 'Manhattan Prep', 'count': 1}
# {'_id': 'Cape Coral', 'count': 1}
# {'_id': 'Simon Kenton', 'count': 1}
# {'_id': 'New London', 'count': 1}
# {'_id': 'Harper', 'count': 1}
# {'_id': 'Eastern Alamance', 'count': 1}
# {'_id': 'Victor Valley', 'count': 1}
# {'_id': 'Tates Creek', 'count': 1}
# {'_id': 'Keokuk', 'count': 1}
# {'_id': 'Stephen F. Austin', 'count': 1}
# {'_id': 'Palmer', 'count': 1}
# {'_id': 'Spencerport', 'count': 1}
# {'_id': 'Bishop McGuinness', 'count': 1}
# {'_id': 'Converse', 'count': 1}
# {'_id': 'Caverna', 'count': 1}
# {'_id': 'Wellsboro', 'count': 1}
# {'_id': 'Oakland Tech', 'count': 1}
# {'_id': 'Euclid', 'count': 1}
# {'_id': 'First Colonial', 'count': 1}
# {'_id': 'Abbeville', 'count': 1}
# {'_id': 'Stephen Decatur', 'count': 1}
# {'_id': 'Milwaukee Trade & Tech', 'count': 1}
# {'_id': 'Hazel Park', 'count': 1}
# {'_id': 'Nettleton', 'count': 1}
# {'_id': 'Bay City Central', 'count': 1}
# {'_id': 'Pruitt', 'count': 1}
# {'_id': 'Magnolia', 'count': 1}
# {'_id': 'Xaverian Prep', 'count': 1}
# {'_id': 'York Community', 'count': 1}
# {'_id': 'Teaneck ', 'count': 1}
# {'_id': 'Foreman', 'count': 1}
# {'_id': 'Monte Vista / IMG Pendleton School', 'count': 1}
# {'_id': 'Fort Walton Beach', 'count': 1}
# {'_id': 'Menlo School', 'count': 1}
# {'_id': 'Parkland', 'count': 1}
# {'_id': 'Curtis Senior / South Kent Prep', 'count': 1}
# {'_id': 'Edgewater', 'count': 1}
# {'_id': 'Brookline', 'count': 1}
# {'_id': 'John Glenn', 'count': 1}
# {'_id': 'Stephen F. Austin  / Brewster Academy', 'count': 1}
# {'_id': 'Caguas Baptist', 'count': 1}
# {'_id': 'Corning Free Academy', 'count': 1}
# {'_id': 'Wamogo', 'count': 1}
# {'_id': 'St. Aloysius', 'count': 1}
# {'_id': 'Savannah Beach', 'count': 1}
# {'_id': 'Nashville High & Elementary', 'count': 1}
# {'_id': 'West Point', 'count': 1}
# {'_id': 'Spencer-Van Etten', 'count': 1}
# {'_id': 'Our Savior Lutheran / John Jay / Oak Hill', 'count': 1}
# {'_id': 'Estudiantes', 'count': 1}
# {'_id': 'Decatur', 'count': 1}
# {'_id': 'Mooresville', 'count': 1}
# {'_id': 'Miami Christian Academy', 'count': 1}
# {'_id': 'Sam Houston', 'count': 1}
# {'_id': 'Timberline', 'count': 1}
# {'_id': 'KC-Wyandotte', 'count': 1}
# {'_id': 'West Monroe', 'count': 1}
# {'_id': 'Livingston', 'count': 1}
# {'_id': 'Bayfield', 'count': 1}
# {'_id': 'Lakeview', 'count': 1}
# {'_id': 'Kirkwood', 'count': 1}
# {'_id': 'Austin / St. Johns Military Academy', 'count': 1}
# {'_id': 'Strong Vincent', 'count': 1}
# {'_id': 'Kennedy Collegiate', 'count': 1}
# {'_id': 'McLain', 'count': 1}
# {'_id': 'Noshiro Kogyo', 'count': 1}
# {'_id': 'Ovideo', 'count': 1}
# {'_id': 'Mossville', 'count': 1}
# {'_id': 'Robert A. Long', 'count': 1}
# {'_id': 'Gage Park', 'count': 1}
# {'_id': 'Automotive', 'count': 1}
# {'_id': 'Elkins', 'count': 1}
# {'_id': 'McMinnville', 'count': 1}
# {'_id': 'Thornton Fractional Township', 'count': 1}
# {'_id': 'Great Valley', 'count': 1}
# {'_id': 'Branson', 'count': 1}
# {'_id': 'Richardson', 'count': 1}
# {'_id': "St. John's College / Oak Hill Academy", 'count': 1}
# {'_id': 'Peddie Prep / Wayne', 'count': 1}
# {'_id': 'Wendell Phillips', 'count': 1}
# {'_id': 'Zephyr Hills', 'count': 1}
# {'_id': 'Charlevoix', 'count': 1}
# {'_id': 'Beechcroft', 'count': 1}
# {'_id': 'Live Oak', 'count': 1}
# {'_id': 'Mahanoy Township', 'count': 1}
# {'_id': 'Dublin', 'count': 1}
# {'_id': 'Greenwich/Tilden Academy', 'count': 1}
# {'_id': 'South Philadelphia / Brown Prep', 'count': 1}
# {'_id': 'Coon Rapids', 'count': 1}
# {'_id': 'Manley', 'count': 1}
# {'_id': 'Mervo', 'count': 1}
# {'_id': 'Atlantic', 'count': 1}
# {'_id': 'Newton', 'count': 1}
# {'_id': 'Mabelville', 'count': 1}
# {'_id': 'Kiln', 'count': 1}
# {'_id': 'Grandview', 'count': 1}
# {'_id': 'Visalia', 'count': 1}
# {'_id': 'Technology', 'count': 1}
# {'_id': 'Pine Crest', 'count': 1}
# {'_id': 'Morris', 'count': 1}
# {'_id': 'Kelly Miller', 'count': 1}
# {'_id': 'St. Charles West', 'count': 1}
# {'_id': 'Lake Forest', 'count': 1}
# {'_id': 'Benilde', 'count': 1}
# {'_id': 'Swissvale', 'count': 1}
# {'_id': "St. Anthony's / Elizabeth", 'count': 1}
# {'_id': 'Carson', 'count': 1}
# {'_id': 'Flat Gap', 'count': 1}
# {'_id': 'Gymnasium Levice', 'count': 1}
# {'_id': 'Conway', 'count': 1}
# {'_id': 'Lodi', 'count': 1}
# {'_id': 'Beaver Falls', 'count': 1}
# {'_id': 'Corbin / Williamsburgh / Catlettsburg', 'count': 1}
# {'_id': 'Hillcrest / Jordan', 'count': 1}
# {'_id': 'Woodward (played) / Libbey (dnp)', 'count': 1}
# {'_id': 'Washington Township', 'count': 1}
# {'_id': 'Racine Lutheran', 'count': 1}
# {'_id': 'Mountain View', 'count': 1}
# {'_id': 'Southern Durham', 'count': 1}
# {'_id': 'Avon', 'count': 1}
# {'_id': 'Marengo', 'count': 1}
# {'_id': 'Brandywine', 'count': 1}
# {'_id': 'Malta Bend', 'count': 1}
# {'_id': 'Christian Academy', 'count': 1}
# {'_id': 'Natl Christ Acad/Marietta/Holy Inn Epis/Windward', 'count': 1}
# {'_id': 'Clifton Forge', 'count': 1}
# {'_id': 'Dunbar Vocational', 'count': 1}
# {'_id': 'Carl Albert', 'count': 1}
# {'_id': 'St. Gregory', 'count': 1}
# {'_id': 'Ivan Goran Kovacic', 'count': 1}
# {'_id': 'Sylmar', 'count': 1}
# {'_id': '14 Belgrade', 'count': 1}
# {'_id': 'New Castle Senior', 'count': 1}
# {'_id': 'McHenry', 'count': 1}
# {'_id': 'Xenia Central', 'count': 1}
# {'_id': 'Sheboygan Central', 'count': 1}
# {'_id': 'Park River', 'count': 1}
# {'_id': 'Jenkintown', 'count': 1}
# {'_id': 'Eisenhower', 'count': 1}
# {'_id': 'Newman / West Fulton?', 'count': 1}
# {'_id': 'Druid', 'count': 1}
# {'_id': 'Louise Dieruff', 'count': 1}
# {'_id': 'Harrison County', 'count': 1}
# {'_id': 'Clearfield', 'count': 1}
# {'_id': 'Spruce', 'count': 1}
# {'_id': 'Oak Park and River Forest', 'count': 1}
# {'_id': 'Gibbs', 'count': 1}
# {'_id': 'Ridgeway', 'count': 1}
# {'_id': 'Naples', 'count': 1}
# {'_id': 'Langhorne', 'count': 1}
# {'_id': 'La Mirada', 'count': 1}
# {'_id': 'Senn (DNP)', 'count': 1}
# {'_id': 'Marquette Prep', 'count': 1}
# {'_id': 'Portsmouth / Worcester Academy', 'count': 1}
# {'_id': 'Connellsville', 'count': 1}
# {'_id': 'Trott Vocational', 'count': 1}
# {'_id': 'Coraopolis', 'count': 1}
# {'_id': 'Msgr. McClancy', 'count': 1}
# {'_id': 'Richard Montgomery', 'count': 1}
# {'_id': 'Bishop Mose Davis', 'count': 1}
# {'_id': 'Elder', 'count': 1}
# {'_id': 'Davis', 'count': 1}
# {'_id': 'Longview (DNP)', 'count': 1}
# {'_id': 'Powell', 'count': 1}
# {'_id': 'Maryville', 'count': 1}
# {'_id': 'Elston', 'count': 1}
# {'_id': 'Union Valley', 'count': 1}
# {'_id': 'Oak Park', 'count': 1}
# {'_id': 'Central Park Christian School / Shaw', 'count': 1}
# {'_id': 'Hoquiam', 'count': 1}
# {'_id': 'Wellsville / Irondale / Raccoon Township', 'count': 1}
# {'_id': 'Hoke City', 'count': 1}
# {'_id': 'Smith-Cotton', 'count': 1}
# {'_id': 'Martin', 'count': 1}
# {'_id': 'Highland / Bishop Gorman', 'count': 1}
# {'_id': 'Solon', 'count': 1}
# {'_id': 'New Haven', 'count': 1}
# {'_id': 'Colonel White', 'count': 1}
# {'_id': 'DeWitt Clinton / Laurinburg Institute', 'count': 1}
# {'_id': 'East Hampton', 'count': 1}
# {'_id': 'Randolph', 'count': 1}
# {'_id': 'Luxora', 'count': 1}
# {'_id': 'South Grand Prairie', 'count': 1}
# {'_id': 'Lincoln Park', 'count': 1}
# {'_id': 'West Wyoming', 'count': 1}
# {'_id': 'Santa Margarita Catholic', 'count': 1}
# {'_id': 'Randallstown', 'count': 1}
# {'_id': 'Wesleyan / Oak Hill Academy', 'count': 1}
# {'_id': 'Slayton', 'count': 1}
# {'_id': 'Textile', 'count': 1}
# {'_id': 'Bishop McDevitt', 'count': 1}
# {'_id': 'Fosdick-Masten', 'count': 1}
# {'_id': 'David B. Oliver', 'count': 1}
# {'_id': 'Huntsville', 'count': 1}
# {'_id': 'Moreno Valley', 'count': 1}
# {'_id': 'Imo State Secondary', 'count': 1}
# {'_id': 'Santa Fe', 'count': 1}
# {'_id': 'Barnesville', 'count': 1}
# {'_id': 'Allegheny', 'count': 1}
# {'_id': 'Jamaica College / Florida Air Academy', 'count': 1}
# {'_id': 'Glens Falls', 'count': 1}
# {'_id': 'U.S. Grant', 'count': 1}
# {'_id': 'Braham', 'count': 1}
# {'_id': 'Kathleen', 'count': 1}
# {'_id': 'Pedro Albizu', 'count': 1}
# {'_id': 'St. Casimir', 'count': 1}
# {'_id': 'Whitehouse', 'count': 1}
# {'_id': 'Mayde Creek', 'count': 1}
# {'_id': 'Armstrong', 'count': 1}
# {'_id': 'Lansdowne-Alden', 'count': 1}
# {'_id': 'St. Stephen', 'count': 1}
# {'_id': 'Escambia', 'count': 1}
# {'_id': 'New Market', 'count': 1}
# {'_id': 'Pickering / Findlay College Prep', 'count': 1}
# {'_id': 'Boys Tech', 'count': 1}
# {'_id': 'Halstead', 'count': 1}
# {'_id': 'Fulda', 'count': 1}
# {'_id': 'Bland', 'count': 1}
# {'_id': 'Oakridge', 'count': 1}
# {'_id': 'Gordon McGregor', 'count': 1}
# {'_id': 'Boylan Central Catholic', 'count': 1}
# {'_id': 'Fort Cobb', 'count': 1}
# {'_id': 'Halifax County', 'count': 1}
# {'_id': 'Findley Prep', 'count': 1}
# {'_id': 'Edison / Westwind Academy', 'count': 1}
# {'_id': 'Salinas', 'count': 1}
# {'_id': 'Wheeling Central', 'count': 1}
# {'_id': 'Dickinson / NY Military Academy', 'count': 1}
# {'_id': 'Winston Churchill / Proctor Academy', 'count': 1}
# {'_id': 'St. Martin de Porres', 'count': 1}
# {'_id': 'Sumas-Nooksack', 'count': 1}
# {'_id': 'Gov. Dummer', 'count': 1}
# {'_id': 'Piedmont Hills', 'count': 1}
# {'_id': 'Lillis', 'count': 1}
# {'_id': 'Kingsland', 'count': 1}
# {'_id': 'Poughkeepsie / St. Thomas More', 'count': 1}
# {'_id': 'Thayer', 'count': 1}
# {'_id': 'Batavia / Carlisle', 'count': 1}
# {'_id': 'Karns', 'count': 1}
# {'_id': 'Lake Howell', 'count': 1}
# {'_id': 'Piscataway', 'count': 1}
# {'_id': 'Capitol ', 'count': 1}
# {'_id': 'Muncie Centrral', 'count': 1}
# {'_id': 'Miller / Northeastern', 'count': 1}
# {'_id': 'Western/AliefHstg/GulfShrs/CalvBapChr/DecaturChr', 'count': 1}
# {'_id': 'LaSalle-Peru', 'count': 1}
# {'_id': 'H.A. Hunt', 'count': 1}
# {'_id': "Ste. Marguerite d'Youville / St. Benedict's Prep / Findlay Prep",
#  'count': 1}
# {'_id': 'Anderson County', 'count': 1}
# {'_id': 'Libby/Scott?', 'count': 1}
# {'_id': 'Bassick', 'count': 1}
# {'_id': 'Passaic County Tech', 'count': 1}
# {'_id': 'Tucker', 'count': 1}
# {'_id': 'Carl Hayden', 'count': 1}
# {'_id': 'Okota Grammar School', 'count': 1}
# {'_id': 'Highlands', 'count': 1}
# {'_id': 'Lovejoy', 'count': 1}
# {'_id': 'St. Josephs', 'count': 1}
# {'_id': 'Edward W. Bok Technical', 'count': 1}
# {'_id': 'Knoxville City', 'count': 1}
# {'_id': 'Philadelphia Engineering & Science', 'count': 1}
# {'_id': 'Harbor', 'count': 1}
# {'_id': 'Cacak', 'count': 1}
# {'_id': 'Tomball', 'count': 1}
# {'_id': 'John Carroll', 'count': 1}
# {'_id': 'Marion Abramson', 'count': 1}
# {'_id': 'Enloe / Bonner Academy', 'count': 1}
# {'_id': 'Ottawa Hills', 'count': 1}
# {'_id': 'Ann Arbor', 'count': 1}
# {'_id': 'Beaverton', 'count': 1}
# {'_id': 'Wheat Ridge', 'count': 1}
# {'_id': 'Penn Charter / Germantown Academy', 'count': 1}
# {'_id': 'West Covina', 'count': 1}
# {'_id': 'Alan B. Shepard', 'count': 1}
# {'_id': 'Rainey', 'count': 1}
# {'_id': 'Ashland', 'count': 1}
# {'_id': 'Northrup', 'count': 1}
# {'_id': 'Lima', 'count': 1}
# {'_id': 'English', 'count': 1}
# {'_id': 'Frederick', 'count': 1}
# {'_id': 'Norcom / Hargrave Military Academy', 'count': 1}
# {'_id': 'Palatine Township', 'count': 1}
# {'_id': 'Our Savior Lutheran', 'count': 1}
# {'_id': 'Brainerd', 'count': 1}
# {'_id': 'Carver / Lanier / LaJolla', 'count': 1}
# {'_id': 'Newburgh Free Academy', 'count': 1}
# {'_id': 'Stone Mountain', 'count': 1}
# {'_id': 'Alvarado', 'count': 1}
# {'_id': 'Fulton', 'count': 1}
# {'_id': 'Waite', 'count': 1}
# {'_id': 'Westside ', 'count': 1}
# {'_id': 'Winton Woods', 'count': 1}
# {'_id': 'Valders', 'count': 1}
# {'_id': 'Eastmoor / Whitehall', 'count': 1}
# {'_id': 'Elberfeld', 'count': 1}
# {'_id': 'Haaren', 'count': 1}
# {'_id': 'Abbotsford', 'count': 1}
# {'_id': 'Central ', 'count': 1}
# {'_id': 'Roxborough', 'count': 1}
# {'_id': 'Somerset', 'count': 1}
# {'_id': 'A.F. Adderly', 'count': 1}
# {'_id': 'Bishop Laughlin', 'count': 1}
# {'_id': 'Roanoke', 'count': 1}
# {'_id': 'Dansville', 'count': 1}
# {'_id': 'Yakima', 'count': 1}
# {'_id': 'Wathena', 'count': 1}
# {'_id': 'Novi Sad', 'count': 1}
# {'_id': 'Country Day', 'count': 1}
# {'_id': 'St. Christopher Episcopal Prep', 'count': 1}
# {'_id': 'Roger Bacon/Xavier', 'count': 1}
# {'_id': 'Hancock', 'count': 1}
# {'_id': 'Olmstead', 'count': 1}
# {'_id': 'Archbishop Shaw', 'count': 1}
# {'_id': 'North Mecklenburg', 'count': 1}
# {'_id': 'Rockville Centre', 'count': 1}
# {'_id': 'Hutchinson Central Technical', 'count': 1}
# {'_id': 'DeQuincy', 'count': 1}
# {'_id': 'Pahokee', 'count': 1}
# {'_id': 'Postville', 'count': 1}
# {'_id': 'Sylvan', 'count': 1}
# {'_id': 'Sandy Hook', 'count': 1}
# {'_id': 'Canonsburg', 'count': 1}
# {'_id': 'Weber County', 'count': 1}
# {'_id': 'Happy Valley', 'count': 1}
# {'_id': 'Stratford', 'count': 1}
# {'_id': 'Dean Academy', 'count': 1}
# {'_id': 'Fairmont Heights', 'count': 1}
# {'_id': 'Fort Worth Tech', 'count': 1}
# {'_id': 'Grand Rapids', 'count': 1}
# {'_id': 'Albany', 'count': 1}
# {'_id': 'Meadowbrook', 'count': 1}
# {'_id': 'St. Charles', 'count': 1}
# {'_id': 'Cherokee / Dunwoody', 'count': 1}
# {'_id': 'David Prouty', 'count': 1}
# {'_id': 'Don Bosco Tech', 'count': 1}

# %% [markdown]
# ## query 2

# %%
cursor = db.collection_players_teams.aggregate([
        {"$group":{"_id":{"firstName":"$playerID.firstName","lastname":"$playerID.lastName"},"points":{"$sum":"$points"}}},
        {"$project":{"_id":1,"points":1}},
        {"$sort":{"points":-1}},
        {"$limit": 10}
        ])
    
for i in cursor:
    pprint(i)
# Out:
# {'_id': {'firstName': 'Kareem', 'lastname': 'Abdul-Jabbar'}, 'points': 38387}
# {'_id': {'firstName': 'Karl', 'lastname': 'Malone'}, 'points': 36928}
# {'_id': {'firstName': 'Michael', 'lastname': 'Jordan'}, 'points': 32292}
# {'_id': {'firstName': 'Wilton', 'lastname': 'Chamberlain'}, 'points': 31419}
# {'_id': {'firstName': 'Clifford', 'lastname': 'Robinson'}, 'points': 30414}
# {'_id': {'firstName': 'Julius', 'lastname': 'Erving'}, 'points': 30026}
# {'_id': {'firstName': 'Moses', 'lastname': 'Malone'}, 'points': 29580}
# {'_id': {'firstName': 'Kobe', 'lastname': 'Bryant'}, 'points': 29484}
# {'_id': {'firstName': 'Edward', 'lastname': 'Johnson'}, 'points': 29365}
# {'_id': {'firstName': 'Shaquille', 'lastname': "O'Neal"}, 'points': 28596}

# %%
temp = db.collection_players_teams.aggregate([
        {"$group":{"_id":{"firstName":"$playerID.firstName","lastname":"$playerID.lastName"},"points":{"$sum":"$points"}}},
        {"$project":{"_id":1,"points":1}},
        {"$sort":{"points":-1}},
        {"$limit": 10}
        ])
    
for i in cursor:
    pprint(i)

# %% [markdown]
# ## Query 4

# %%
temp = db.collection_player_all_star.aggregate([
        {"$group":{"_id":"$playerID._id"}},
        {"$project":{"_id":1}},
        ])


listName = []
for i in temp:
    listName.append(i["_id"])
    
cursor = db.collection_players_teams.aggregate([
        {"$match":{"playerID._id":{"$nin": listName}}},
        {"$group":{"_id":{"id": "$playerID._id","firstName":"$playerID.firstName","lastname":"$playerID.lastName"},"points":{"$sum":"$points"}}},
        {"$project":{"_id":1,"points":1}},
        {"$sort":{"points":-1}},
        {"$limit": 10}
        ])

for i in cursor:
    pprint(i)
# Out:
# {'_id': {'firstName': 'Edward', 'id': 'johnsed03', 'lastname': 'Johnson'},
#  'points': 19202}
# {'_id': {'firstName': 'Kevin', 'id': 'willike02', 'lastname': 'Willis'},
#  'points': 17253}
# {'_id': {'firstName': 'Jason', 'id': 'terryja01', 'lastname': 'Terry'},
#  'points': 16487}
# {'_id': {'firstName': 'Derek', 'id': 'harpede01', 'lastname': 'Harper'},
#  'points': 16006}
# {'_id': {'firstName': 'Samuel', 'id': 'perkisa01', 'lastname': 'Perkins'},
#  'points': 15324}
# {'_id': {'firstName': 'Antoine', 'id': 'walkean02', 'lastname': 'Walker'},
#  'points': 15279}
# {'_id': {'firstName': 'Byron', 'id': 'scottby01', 'lastname': 'Scott'},
#  'points': 15097}
# {'_id': {'firstName': 'Rashard', 'id': 'lewisra02', 'lastname': 'Lewis'},
#  'points': 15026}
# {'_id': {'firstName': 'James', 'id': 'edwarja01', 'lastname': 'Edwards'},
#  'points': 14862}
# {'_id': {'firstName': 'Andre', 'id': 'millean02', 'lastname': 'Miller'},
#  'points': 14710}
# {'_id': {'firstName': 'Michael', 'id': 'bibbymi01', 'lastname': 'Bibby'},
#  'points': 14698}
# {'_id': {'firstName': 'Purvis', 'id': 'shortpu01', 'lastname': 'Short'},
#  'points': 14607}
# {'_id': {'firstName': 'Rodney', 'id': 'stricro02', 'lastname': 'Strickland'},
#  'points': 14463}
# {'_id': {'firstName': 'Jason', 'id': 'richaja01', 'lastname': 'Richardson'},
#  'points': 14125}
# {'_id': {'firstName': 'Eddie', 'id': 'jonesed02', 'lastname': 'Jones'},
#  'points': 13979}
# {'_id': {'firstName': 'Ronald', 'id': 'harpero01', 'lastname': 'Harper'},
#  'points': 13910}
# {'_id': {'firstName': 'Chuck', 'id': 'persoch01', 'lastname': 'Person'},
#  'points': 13858}
# {'_id': {'firstName': 'Orlando', 'id': 'woolror01', 'lastname': 'Woolridge'},
#  'points': 13623}
# {'_id': {'firstName': 'Jalen', 'id': 'roseja01', 'lastname': 'Rose'},
#  'points': 13220}
# {'_id': {'firstName': 'Kevin', 'id': 'johnske02', 'lastname': 'Johnson'},
#  'points': 13127}
# {'_id': {'firstName': 'Corey', 'id': 'maggeco01', 'lastname': 'Maggette'},
#  'points': 13103}
# {'_id': {'firstName': 'Albert', 'id': 'harrial01', 'lastname': 'Harrington'},
#  'points': 12961}
# {'_id': {'firstName': 'Kendall', 'id': 'gillke01', 'lastname': 'Gill'},
#  'points': 12914}
# {'_id': {'firstName': 'Wayman', 'id': 'tisdawa01', 'lastname': 'Tisdale'},
#  'points': 12878}
# {'_id': {'firstName': 'Mychal', 'id': 'thompmy01', 'lastname': 'Thompson'},
#  'points': 12810}
# {'_id': {'firstName': 'Wallace', 'id': 'johnsmi01', 'lastname': 'Johnson'},
#  'points': 12748}
# {'_id': {'firstName': 'John', 'id': 'newmajo01', 'lastname': 'Newman'},
#  'points': 12740}
# {'_id': {'firstName': 'Armen', 'id': 'gilliar01', 'lastname': 'Gilliam'},
#  'points': 12700}
# {'_id': {'firstName': 'James', 'id': 'jacksji01', 'lastname': 'Jackson'},
#  'points': 12690}
# {'_id': {'firstName': 'Wardell', 'id': 'curryde01', 'lastname': 'Curry'},
#  'points': 12670}
# {'_id': {'firstName': 'Stephen', 'id': 'jacksst02', 'lastname': 'Jackson'},
#  'points': 12620}
# {'_id': {'firstName': 'Richard', 'id': 'jefferi01', 'lastname': 'Jefferson'},
#  'points': 12577}
# {'_id': {'firstName': 'Michael', 'id': 'newlimi01', 'lastname': 'Newlin'},
#  'points': 12507}
# {'_id': {'firstName': 'Lamar', 'id': 'odomla01', 'lastname': 'Odom'},
#  'points': 12451}
# {'_id': {'firstName': 'Aaron', 'id': 'crawfja01', 'lastname': 'Crawford'},
#  'points': 12409}
# {'_id': {'firstName': 'Darrell', 'id': 'griffda01', 'lastname': 'Griffith'},
#  'points': 12391}
# {'_id': {'firstName': 'John', 'id': 'longjo01', 'lastname': 'Long'},
#  'points': 12131}
# {'_id': {'firstName': 'Frederick', 'id': 'lewisfr02', 'lastname': 'Lewis'},
#  'points': 12033}
# {'_id': {'firstName': 'Cuttino', 'id': 'moblecu01', 'lastname': 'Mobley'},
#  'points': 11964}
# {'_id': {'firstName': 'Herbert', 'id': 'willihe01', 'lastname': 'Williams'},
#  'points': 11944}
# {'_id': {'firstName': 'David', 'id': 'wesleda01', 'lastname': 'Wesley'},
#  'points': 11842}
# {'_id': {'firstName': 'Thurl', 'id': 'baileth01', 'lastname': 'Bailey'},
#  'points': 11834}
# {'_id': {'firstName': 'Jerome', 'id': 'kerseje01', 'lastname': 'Kersey'},
#  'points': 11825}
# {'_id': {'firstName': 'Vincent', 'id': 'johnsvi01', 'lastname': 'Johnson'},
#  'points': 11825}
# {'_id': {'firstName': 'Damon', 'id': 'stoudda01', 'lastname': 'Stoudamire'},
#  'points': 11763}
# {'_id': {'firstName': 'Richard', 'id': 'snydedi01', 'lastname': 'Snyder'},
#  'points': 11755}
# {'_id': {'firstName': 'Gerald', 'id': 'wilkige01', 'lastname': 'Wilkins'},
#  'points': 11736}
# {'_id': {'firstName': 'John', 'id': 'scottra01', 'lastname': 'Scott'},
#  'points': 11629}
# {'_id': {'firstName': 'Kevin', 'id': 'loughke01', 'lastname': 'Loughery'},
#  'points': 11575}
# {'_id': {'firstName': 'Nelison', 'id': 'anderni01', 'lastname': 'Anderson'},
#  'points': 11529}
# {'_id': {'firstName': 'Ulysses', 'id': 'bridgju01', 'lastname': 'Bridgeman'},
#  'points': 11517}
# {'_id': {'firstName': 'Harold', 'id': 'hairsha01', 'lastname': 'Hairston'},
#  'points': 11505}
# {'_id': {'firstName': 'Larry', 'id': 'johnsla02', 'lastname': 'Johnson'},
#  'points': 11450}
# {'_id': {'firstName': 'Joseph', 'id': 'smithjo02', 'lastname': 'Smith'},
#  'points': 11203}
# {'_id': {'firstName': 'James', 'id': 'paxsoji02', 'lastname': 'Paxson'},
#  'points': 11199}
# {'_id': {'firstName': 'Michael', 'id': 'woodsmi01', 'lastname': 'Woodson'},
#  'points': 10981}
# {'_id': {'firstName': 'Michael', 'id': 'gminsmi01', 'lastname': 'Gminski'},
#  'points': 10953}
# {'_id': {'firstName': 'Vernon', 'id': 'maxweve01', 'lastname': 'Maxwell'},
#  'points': 10912}
# {'_id': {'firstName': 'Ricky', 'id': 'soberri01', 'lastname': 'Sobers'},
#  'points': 10902}
# {'_id': {'firstName': 'Donald', 'id': 'nelsodo01', 'lastname': 'Nelson'},
#  'points': 10898}
# {'_id': {'firstName': 'Robert', 'id': 'smithbi02', 'lastname': 'Smith'},
#  'points': 10882}
# {'_id': {'firstName': 'Clifford', 'id': 'robincl01', 'lastname': 'Robinson'},
#  'points': 10823}
# {'_id': {'firstName': 'Elden', 'id': 'campbel01', 'lastname': 'Campbell'},
#  'points': 10805}
# {'_id': {'firstName': 'Donyell', 'id': 'marshdo01', 'lastname': 'Marshall'},
#  'points': 10716}
# {'_id': {'firstName': 'Hidayet', 'id': 'turkohe01', 'lastname': 'Turkoglu'},
#  'points': 10643}
# {'_id': {'firstName': 'David', 'id': 'robisda01', 'lastname': 'Robisch'},
#  'points': 10581}
# {'_id': {'firstName': 'Stewart', 'id': 'johnsst01', 'lastname': 'Johnson'},
#  'points': 10538}
# {'_id': {'firstName': 'Clarence',
#          'id': 'weathcl01',
#          'lastname': 'Weatherspoon'},
#  'points': 10483}
# {'_id': {'firstName': 'Cedric', 'id': 'maxwece01', 'lastname': 'Maxwell'},
#  'points': 10465}
# {'_id': {'firstName': 'Robert', 'id': 'reidro01', 'lastname': 'Reid'},
#  'points': 10448}
# {'_id': {'firstName': 'Derrick', 'id': 'mckeyde01', 'lastname': 'McKey'},
#  'points': 10266}
# {'_id': {'firstName': 'Larry', 'id': 'hughela01', 'lastname': 'Hughes'},
#  'points': 10242}
# {'_id': {'firstName': 'Leroy', 'id': 'ellisle01', 'lastname': 'Ellis'},
#  'points': 10176}
# {'_id': {'firstName': 'Thomas', 'id': 'willira01', 'lastname': 'Williams'},
#  'points': 10158}
# {'_id': {'firstName': 'Vern', 'id': 'flemive01', 'lastname': 'Fleming'},
#  'points': 10125}
# {'_id': {'firstName': 'Derek', 'id': 'fishede01', 'lastname': 'Fisher'},
#  'points': 10113}
# {'_id': {'firstName': 'Rony', 'id': 'seikaro01', 'lastname': 'Seikaly'},
#  'points': 9991}
# {'_id': {'firstName': 'Gregory', 'id': 'ballagr01', 'lastname': 'Ballard'},
#  'points': 9953}
# {'_id': {'firstName': 'John', 'id': 'lucasjo01', 'lastname': 'Lucas'},
#  'points': 9953}
# {'_id': {'firstName': 'Michael', 'id': 'millemi01', 'lastname': 'Miller'},
#  'points': 9913}
# {'_id': {'firstName': 'Tyree', 'id': 'davisri01', 'lastname': 'Davis'},
#  'points': 9912}
# {'_id': {'firstName': 'Thomas', 'id': 'owensto01', 'lastname': 'Owens'},
#  'points': 9898}
# {'_id': {'firstName': 'Collier', 'id': 'brownpj01', 'lastname': 'Brown'},
#  'points': 9870}
# {'_id': {'firstName': 'James', 'id': 'choneji01', 'lastname': 'Chones'},
#  'points': 9821}
# {'_id': {'firstName': 'Toni', 'id': 'kukocto01', 'lastname': 'Kukoc'},
#  'points': 9810}
# {'_id': {'firstName': 'Benjamin', 'id': 'gordobe01', 'lastname': 'Gordon'},
#  'points': 9796}
# {'_id': {'firstName': 'John', 'id': 'williho01', 'lastname': 'Williams'},
#  'points': 9784}
# {'_id': {'firstName': 'Tyrone', 'id': 'corbity01', 'lastname': 'Corbin'},
#  'points': 9766}
# {'_id': {'firstName': 'Rex', 'id': 'chapmre01', 'lastname': 'Chapman'},
#  'points': 9731}
# {'_id': {'firstName': 'Johnny', 'id': 'davisjo01', 'lastname': 'Davis'},
#  'points': 9710}
# {'_id': {'firstName': 'Grant', 'id': 'longgr01', 'lastname': 'Long'},
#  'points': 9518}
# {'_id': {'firstName': 'Joseph', 'id': 'grabojo01', 'lastname': 'Graboski'},
#  'points': 9503}
# {'_id': {'firstName': 'Rodney', 'id': 'rogerro01', 'lastname': 'Rogers'},
#  'points': 9468}
# {'_id': {'firstName': 'Timothy', 'id': 'thomati01', 'lastname': 'Thomas'},
#  'points': 9454}
# {'_id': {'firstName': 'Andre', 'id': 'iguodan01', 'lastname': 'Iguodala'},
#  'points': 9422}
# {'_id': {'firstName': 'Lucius', 'id': 'allenlu01', 'lastname': 'Allen'},
#  'points': 9407}
# {'_id': {'firstName': 'Isaiah', 'id': 'rideris01', 'lastname': 'Rider'},
#  'points': 9405}
# {'_id': {'firstName': 'Kenneth', 'id': 'smithke01', 'lastname': 'Smith'},
#  'points': 9397}
# {'_id': {'firstName': 'Sedale', 'id': 'threase01', 'lastname': 'Threatt'},
#  'points': 9327}
# {'_id': {'firstName': 'Tayshaun', 'id': 'princta01', 'lastname': 'Prince'},
#  'points': 9311}
# {'_id': {'firstName': 'Douglas', 'id': 'chrisdo01', 'lastname': 'Christie'},
#  'points': 9301}
# {'_id': {'firstName': 'Frederick', 'id': 'cartefr01', 'lastname': 'Carter'},
#  'points': 9271}
# {'_id': {'firstName': 'Lenard', 'id': 'benjabe01', 'lastname': 'Benjamin'},
#  'points': 9223}
# {'_id': {'firstName': 'Marcus', 'id': 'cambyma01', 'lastname': 'Camby'},
#  'points': 9222}
# {'_id': {'firstName': 'Keith', 'id': 'vanhoke01', 'lastname': 'Van Horn'},
#  'points': 9206}
# {'_id': {'firstName': 'Walter', 'id': 'szczewa02', 'lastname': 'Szczerbiak'},
#  'points': 9189}
# {'_id': {'firstName': 'Antoine', 'id': 'carran01', 'lastname': 'Carr'},
#  'points': 9176}
# {'_id': {'firstName': 'Corliss', 'id': 'willico02', 'lastname': 'Williamson'},
#  'points': 9147}
# {'_id': {'firstName': 'Mahdi', 'id': 'abdulma01', 'lastname': 'Abdul-Rahman'},
#  'points': 9087}
# {'_id': {'firstName': 'Joshua', 'id': 'smithjo03', 'lastname': 'Smith'},
#  'points': 9044}
# {'_id': {'firstName': 'John', 'id': 'willijo01', 'lastname': 'Williamson'},
#  'points': 9017}
# {'_id': {'firstName': 'Rodney', 'id': 'mccraro01', 'lastname': 'McCray'},
#  'points': 9014}
# {'_id': {'firstName': 'Ulrich', 'id': 'foxri01', 'lastname': 'Fox'},
#  'points': 8966}
# {'_id': {'firstName': 'Mark', 'id': 'olberma01', 'lastname': 'Olberding'},
#  'points': 8940}
# {'_id': {'firstName': 'Al', 'id': 'jeffeal01', 'lastname': 'Jefferson'},
#  'points': 8927}
# {'_id': {'firstName': 'Kurt', 'id': 'thomaku01', 'lastname': 'Thomas'},
#  'points': 8876}
# {'_id': {'firstName': 'Terry', 'id': 'tylerte01', 'lastname': 'Tyler'},
#  'points': 8868}
# {'_id': {'firstName': 'Avery', 'id': 'johnsav01', 'lastname': 'Johnson'},
#  'points': 8817}
# {'_id': {'firstName': 'Daniel', 'id': 'schayda01', 'lastname': 'Schayes'},
#  'points': 8780}
# {'_id': {'firstName': 'John', 'id': 'humphja01', 'lastname': 'Humphries'},
#  'points': 8772}
# {'_id': {'firstName': 'Thomas', 'id': 'sandeto01', 'lastname': 'Sanders'},
#  'points': 8766}
# {'_id': {'firstName': 'Clem', 'id': 'haskicl01', 'lastname': 'Haskins'},
#  'points': 8743}
# {'_id': {'firstName': 'James', 'id': 'mcmilji01', 'lastname': 'McMillian'},
#  'points': 8736}
# {'_id': {'firstName': 'Darryl', 'id': 'dawkida01', 'lastname': 'Dawkins'},
#  'points': 8733}
# {'_id': {'firstName': 'Jay', 'id': 'vinceja01', 'lastname': 'Vincent'},
#  'points': 8729}
# {'_id': {'firstName': 'Kevin', 'id': 'martike02', 'lastname': 'Martin'},
#  'points': 8728}
# {'_id': {'firstName': 'Kenneth', 'id': 'normake01', 'lastname': 'Norman'},
#  'points': 8717}
# {'_id': {'firstName': 'Samuel', 'id': 'mitchsa01', 'lastname': 'Mitchell'},
#  'points': 8636}
# {'_id': {'firstName': 'Luol', 'id': 'denglu01', 'lastname': 'Deng'},
#  'points': 8609}
# {'_id': {'firstName': 'Michael', 'id': 'bantomi01', 'lastname': 'Bantom'},
#  'points': 8568}
# {'_id': {'firstName': 'Mahmoud', 'id': 'abdulma02', 'lastname': 'Abdul-Rauf'},
#  'points': 8553}
# {'_id': {'firstName': 'James', 'id': 'barneji02', 'lastname': 'Barnett'},
#  'points': 8536}
# {'_id': {'firstName': 'Reggie', 'id': 'willire01', 'lastname': 'Williams'},
#  'points': 8520}
# {'_id': {'firstName': 'Brent', 'id': 'barrybr01', 'lastname': 'Barry'},
#  'points': 8488}
# {'_id': {'firstName': 'Wilbert', 'id': 'joneswi02', 'lastname': 'Jones'},
#  'points': 8484}
# {'_id': {'firstName': 'Monta', 'id': 'ellismo01', 'lastname': 'Ellis'},
#  'points': 8457}
# {'_id': {'firstName': 'David', 'id': 'greenda01', 'lastname': 'Greenwood'},
#  'points': 8428}
# {'_id': {'firstName': 'Sherman', 'id': 'douglsh01', 'lastname': 'Douglas'},
#  'points': 8425}
# {'_id': {'firstName': 'Walter', 'id': 'williwa02', 'lastname': 'Williams'},
#  'points': 8385}
# {'_id': {'firstName': 'Frank', 'id': 'ramsefr01', 'lastname': 'Ramsey'},
#  'points': 8378}
# {'_id': {'firstName': 'Lamond', 'id': 'murrala01', 'lastname': 'Murray'},
#  'points': 8286}
# {'_id': {'firstName': 'Michael', 'id': 'cagemi01', 'lastname': 'Cage'},
#  'points': 8278}
# {'_id': {'firstName': 'Jason', 'id': 'willija02', 'lastname': 'Williams'},
#  'points': 8266}
# {'_id': {'firstName': 'Olden', 'id': 'polynol01', 'lastname': 'Polynice'},
#  'points': 8265}
# {'_id': {'firstName': 'Michael', 'id': 'dunlemi02', 'lastname': 'Dunleavy'},
#  'points': 8242}
# {'_id': {'firstName': 'Wesley', 'id': 'persowe01', 'lastname': 'Person'},
#  'points': 8192}
# {'_id': {'firstName': 'Christopher', 'id': 'morrich01', 'lastname': 'Morris'},
#  'points': 8184}
# {'_id': {'firstName': 'James', 'id': 'washiji01', 'lastname': 'Washington'},
#  'points': 8168}
# {'_id': {'firstName': 'Larry', 'id': 'drewla01', 'lastname': 'Drew'},
#  'points': 8110}
# {'_id': {'firstName': 'Charles', 'id': 'smithch01', 'lastname': 'Smith'},
#  'points': 8107}
# {'_id': {'firstName': 'Dennis', 'id': 'scottde01', 'lastname': 'Scott'},
#  'points': 8094}
# {'_id': {'firstName': 'Anthony', 'id': 'webbsp01', 'lastname': 'Webb'},
#  'points': 8072}
# {'_id': {'firstName': 'Andrew', 'id': 'goodedr01', 'lastname': 'Gooden'},
#  'points': 8059}
# {'_id': {'firstName': 'Quentin', 'id': 'richaqu01', 'lastname': 'Richardson'},
#  'points': 8027}
# {'_id': {'firstName': 'Anthony', 'id': 'peelean01', 'lastname': 'Peeler'},
#  'points': 8017}
# {'_id': {'firstName': 'Anthony', 'id': 'campbto01', 'lastname': 'Campbell'},
#  'points': 7994}
# {'_id': {'firstName': 'Stacey', 'id': 'augmost01', 'lastname': 'Augmon'},
#  'points': 7990}
# {'_id': {'firstName': 'Terry', 'id': 'teaglte01', 'lastname': 'Teagle'},
#  'points': 7982}
# {'_id': {'firstName': 'Lindsey', 'id': 'hunteli01', 'lastname': 'Hunter'},
#  'points': 7956}
# {'_id': {'firstName': 'Kirk', 'id': 'hinriki01', 'lastname': 'Hinrich'},
#  'points': 7956}
# {'_id': {'firstName': 'Brian', 'id': 'grantbr01', 'lastname': 'Grant'},
#  'points': 7933}
# {'_id': {'firstName': 'Conrad', 'id': 'dierkco01', 'lastname': 'Dierking'},
#  'points': 7915}
# {'_id': {'firstName': 'Bradley', 'id': 'davisbr01', 'lastname': 'Davis'},
#  'points': 7866}
# {'_id': {'firstName': 'Rudy', 'id': 'gayru01', 'lastname': 'Gay'},
#  'points': 7839}
# {'_id': {'firstName': 'Calbert', 'id': 'cheanca01', 'lastname': 'Cheaney'},
#  'points': 7826}
# {'_id': {'firstName': 'Kenneth', 'id': 'carrke01', 'lastname': 'Carr'},
#  'points': 7813}
# {'_id': {'firstName': 'LaSalle', 'id': 'thompla01', 'lastname': 'Thompson'},
#  'points': 7806}
# {'_id': {'firstName': 'Troy', 'id': 'murphtr01', 'lastname': 'Murphy'},
#  'points': 7792}
# {'_id': {'firstName': 'Harvey', 'id': 'grantha01', 'lastname': 'Grant'},
#  'points': 7781}
# {'_id': {'firstName': 'Artis', 'id': 'coopewa01', 'lastname': 'Cooper'},
#  'points': 7777}
# {'_id': {'firstName': 'Jerome', 'id': 'hendege01', 'lastname': 'Henderson'},
#  'points': 7773}
# {'_id': {'firstName': 'Desmond', 'id': 'masonde01', 'lastname': 'Mason'},
#  'points': 7767}
# {'_id': {'firstName': 'Derrick', 'id': 'mahorri01', 'lastname': 'Mahorn'},
#  'points': 7763}
# {'_id': {'firstName': 'LaMarcus', 'id': 'aldrila01', 'lastname': 'Aldridge'},
#  'points': 7738}
# {'_id': {'firstName': 'Michael', 'id': 'coopemi01', 'lastname': 'Cooper'},
#  'points': 7729}
# {'_id': {'firstName': 'Robert', 'id': 'horryro01', 'lastname': 'Horry'},
#  'points': 7715}
# {'_id': {'firstName': 'Darrell', 'id': 'armstda01', 'lastname': 'Armstrong'},
#  'points': 7712}
# {'_id': {'firstName': 'Nathaniel', 'id': 'willina01', 'lastname': 'Williams'},
#  'points': 7709}
# {'_id': {'firstName': 'Paul', 'id': 'presspa01', 'lastname': 'Pressey'},
#  'points': 7664}
# {'_id': {'firstName': 'Matthew', 'id': 'harprma01', 'lastname': 'Harpring'},
#  'points': 7645}
# {'_id': {'firstName': 'Kevin', 'id': 'porteke01', 'lastname': 'Porter'},
#  'points': 7645}
# {'_id': {'firstName': 'Shane', 'id': 'battish01', 'lastname': 'Battier'},
#  'points': 7638}
# {'_id': {'firstName': 'David', 'id': 'gambeda01', 'lastname': 'Gambee'},
#  'points': 7632}
# {'_id': {'firstName': 'Morris', 'id': 'petermo01', 'lastname': 'Peterson'},
#  'points': 7628}
# {'_id': {'firstName': 'David', 'id': 'corzida01', 'lastname': 'Corzine'},
#  'points': 7615}
# {'_id': {'firstName': 'Theodore', 'id': 'edwarbl01', 'lastname': 'Edwards'},
#  'points': 7585}
# {'_id': {'firstName': 'Rory', 'id': 'sparrro01', 'lastname': 'Sparrow'},
#  'points': 7557}
# {'_id': {'firstName': 'Howard', 'id': 'komivho01', 'lastname': 'Komives'},
#  'points': 7550}
# {'_id': {'firstName': 'Elmore', 'id': 'smithel01', 'lastname': 'Smith'},
#  'points': 7541}
# {'_id': {'firstName': 'Joel', 'id': 'ehlocr01', 'lastname': 'Ehlo'},
#  'points': 7492}
# {'_id': {'firstName': 'Quintin', 'id': 'dailequ01', 'lastname': 'Dailey'},
#  'points': 7470}
# {'_id': {'firstName': 'James', 'id': 'poseyja01', 'lastname': 'Posey'},
#  'points': 7419}
# {'_id': {'firstName': 'LaPhonso', 'id': 'ellisla01', 'lastname': 'Ellis'},
#  'points': 7410}
# {'_id': {'firstName': 'Kevin', 'id': 'greveke01', 'lastname': 'Grevey'},
#  'points': 7364}
# {'_id': {'firstName': 'Derek', 'id': 'anderde01', 'lastname': 'Anderson'},
#  'points': 7357}
# {'_id': {'firstName': 'Leandro', 'id': 'barbole01', 'lastname': 'Barbosa'},
#  'points': 7351}
# {'_id': {'firstName': 'Bobby', 'id': 'jacksbo01', 'lastname': 'Jackson'},
#  'points': 7344}
# {'_id': {'firstName': 'Christopher', 'id': 'fordch01', 'lastname': 'Ford'},
#  'points': 7314}
# {'_id': {'firstName': 'Erick', 'id': 'dampier01', 'lastname': 'Dampier'},
#  'points': 7309}
# {'_id': {'firstName': 'Francis', 'id': 'brickfr01', 'lastname': 'Brickowski'},
#  'points': 7302}
# {'_id': {'firstName': 'Keith', 'id': 'erickke01', 'lastname': 'Erickson'},
#  'points': 7251}
# {'_id': {'firstName': 'Philip', 'id': 'hubbaph01', 'lastname': 'Hubbard'},
#  'points': 7228}
# {'_id': {'firstName': 'Roy', 'id': 'hinsoro01', 'lastname': 'Hinson'},
#  'points': 7206}
# {'_id': {'firstName': 'Terry', 'id': 'millste01', 'lastname': 'Mills'},
#  'points': 7175}
# {'_id': {'firstName': 'John', 'id': 'salmojo01', 'lastname': 'Salmons'},
#  'points': 7175}
# {'_id': {'firstName': 'Kerry', 'id': 'kittlke01', 'lastname': 'Kittles'},
#  'points': 7165}
# {'_id': {'firstName': 'Raymond', 'id': 'feltora01', 'lastname': 'Felton'},
#  'points': 7159}
# {'_id': {'firstName': 'Neal', 'id': 'walkne01', 'lastname': 'Walk'},
#  'points': 7157}
# {'_id': {'firstName': 'Gawen', 'id': 'wellsbo01', 'lastname': 'Wells'},
#  'points': 7147}
# {'_id': {'firstName': 'Jerome', 'id': 'richapo01', 'lastname': 'Richardson'},
#  'points': 7083}
# {'_id': {'firstName': 'Ronald', 'id': 'anderro01', 'lastname': 'Anderson'},
#  'points': 7056}
# {'_id': {'firstName': 'Vincent', 'id': 'delnevi01', 'lastname': 'Del Negro'},
#  'points': 7038}
# {'_id': {'firstName': '', 'id': 'hilarne01', 'lastname': 'Nene'},
#  'points': 7027}
# {'_id': {'firstName': 'Billy', 'id': 'owensbi01', 'lastname': 'Owens'},
#  'points': 7026}
# {'_id': {'firstName': 'Roderick', 'id': 'higgiro01', 'lastname': 'Higgins'},
#  'points': 7011}
# {'_id': {'firstName': 'Raja', 'id': 'bellra01', 'lastname': 'Bell'},
#  'points': 6998}
# {'_id': {'firstName': 'Loy', 'id': 'vaughlo01', 'lastname': 'Vaught'},
#  'points': 6984}
# {'_id': {'firstName': 'Ruben', 'id': 'patteru01', 'lastname': 'Patterson'},
#  'points': 6953}
# {'_id': {'firstName': 'James', 'id': 'foxji01', 'lastname': 'Fox'},
#  'points': 6945}
# {'_id': {'firstName': 'George', 'id': 'mccloge01', 'lastname': 'McCloud'},
#  'points': 6925}
# {'_id': {'firstName': 'Kenneth', 'id': 'atkinch01', 'lastname': 'Atkins'},
#  'points': 6863}
# {'_id': {'firstName': 'Tyrone', 'id': 'boguemu01', 'lastname': 'Bogues'},
#  'points': 6858}
# {'_id': {'firstName': 'Garfield', 'id': 'heardga01', 'lastname': 'Heard'},
#  'points': 6828}
# {'_id': {'firstName': 'Eddy', 'id': 'curryed01', 'lastname': 'Curry'},
#  'points': 6811}
# {'_id': {'firstName': 'Rafer', 'id': 'alstora01', 'lastname': 'Alston'},
#  'points': 6799}
# {'_id': {'firstName': 'Stuart', 'id': 'lantzst01', 'lastname': 'Lantz'},
#  'points': 6782}
# {'_id': {'firstName': 'Willie', 'id': 'anderwi01', 'lastname': 'Anderson'},
#  'points': 6771}
# {'_id': {'firstName': 'Michael', 'id': 'carrml01', 'lastname': 'Carr'},
#  'points': 6759}
# {'_id': {'firstName': 'DeCovan', 'id': 'brownde01', 'lastname': 'Brown'},
#  'points': 6758}
# {'_id': {'firstName': 'Shawn', 'id': 'bradlsh01', 'lastname': 'Bradley'},
#  'points': 6752}
# {'_id': {'firstName': 'Voshon', 'id': 'lenarvo01', 'lastname': 'Lenard'},
#  'points': 6745}
# {'_id': {'firstName': 'Michael', 'id': 'conlemi01', 'lastname': 'Conley'},
#  'points': 6740}
# {'_id': {'firstName': 'Earl', 'id': 'smithjr01', 'lastname': 'Smith'},
#  'points': 6725}
# {'_id': {'firstName': 'Allen', 'id': 'leaveal01', 'lastname': 'Leavell'},
#  'points': 6684}
# {'_id': {'firstName': 'Wali', 'id': 'joneswa02', 'lastname': 'Jones'},
#  'points': 6672}
# {'_id': {'firstName': 'Thomas', 'id': 'hawkito01', 'lastname': 'Hawkins'},
#  'points': 6672}
# {'_id': {'firstName': 'Darnell', 'id': 'hillmda01', 'lastname': 'Hillman'},
#  'points': 6666}
# {'_id': {'firstName': 'Donald', 'id': 'chanedo01', 'lastname': 'Chaney'},
#  'points': 6663}
# {'_id': {'firstName': 'Bryon', 'id': 'russebr01', 'lastname': 'Russell'},
#  'points': 6663}
# {'_id': {'firstName': 'Scott', 'id': 'skilesc01', 'lastname': 'Skiles'},
#  'points': 6652}
# {'_id': {'firstName': 'Vernell', 'id': 'colesbi01', 'lastname': 'Coles'},
#  'points': 6628}
# {'_id': {'firstName': 'Antonio', 'id': 'daniean01', 'lastname': 'Daniels'},
#  'points': 6626}
# {'_id': {'firstName': 'Larry', 'id': 'siegfla01', 'lastname': 'Siegfried'},
#  'points': 6599}
# {'_id': {'firstName': 'Kevin', 'id': 'edwarke01', 'lastname': 'Edwards'},
#  'points': 6596}
# {'_id': {'firstName': 'Lawrence', 'id': 'millela01', 'lastname': 'Miller'},
#  'points': 6595}
# {'_id': {'firstName': 'William', 'id': 'kellebi01', 'lastname': 'Keller'},
#  'points': 6588}
# {'_id': {'firstName': 'Brian', 'id': 'shawbr01', 'lastname': 'Shaw'},
#  'points': 6547}
# {'_id': {'firstName': 'Jameer', 'id': 'nelsoja01', 'lastname': 'Nelson'},
#  'points': 6542}
# {'_id': {'firstName': 'Patrick', 'id': 'cummipa01', 'lastname': 'Cummings'},
#  'points': 6529}
# {'_id': {'firstName': 'Terry', 'id': 'catlete01', 'lastname': 'Catledge'},
#  'points': 6520}
# {'_id': {'firstName': 'Mel', 'id': 'countme01', 'lastname': 'Counts'},
#  'points': 6516}
# {'_id': {'firstName': 'Chukwuemeka', 'id': 'okafoem01', 'lastname': 'Okafor'},
#  'points': 6491}
# {'_id': {'firstName': 'Jeffery', 'id': 'westdo01', 'lastname': 'West'},
#  'points': 6477}
# {'_id': {'firstName': 'Albert', 'id': 'kingal01', 'lastname': 'King'},
#  'points': 6470}
# {'_id': {'firstName': 'Boris', 'id': 'diawbo01', 'lastname': 'Diaw-Riffiod'},
#  'points': 6454}
# {'_id': {'firstName': 'Daniel', 'id': 'ferryda01', 'lastname': 'Ferry'},
#  'points': 6439}
# {'_id': {'firstName': 'Darrell', 'id': 'walkeda01', 'lastname': 'Walker'},
#  'points': 6389}
# {'_id': {'firstName': 'Christopher', 'id': 'millsch01', 'lastname': 'Mills'},
#  'points': 6357}
# {'_id': {'firstName': 'Michael', 'id': 'riordmi01', 'lastname': 'Riordan'},
#  'points': 6334}
# {'_id': {'firstName': 'Alvin', 'id': 'attleal01', 'lastname': 'Attles'},
#  'points': 6328}
# {'_id': {'firstName': 'Kyle', 'id': 'korveky01', 'lastname': 'Korver'},
#  'points': 6307}
# {'_id': {'firstName': 'Lukas', 'id': 'ridnolu01', 'lastname': 'Ridnour'},
#  'points': 6307}
# {'_id': {'firstName': 'Alton', 'id': 'listeal01', 'lastname': 'Lister'},
#  'points': 6298}
# {'_id': {'firstName': 'Mario', 'id': 'eliema01', 'lastname': 'Elie'},
#  'points': 6265}
# {'_id': {'firstName': 'Mark', 'id': 'westma01', 'lastname': 'West'},
#  'points': 6259}
# {'_id': {'firstName': 'Herman', 'id': 'gillihe01', 'lastname': 'Gilliam'},
#  'points': 6252}
# {'_id': {'firstName': 'Wayne', 'id': 'rollitr01', 'lastname': 'Rollins'},
#  'points': 6249}
# {'_id': {'firstName': 'Kelvin', 'id': 'tucketr01', 'lastname': 'Tucker'},
#  'points': 6237}
# {'_id': {'firstName': 'Dwight', 'id': 'jonesdw01', 'lastname': 'Jones'},
#  'points': 6230}
# {'_id': {'firstName': 'John', 'id': 'mengejo01', 'lastname': 'Mengelt'},
#  'points': 6218}
# {'_id': {'firstName': 'Michael', 'id': 'galemi01', 'lastname': 'Gale'},
#  'points': 6203}
# {'_id': {'firstName': 'Richard', 'id': 'kelleri01', 'lastname': 'Kelley'},
#  'points': 6199}
# {'_id': {'firstName': 'Tyson', 'id': 'chandty01', 'lastname': 'Chandler'},
#  'points': 6193}
# {'_id': {'firstName': 'Lorenzen', 'id': 'wrighlo02', 'lastname': 'Wright'},
#  'points': 6191}
# {'_id': {'firstName': 'Michael', 'id': 'bensoke01', 'lastname': 'Benson'},
#  'points': 6168}
# {'_id': {'firstName': 'Kevin', 'id': 'gamblke01', 'lastname': 'Gamble'},
#  'points': 6154}
# {'_id': {'firstName': 'Andrea', 'id': 'bargnan01', 'lastname': 'Bargnani'},
#  'points': 6138}
# {'_id': {'firstName': 'Thomas', 'id': 'hendeto01', 'lastname': 'Henderson'},
#  'points': 6088}
# {'_id': {'firstName': 'Johnny', 'id': 'neumajo01', 'lastname': 'Neumann'},
#  'points': 6022}
# {'_id': {'firstName': 'Robert', 'id': 'weissbo01', 'lastname': 'Weiss'},
#  'points': 5989}
# {'_id': {'firstName': 'Johnny', 'id': 'dawkijo01', 'lastname': 'Dawkins'},
#  'points': 5984}
# {'_id': {'firstName': 'Ronald', 'id': 'brewero01', 'lastname': 'Brewer'},
#  'points': 5971}
# {'_id': {'firstName': 'Frederick', 'id': 'roberfr01', 'lastname': 'Roberts'},
#  'points': 5962}
# {'_id': {'firstName': 'Bryant', 'id': 'stithbr01', 'lastname': 'Stith'},
#  'points': 5946}
# {'_id': {'firstName': 'Tracy', 'id': 'murratr01', 'lastname': 'Murray'},
#  'points': 5943}
# {'_id': {'firstName': 'Craig', 'id': 'hodgecr01', 'lastname': 'Hodges'},
#  'points': 5940}
# {'_id': {'firstName': 'John', 'id': 'barnhjo01', 'lastname': 'Barnhill'},
#  'points': 5937}
# {'_id': {'firstName': 'William', 'id': 'bucknqu01', 'lastname': 'Buckner'},
#  'points': 5929}
# {'_id': {'firstName': 'Russell', 'id': 'westbru01', 'lastname': 'Westbrook'},
#  'points': 5929}
# {'_id': {'firstName': 'Eric', 'id': 'piatker01', 'lastname': 'Piatkowski'},
#  'points': 5919}
# {'_id': {'firstName': 'Todd', 'id': 'dayto01', 'lastname': 'Day'},
#  'points': 5917}
# {'_id': {'firstName': 'Charles', 'id': 'mcmilto01', 'lastname': 'McMillen'},
#  'points': 5914}
# {'_id': {'firstName': 'Larry', 'id': 'smithla01', 'lastname': 'Smith'},
#  'points': 5904}
# {'_id': {'firstName': 'Ronald', 'id': 'mercero01', 'lastname': 'Mercer'},
#  'points': 5892}
# {'_id': {'firstName': 'Maurice', 'id': 'tayloma01', 'lastname': 'Taylor'},
#  'points': 5889}
# {'_id': {'firstName': 'Clifford', 'id': 'levincl01', 'lastname': 'Levingston'},
#  'points': 5888}
# {'_id': {'firstName': 'Kenneth', 'id': 'thomake01', 'lastname': 'Thomas'},
#  'points': 5876}
# {'_id': {'firstName': 'Aaron', 'id': 'mckieaa01', 'lastname': 'McKie'},
#  'points': 5871}
# {'_id': {'firstName': 'Vladimir', 'id': 'radmavl01', 'lastname': 'Radmanovic'},
#  'points': 5848}
# {'_id': {'firstName': 'Samuel', 'id': 'dalemsa01', 'lastname': 'Dalembert'},
#  'points': 5844}
# {'_id': {'firstName': 'Lionel', 'id': 'simmoli01', 'lastname': 'Simmons'},
#  'points': 5833}
# {'_id': {'firstName': 'Clifford', 'id': 'raycl01', 'lastname': 'Ray'},
#  'points': 5821}
# {'_id': {'firstName': 'Darwin', 'id': 'cookda01', 'lastname': 'Cook'},
#  'points': 5820}
# {'_id': {'firstName': 'John', 'id': 'baglejo01', 'lastname': 'Bagley'},
#  'points': 5802}
# {'_id': {'firstName': 'Earl', 'id': 'boykiea01', 'lastname': 'Boykins'},
#  'points': 5791}
# {'_id': {'firstName': 'Eric', 'id': 'snower01', 'lastname': 'Snow'},
#  'points': 5791}
# {'_id': {'firstName': 'Lucious', 'id': 'harrilu01', 'lastname': 'Harris'},
#  'points': 5784}
# {'_id': {'firstName': 'Robert', 'id': 'ferrybo01', 'lastname': 'Ferry'},
#  'points': 5780}
# {'_id': {'firstName': 'Charles', 'id': 'bibbyhe01', 'lastname': 'Bibby'},
#  'points': 5775}
# {'_id': {'firstName': 'Steven', 'id': 'hawesst01', 'lastname': 'Hawes'},
#  'points': 5768}
# {'_id': {'firstName': 'Jack', 'id': 'morelja01', 'lastname': 'Moreland'},
#  'points': 5730}
# {'_id': {'firstName': 'Jarrett', 'id': 'jackja01', 'lastname': 'Jack'},
#  'points': 5726}
# {'_id': {'firstName': 'Raef', 'id': 'lafrera01', 'lastname': 'LaFrentz'},
#  'points': 5690}
# {'_id': {'firstName': 'Herman', 'id': 'reidjr01', 'lastname': 'Reid'},
#  'points': 5680}
# {'_id': {'firstName': 'Udonis', 'id': 'hasleud01', 'lastname': 'Haslem'},
#  'points': 5664}
# {'_id': {'firstName': 'Robert', 'id': 'surabo01', 'lastname': 'Sura'},
#  'points': 5654}
# {'_id': {'firstName': 'DeShawn', 'id': 'stevede01', 'lastname': 'Stevenson'},
#  'points': 5643}
# {'_id': {'firstName': 'Eric', 'id': 'willier01', 'lastname': 'Williams'},
#  'points': 5642}
# {'_id': {'firstName': 'Arvydas', 'id': 'sabonar01', 'lastname': 'Sabonis'},
#  'points': 5629}
# {'_id': {'firstName': 'Otto', 'id': 'mooreot01', 'lastname': 'Moore'},
#  'points': 5616}
# {'_id': {'firstName': 'Marvin', 'id': 'willima02', 'lastname': 'Williams'},
#  'points': 5616}
# {'_id': {'firstName': 'Luis', 'id': 'scolalu01', 'lastname': 'Scola Balvoa'},
#  'points': 5597}
# {'_id': {'firstName': 'Phil', 'id': 'fordph01', 'lastname': 'Ford'},
#  'points': 5594}
# {'_id': {'firstName': 'Hubert', 'id': 'davishu01', 'lastname': 'Davis'},
#  'points': 5583}
# {'_id': {'firstName': 'Michael', 'id': 'jamesmi01', 'lastname': 'James'},
#  'points': 5579}
# {'_id': {'firstName': 'Paul', 'id': 'millspa01', 'lastname': 'Millsap'},
#  'points': 5573}
# {'_id': {'firstName': 'Samuel', 'id': 'bowiesa01', 'lastname': 'Bowie'},
#  'points': 5564}
# {'_id': {'firstName': 'John', 'id': 'paxsojo01', 'lastname': 'Paxson'},
#  'points': 5560}
# {'_id': {'firstName': 'Alfred', 'id': 'biancal01', 'lastname': 'Bianchi'},
#  'points': 5550}
# {'_id': {'firstName': 'Louis', 'id': 'orrlo01', 'lastname': 'Orr'},
#  'points': 5545}
# {'_id': {'firstName': 'William', 'id': 'robinbi01', 'lastname': 'Robinzine'},
#  'points': 5541}
# {'_id': {'firstName': 'Charlie', 'id': 'villach01', 'lastname': 'Villanueva'},
#  'points': 5525}
# {'_id': {'firstName': 'John', 'id': 'eganjo01', 'lastname': 'Egan'},
#  'points': 5521}
# {'_id': {'firstName': 'Radoslav', 'id': 'nestera01', 'lastname': 'Nesterovic'},
#  'points': 5519}
# {'_id': {'firstName': 'Cornelius', 'id': 'simmoco01', 'lastname': 'Simmons'},
#  'points': 5513}
# {'_id': {'firstName': 'Nazr', 'id': 'mohamna01', 'lastname': 'Mohammed'},
#  'points': 5502}
# {'_id': {'firstName': 'Gregory', 'id': 'anthogr01', 'lastname': 'Anthony'},
#  'points': 5497}
# {'_id': {'firstName': 'Earl', 'id': 'watsoea01', 'lastname': 'Watson'},
#  'points': 5481}
# {'_id': {'firstName': 'Allan', 'id': 'bristal01', 'lastname': 'Bristow'},
#  'points': 5450}
# {'_id': {'firstName': 'Joe', 'id': 'meriwjo01', 'lastname': 'Meriweather'},
#  'points': 5439}
# {'_id': {'firstName': 'Stephen', 'id': 'kerrst01', 'lastname': 'Kerr'},
#  'points': 5437}
# {'_id': {'firstName': 'Arlen', 'id': 'bockhbu01', 'lastname': 'Bockhorn'},
#  'points': 5430}
# {'_id': {'firstName': 'Philip', 'id': 'jacksph01', 'lastname': 'Jackson'},
#  'points': 5428}
# {'_id': {'firstName': 'Robert', 'id': 'wilkebo01', 'lastname': 'Wilkerson'},
#  'points': 5424}
# {'_id': {'firstName': 'Andres', 'id': 'nocioan01', 'lastname': 'Nocioni'},
#  'points': 5414}
# {'_id': {'firstName': 'William', 'id': 'hanzlbi01', 'lastname': 'Hanzlik'},
#  'points': 5414}
# {'_id': {'firstName': 'James', 'id': 'cleamji01', 'lastname': 'Cleamons'},
#  'points': 5412}
# {'_id': {'firstName': 'Darnell', 'id': 'valenda01', 'lastname': 'Valentine'},
#  'points': 5400}
# {'_id': {'firstName': 'Jeffrey', 'id': 'mcinnje01', 'lastname': 'McInnis'},
#  'points': 5396}
# {'_id': {'firstName': 'Kelvin', 'id': 'ranseke01', 'lastname': 'Ransey'},
#  'points': 5380}
# {'_id': {'firstName': 'Edward', 'id': 'pincked01', 'lastname': 'Pinckney'},
#  'points': 5378}
# {'_id': {'firstName': 'Travis', 'id': 'besttr01', 'lastname': 'Best'},
#  'points': 5376}
# {'_id': {'firstName': 'Edward', 'id': 'houseed01', 'lastname': 'House'},
#  'points': 5356}
# {'_id': {'firstName': 'John', 'id': 'rochejo01', 'lastname': 'Roche'},
#  'points': 5345}
# {'_id': {'firstName': 'Brevin', 'id': 'knighbr01', 'lastname': 'Knight'},
#  'points': 5342}
# {'_id': {'firstName': 'Ollie', 'id': 'johnsol01', 'lastname': 'Johnson'},
#  'points': 5341}
# {'_id': {'firstName': 'John', 'id': 'battljo01', 'lastname': 'Battle'},
#  'points': 5338}
# {'_id': {'firstName': 'Shandon', 'id': 'andersh01', 'lastname': 'Anderson'},
#  'points': 5327}
# {'_id': {'firstName': 'Stephen', 'id': 'stipast01', 'lastname': 'Stipanovich'},
#  'points': 5323}
# {'_id': {'firstName': 'John', 'id': 'clemeba01', 'lastname': 'Clemens'},
#  'points': 5312}
# {'_id': {'firstName': 'Eugene', 'id': 'banksge01', 'lastname': 'Banks'},
#  'points': 5305}
# {'_id': {'firstName': 'Emanuel', 'id': 'leaksma01', 'lastname': 'Leaks'},
#  'points': 5302}
# {'_id': {'firstName': 'Bruce', 'id': 'bowenbr01', 'lastname': 'Bowen'},
#  'points': 5290}
# {'_id': {'firstName': 'Brendan', 'id': 'haywobr01', 'lastname': 'Haywood'},
#  'points': 5287}
# {'_id': {'firstName': 'Kyle', 'id': 'macyky01', 'lastname': 'Macy'},
#  'points': 5259}
# {'_id': {'firstName': 'Joseph', 'id': 'bryanjo01', 'lastname': 'Bryant'},
#  'points': 5252}
# {'_id': {'firstName': 'Rasual', 'id': 'butlera01', 'lastname': 'Butler'},
#  'points': 5252}
# {'_id': {'firstName': 'James', 'id': 'baileja01', 'lastname': 'Bailey'},
#  'points': 5246}
# {'_id': {'firstName': 'Derek', 'id': 'smithde02', 'lastname': 'Smith'},
#  'points': 5232}
# {'_id': {'firstName': 'John', 'id': 'sallejo01', 'lastname': 'Salley'},
#  'points': 5228}
# {'_id': {'firstName': 'Othella', 'id': 'harriot01', 'lastname': 'Harrington'},
#  'points': 5212}
# {'_id': {'firstName': 'Eric', 'id': 'moneyer01', 'lastname': 'Money'},
#  'points': 5211}
# {'_id': {'firstName': 'Mitchell', 'id': 'kupchmi01', 'lastname': 'Kupchak'},
#  'points': 5202}
# {'_id': {'firstName': 'Andrew', 'id': 'bogutan01', 'lastname': 'Bogut'},
#  'points': 5179}
# {'_id': {'firstName': 'Beno', 'id': 'udrihbe01', 'lastname': 'Udrih'},
#  'points': 5177}
# {'_id': {'firstName': 'Michael', 'id': 'sandemi01', 'lastname': 'Sanders'},
#  'points': 5162}
# {'_id': {'firstName': 'Louis', 'id': 'willilo02', 'lastname': 'Williams'},
#  'points': 5158}
# {'_id': {'firstName': 'Bobby', 'id': 'phillbo01', 'lastname': 'Phills'},
#  'points': 5153}
# {'_id': {'firstName': 'Coby', 'id': 'dietrco01', 'lastname': 'Dietrick'},
#  'points': 5140}
# {'_id': {'firstName': 'Lewis', 'id': 'lloydle01', 'lastname': 'Lloyd'},
#  'points': 5130}
# {'_id': {'firstName': 'McCoy', 'id': 'mclemmc01', 'lastname': 'McLemore'},
#  'points': 5130}
# {'_id': {'firstName': 'Ernest', 'id': 'grunfer01', 'lastname': 'Grunfeld'},
#  'points': 5124}
# {'_id': {'firstName': 'Blair', 'id': 'rasmubl01', 'lastname': 'Rasmussen'},
#  'points': 5119}
# {'_id': {'firstName': 'John', 'id': 'tresvjo01', 'lastname': 'Tresvant'},
#  'points': 5118}
# {'_id': {'firstName': 'Eric', 'id': 'murdoer01', 'lastname': 'Murdock'},
#  'points': 5118}
# {'_id': {'firstName': 'Howard', 'id': 'eisleho01', 'lastname': 'Eisley'},
#  'points': 5116}
# {'_id': {'firstName': 'George', 'id': 'lynchge01', 'lastname': 'Lynch'},
#  'points': 5109}
# {'_id': {'firstName': 'Roland', 'id': 'taylofa01', 'lastname': 'Taylor'},
#  'points': 5098}
# {'_id': {'firstName': 'Alan', 'id': 'hendeal01', 'lastname': 'Henderson'},
#  'points': 5094}
# {'_id': {'firstName': 'Demetrius', 'id': 'battito01', 'lastname': 'Battie'},
#  'points': 5082}
# {'_id': {'firstName': 'Sidney', 'id': 'greensi02', 'lastname': 'Green'},
#  'points': 5080}
# {'_id': {'firstName': 'Matthew', 'id': 'geigema01', 'lastname': 'Geiger'},
#  'points': 5059}
# {'_id': {'firstName': 'Nathaniel', 'id': 'robinna01', 'lastname': 'Robinson'},
#  'points': 5038}
# {'_id': {'firstName': 'Keyon', 'id': 'doolike01', 'lastname': 'Dooling'},
#  'points': 5036}
# {'_id': {'firstName': 'Theodore', 'id': 'dunntr01', 'lastname': 'Dunn'},
#  'points': 5033}
# {'_id': {'firstName': 'Willie', 'id': 'greenwi01', 'lastname': 'Green'},
#  'points': 5030}
# {'_id': {'firstName': 'Rodney', 'id': 'thornro01', 'lastname': 'Thorn'},
#  'points': 5012}
# {'_id': {'firstName': 'K.C.', 'id': 'joneskc01', 'lastname': 'Jones'},
#  'points': 5011}
# {'_id': {'firstName': 'Larry', 'id': 'steella01', 'lastname': 'Steele'},
#  'points': 5009}
# {'_id': {'firstName': 'Malik', 'id': 'rosema01', 'lastname': 'Rose'},
#  'points': 5003}
# {'_id': {'firstName': 'Walter', 'id': 'weslewa01', 'lastname': 'Wesley'},
#  'points': 5002}
# {'_id': {'firstName': 'Paul', 'id': 'neumapa01', 'lastname': 'Neumann'},
#  'points': 4989}
# {'_id': {'firstName': 'Charles', 'id': 'outlabo01', 'lastname': 'Outlaw'},
#  'points': 4970}
# {'_id': {'firstName': 'Michael', 'id': 'mcgeemi01', 'lastname': 'McGee'},
#  'points': 4968}
# {'_id': {'firstName': 'Tony', 'id': 'delkto01', 'lastname': 'Delk'},
#  'points': 4957}
# {'_id': {'firstName': 'Malik', 'id': 'sealyma01', 'lastname': 'Sealy'},
#  'points': 4955}
# {'_id': {'firstName': 'Gregory', 'id': 'andergr01', 'lastname': 'Anderson'},
#  'points': 4953}
# {'_id': {'firstName': 'Bryant', 'id': 'reevebr01', 'lastname': 'Reeves'},
#  'points': 4945}
# {'_id': {'firstName': 'Mark', 'id': 'blounma01', 'lastname': 'Blount'},
#  'points': 4941}
# {'_id': {'firstName': 'Franklin', 'id': 'johnsfr01', 'lastname': 'Johnson'},
#  'points': 4937}
# {'_id': {'firstName': 'Robert', 'id': 'packro01', 'lastname': 'Pack'},
#  'points': 4921}
# {'_id': {'firstName': 'Ryan', 'id': 'gomesry01', 'lastname': 'Gomes'},
#  'points': 4920}
# {'_id': {'firstName': 'Clark', 'id': 'kellocl01', 'lastname': 'Kellogg'},
#  'points': 4918}
# {'_id': {'firstName': 'Martin', 'id': 'woodal01', 'lastname': 'Wood'},
#  'points': 4902}
# {'_id': {'firstName': 'Benedict', 'id': 'poquebe01', 'lastname': 'Poquette'},
#  'points': 4899}
# {'_id': {'firstName': 'Edward', 'id': 'conlied01', 'lastname': 'Conlin'},
#  'points': 4891}
# {'_id': {'firstName': 'Chris', 'id': 'wilcoch01', 'lastname': 'Wilcox'},
#  'points': 4891}
# {'_id': {'firstName': 'John', 'id': 'moorejo01', 'lastname': 'Moore'},
#  'points': 4890}
# {'_id': {'firstName': 'David', 'id': 'stallda01', 'lastname': 'Stallworth'},
#  'points': 4860}
# {'_id': {'firstName': 'Lloyd', 'id': 'nealll01', 'lastname': 'Neal'},
#  'points': 4846}
# {'_id': {'firstName': 'Channing', 'id': 'fryech01', 'lastname': 'Frye'},
#  'points': 4833}
# {'_id': {'firstName': 'Philip', 'id': 'jordoph01', 'lastname': 'Jordon'},
#  'points': 4833}
# {'_id': {'firstName': 'Ronald', 'id': 'murraro01', 'lastname': 'Murray'},
#  'points': 4817}
# {'_id': {'firstName': 'Jack', 'id': 'nichoja01', 'lastname': 'Nichols'},
#  'points': 4806}
# {'_id': {'firstName': 'Winston', 'id': 'garlawi01', 'lastname': 'Garland'},
#  'points': 4799}
# {'_id': {'firstName': 'Ronald', 'id': 'williro01', 'lastname': 'Williams'},
#  'points': 4797}
# {'_id': {'firstName': 'Terrance', 'id': 'fordtj01', 'lastname': 'Ford'},
#  'points': 4797}
# {'_id': {'firstName': 'Ledell', 'id': 'eacklle01', 'lastname': 'Eackles'},
#  'points': 4783}
# {'_id': {'firstName': 'Hakim', 'id': 'warriha01', 'lastname': 'Warrick'},
#  'points': 4753}
# {'_id': {'firstName': 'Randall', 'id': 'dentora01', 'lastname': 'Denton'},
#  'points': 4749}
# {'_id': {'firstName': 'Freeman', 'id': 'willifr01', 'lastname': 'Williams'},
#  'points': 4738}
# {'_id': {'firstName': 'Jose',
#          'id': 'caldejo01',
#          'lastname': 'Calderon Borrallo'},
#  'points': 4735}
# {'_id': {'firstName': 'Ronald', 'id': 'franzro01', 'lastname': 'Franz'},
#  'points': 4733}
# {'_id': {'firstName': 'Nathaniel', 'id': 'mcmilna01', 'lastname': 'McMillan'},
#  'points': 4733}
# {'_id': {'firstName': 'Travis', 'id': 'outlatr01', 'lastname': 'Outlaw'},
#  'points': 4732}
# {'_id': {'firstName': 'Jon', 'id': 'barryjo01', 'lastname': 'Barry'},
#  'points': 4715}
# {'_id': {'firstName': 'Tyronn', 'id': 'luety01', 'lastname': 'Lue'},
#  'points': 4710}
# {'_id': {'firstName': 'Earl', 'id': 'lloydea01', 'lastname': 'Lloyd'},
#  'points': 4682}
# {'_id': {'firstName': 'Sean', 'id': 'rooksse01', 'lastname': 'Rooks'},
#  'points': 4676}
# {'_id': {'firstName': 'Joseph', 'id': 'kleinjo01', 'lastname': 'Kleine'},
#  'points': 4666}
# {'_id': {'firstName': 'Fred', 'id': 'hetzefr01', 'lastname': 'Hetzel'},
#  'points': 4658}
# {'_id': {'firstName': 'Kevin', 'id': 'loveke01', 'lastname': 'Love'},
#  'points': 4649}
# {'_id': {'firstName': 'Troy', 'id': 'hudsotr01', 'lastname': 'Hudson'},
#  'points': 4637}
# {'_id': {'firstName': 'Raimondas',
#          'id': 'marcisa01',
#          'lastname': 'Marciulionis'},
#  'points': 4631}
# {'_id': {'firstName': 'Joseph', 'id': 'ellisjo01', 'lastname': 'Ellis'},
#  'points': 4623}
# {'_id': {'firstName': 'Alfonso', 'id': 'johnsbu01', 'lastname': 'Johnson'},
#  'points': 4617}
# {'_id': {'firstName': 'Darrell', 'id': 'rambiku01', 'lastname': 'Rambis'},
#  'points': 4603}
# {'_id': {'firstName': 'Rodney', 'id': 'stuckro01', 'lastname': 'Stuckey'},
#  'points': 4603}
# {'_id': {'firstName': 'Kevin', 'id': 'kunneke01', 'lastname': 'Kunnert'},
#  'points': 4602}
# {'_id': {'firstName': 'Randall', 'id': 'breuera01', 'lastname': 'Breuer'},
#  'points': 4599}
# {'_id': {'firstName': 'Donald', 'id': 'adamsdo01', 'lastname': 'Adams'},
#  'points': 4598}
# {'_id': {'firstName': 'Andrew', 'id': 'bynuman01', 'lastname': 'Bynum'},
#  'points': 4597}
# {'_id': {'firstName': 'Thomas', 'id': 'boerwto01', 'lastname': 'Boerwinkle'},
#  'points': 4596}
# {'_id': {'firstName': 'Ovinton', 'id': 'mayooj01', 'lastname': 'Mayo'},
#  'points': 4584}
# {'_id': {'firstName': 'Stromile', 'id': 'swiftst01', 'lastname': 'Swift'},
#  'points': 4582}
# {'_id': {'firstName': 'Curtis', 'id': 'perrycu01', 'lastname': 'Perry'},
#  'points': 4578}
# {'_id': {'firstName': 'Robert', 'id': 'grossbo01', 'lastname': 'Gross'},
#  'points': 4567}
# {'_id': {'firstName': 'Marion', 'id': 'spearod01', 'lastname': 'Spears'},
#  'points': 4557}
# {'_id': {'firstName': 'Zaid', 'id': 'abdulza01', 'lastname': 'Abdul-Aziz'},
#  'points': 4557}
# {'_id': {'firstName': 'Bison', 'id': 'delebi01', 'lastname': 'Dele'},
#  'points': 4536}
# {'_id': {'firstName': 'Thaddeus', 'id': 'youngth01', 'lastname': 'Young'},
#  'points': 4534}
# {'_id': {'firstName': 'Micheal', 'id': 'willimi02', 'lastname': 'Williams'},
#  'points': 4533}
# {'_id': {'firstName': 'Michael', 'id': 'evansmi01', 'lastname': 'Evans'},
#  'points': 4531}
# {'_id': {'firstName': 'Mickael', 'id': 'pietrmi01', 'lastname': 'Pietrus'},
#  'points': 4529}
# {'_id': {'firstName': 'Randy', 'id': 'foyera01', 'lastname': 'Foye'},
#  'points': 4513}
# {'_id': {'firstName': 'Darius', 'id': 'milesda01', 'lastname': 'Miles'},
#  'points': 4507}
# {'_id': {'firstName': 'Trevor', 'id': 'arizatr01', 'lastname': 'Ariza'},
#  'points': 4501}
# {'_id': {'firstName': 'Mike', 'id': 'glennmi01', 'lastname': 'Glenn'},
#  'points': 4496}
# {'_id': {'firstName': 'Pervis', 'id': 'ellispe01', 'lastname': 'Ellison'},
#  'points': 4494}
# {'_id': {'firstName': 'Anthony', 'id': 'parkean01', 'lastname': 'Parker'},
#  'points': 4478}
# {'_id': {'firstName': 'Dwight', 'id': 'lamarbo01', 'lastname': 'Lamar'},
#  'points': 4478}
# {'_id': {'firstName': 'Austin', 'id': 'croshau01', 'lastname': 'Croshere'},
#  'points': 4475}
# {'_id': {'firstName': 'Robert', 'id': 'parkeso01', 'lastname': 'Parker'},
#  'points': 4471}
# {'_id': {'firstName': 'Drazen', 'id': 'petrodr01', 'lastname': 'Petrovic'},
#  'points': 4461}
# {'_id': {'firstName': 'George', 'id': 'lehmage01', 'lastname': 'Lehmann'},
#  'points': 4458}
# {'_id': {'firstName': 'William', 'id': 'averibi01', 'lastname': 'Averitt'},
#  'points': 4434}
# {'_id': {'firstName': 'Anthony', 'id': 'johnsan02', 'lastname': 'Johnson'},
#  'points': 4434}
# {'_id': {'firstName': 'Andrew', 'id': 'langan01', 'lastname': 'Lang'},
#  'points': 4431}
# {'_id': {'firstName': 'Jerome', 'id': 'whiteje01', 'lastname': 'Whitehead'},
#  'points': 4423}
# {'_id': {'firstName': 'Jamaal', 'id': 'tinslja01', 'lastname': 'Tinsley'},
#  'points': 4414}
# {'_id': {'firstName': 'John', 'id': 'willijo02', 'lastname': 'Williams'},
#  'points': 4406}
# {'_id': {'firstName': 'Charles', 'id': 'sharech01', 'lastname': 'Share'},
#  'points': 4403}
# {'_id': {'firstName': 'Ira', 'id': 'hargeir01', 'lastname': 'Harge'},
#  'points': 4396}
# {'_id': {'firstName': 'Geoffrey', 'id': 'hustoge01', 'lastname': 'Huston'},
#  'points': 4380}
# {'_id': {'firstName': 'Brook', 'id': 'lopezbr01', 'lastname': 'Lopez'},
#  'points': 4379}
# {'_id': {'firstName': 'Zaur', 'id': 'pachuza01', 'lastname': 'Pachulia'},
#  'points': 4378}
# {'_id': {'firstName': 'George', 'id': 'johnsge02', 'lastname': 'Johnson'},
#  'points': 4369}
# {'_id': {'firstName': 'Gary', 'id': 'grantga01', 'lastname': 'Grant'},
#  'points': 4368}
# {'_id': {'firstName': 'Jeffrey', 'id': 'greenje02', 'lastname': 'Green'},
#  'points': 4367}
# {'_id': {'firstName': 'Gary', 'id': 'trentga01', 'lastname': 'Trent'},
#  'points': 4366}
# {'_id': {'firstName': 'Steven', 'id': 'blakest01', 'lastname': 'Blake'},
#  'points': 4353}
# {'_id': {'firstName': 'Robert', 'id': 'warrebo01', 'lastname': 'Warren'},
#  'points': 4347}
# {'_id': {'firstName': 'Lester', 'id': 'connele01', 'lastname': 'Conner'},
#  'points': 4337}
# {'_id': {'firstName': 'Mark', 'id': 'bryanma01', 'lastname': 'Bryant'},
#  'points': 4313}
# {'_id': {'firstName': 'Marvin', 'id': 'webstma01', 'lastname': 'Webster'},
#  'points': 4302}
# {'_id': {'firstName': 'Damon', 'id': 'jonesda01', 'lastname': 'Jones'},
#  'points': 4299}
# {'_id': {'firstName': 'Matthew', 'id': 'guokama02', 'lastname': 'Guokas'},
#  'points': 4285}
# {'_id': {'firstName': 'Stanley', 'id': 'miasest01', 'lastname': 'Miasek'},
#  'points': 4253}
# {'_id': {'firstName': 'Donald', 'id': 'sidledo01', 'lastname': 'Sidle'},
#  'points': 4247}
# {'_id': {'firstName': 'Charles', 'id': 'johnsch01', 'lastname': 'Johnson'},
#  'points': 4241}
# {'_id': {'firstName': 'Tony', 'id': 'masseto01', 'lastname': 'Massenburg'},
#  'points': 4238}
# {'_id': {'firstName': 'John', 'id': 'mcmahja01', 'lastname': 'McMahon'},
#  'points': 4237}
# {'_id': {'firstName': 'Michael', 'id': 'beaslmi01', 'lastname': 'Beasley'},
#  'points': 4221}
# {'_id': {'firstName': 'George', 'id': 'kingge01', 'lastname': 'King'},
#  'points': 4219}
# {'_id': {'firstName': 'Howard', 'id': 'porteho01', 'lastname': 'Porter'},
#  'points': 4215}
# {'_id': {'firstName': 'George', 'id': 'johnsge03', 'lastname': 'Johnson'},
#  'points': 4214}
# {'_id': {'firstName': 'John', 'id': 'gianejo01', 'lastname': 'Gianelli'},
#  'points': 4210}
# {'_id': {'firstName': 'Nenad', 'id': 'krstine01', 'lastname': 'Krstic'},
#  'points': 4210}
# {'_id': {'firstName': 'William', 'id': 'leonasl01', 'lastname': 'Leonard'},
#  'points': 4204}
# {'_id': {'firstName': 'Clarence', 'id': 'walkefo01', 'lastname': 'Walker'},
#  'points': 4199}
# {'_id': {'firstName': 'Tommy', 'id': 'burleto01', 'lastname': 'Burleson'},
#  'points': 4190}
# {'_id': {'firstName': 'Bobby', 'id': 'simmobo01', 'lastname': 'Simmons'},
#  'points': 4189}
# {'_id': {'firstName': 'Delonte', 'id': 'westde01', 'lastname': 'West'},
#  'points': 4188}
# {'_id': {'firstName': 'Edward', 'id': 'sadowed01', 'lastname': 'Sadowski'},
#  'points': 4171}
# {'_id': {'firstName': 'David', 'id': 'wingada01', 'lastname': 'Wingate'},
#  'points': 4166}
# {'_id': {'firstName': 'Alvin', 'id': 'willial02', 'lastname': 'Williams'},
#  'points': 4161}
# {'_id': {'firstName': 'George', 'id': 'ratkoge01', 'lastname': 'Ratkovicz'},
#  'points': 4157}
# {'_id': {'firstName': 'Nicholas', 'id': 'collini01', 'lastname': 'Collison'},
#  'points': 4149}
# {'_id': {'firstName': 'James', 'id': 'hamiljo01', 'lastname': 'Hamilton'},
#  'points': 4145}
# {'_id': {'firstName': 'Jerry', 'id': 'sichtje01', 'lastname': 'Sichting'},
#  'points': 4141}
# {'_id': {'firstName': 'Michael', 'id': 'olowomi01', 'lastname': 'Olowokandi'},
#  'points': 4135}
# {'_id': {'firstName': 'James', 'id': 'krebsji01', 'lastname': 'Krebs'},
#  'points': 4128}
# {'_id': {'firstName': 'Clarence', 'id': 'brownch01', 'lastname': 'Brown'},
#  'points': 4125}
# {'_id': {'firstName': 'Aaron', 'id': 'williaa01', 'lastname': 'Williams'},
#  'points': 4120}
# {'_id': {'firstName': 'James', 'id': 'mcelrji01', 'lastname': 'McElroy'},
#  'points': 4120}
# ...
#  'points': 2}
# {'_id': {'firstName': 'Bill', 'id': 'summebi01', 'lastname': 'Summers'},
#  'points': 2}
# {'_id': {'firstName': 'David', 'id': 'scholda01', 'lastname': 'Scholz'},
#  'points': 2}
# {'_id': {'firstName': 'George', 'id': 'morsege01', 'lastname': 'Morse'},
#  'points': 2}
# {'_id': {'firstName': 'Trey', 'id': 'gildetr01', 'lastname': 'Gilder'},
#  'points': 2}
# {'_id': {'firstName': 'Richard', 'id': 'dumasri01', 'lastname': 'Dumas'},
#  'points': 2}
# {'_id': {'firstName': 'Warren', 'id': 'switzwa01', 'lastname': 'Switzer'},
#  'points': 2}
# {'_id': {'firstName': 'Dennis', 'id': 'vanzade01', 'lastname': 'Van Zant'},
#  'points': 2}
# {'_id': {'firstName': 'Bill', 'id': 'durkibi01', 'lastname': 'Durkin'},
#  'points': 2}
# {'_id': {'firstName': 'Jack', 'id': 'gilleja01', 'lastname': 'Gillespie'},
#  'points': 2}
# {'_id': {'firstName': 'Matthew', 'id': 'walshma01', 'lastname': 'Walsh'},
#  'points': 2}
# {'_id': {'firstName': 'William', 'id': 'gainebi01', 'lastname': 'Gaines'},
#  'points': 2}
# {'_id': {'firstName': 'George', 'id': 'conlela01', 'lastname': 'Conley'},
#  'points': 2}
# {'_id': {'firstName': 'Beryl', 'id': 'drummbe01', 'lastname': 'Drummond'},
#  'points': 2}
# {'_id': {'firstName': 'Jonathan', 'id': 'smartke01', 'lastname': 'Smart'},
#  'points': 2}
# {'_id': {'firstName': 'Marvin', 'id': 'stoutma01', 'lastname': 'Stout'},
#  'points': 2}
# {'_id': {'firstName': 'Julie', 'id': 'silveju01', 'lastname': 'Silverman'},
#  'points': 2}
# {'_id': {'firstName': 'Harold', 'id': 'jeterha01', 'lastname': 'Jeter'},
#  'points': 2}
# {'_id': {'firstName': 'Isaac', 'id': 'walthis01', 'lastname': 'Walthour'},
#  'points': 2}
# {'_id': {'firstName': 'Mortimer', 'id': 'hillmo01', 'lastname': 'Hill'},
#  'points': 2}
# {'_id': {'firstName': 'James', 'id': 'davisre01', 'lastname': 'Davis'},
#  'points': 2}
# {'_id': {'firstName': 'Carter', 'id': 'orourbu01', 'lastname': "O'Rourke"},
#  'points': 2}
# {'_id': {'firstName': 'Randy', 'id': 'holcora01', 'lastname': 'Holcomb'},
#  'points': 2}
# {'_id': {'firstName': 'Charlie', 'id': 'scrugch01', 'lastname': 'Scruggs'},
#  'points': 2}
# {'_id': {'firstName': 'Eugene', 'id': 'scholge01', 'lastname': 'Scholz'},
#  'points': 2}
# {'_id': {'firstName': 'Garth', 'id': 'josepga01', 'lastname': 'Joseph'},
#  'points': 2}
# {'_id': {'firstName': 'Frank', 'id': 'burksfr01', 'lastname': 'Burks'},
#  'points': 2}
# {'_id': {'firstName': 'Robert', 'id': 'lytlebo01', 'lastname': 'Lytle'},
#  'points': 2}
# {'_id': {'firstName': 'Anthony', 'id': 'jacksto02', 'lastname': 'Jackson'},
#  'points': 2}
# {'_id': {'firstName': 'Roger', 'id': 'powelro01', 'lastname': 'Powell'},
#  'points': 2}
# {'_id': {'firstName': 'Roger', 'id': 'stricro01', 'lastname': 'Strickland'},
#  'points': 2}
# {'_id': {'firstName': 'Thomas', 'id': 'kearnto01', 'lastname': 'Kearns'},
#  'points': 2}
# {'_id': {'firstName': 'Jimmy', 'id': 'joyceji01', 'lastname': 'Joyce'},
#  'points': 1}
# {'_id': {'firstName': 'Robert', 'id': 'naberbo01', 'lastname': 'Naber'},
#  'points': 1}
# {'_id': {'firstName': 'Michael', 'id': 'kearnmi01', 'lastname': 'Kearns'},
#  'points': 1}
# {'_id': {'firstName': 'David', 'id': 'dupeeda01', 'lastname': 'Dupee'},
#  'points': 1}
# {'_id': {'firstName': 'Irving', 'id': 'norenir01', 'lastname': 'Noren'},
#  'points': 1}
# {'_id': {'firstName': 'Frank', 'id': 'beatyfr01', 'lastname': 'Beaty'},
#  'points': 1}
# {'_id': {'firstName': 'Ruben', 'id': 'reiswru01', 'lastname': 'Reiswerg'},
#  'points': 1}
# {'_id': {'firstName': 'Erv', 'id': 'menceer01', 'lastname': 'Mencel'},
#  'points': 1}
# {'_id': {'firstName': 'Bernard', 'id': 'berenbe01', 'lastname': 'Berens'},
#  'points': 1}
# {'_id': {'firstName': 'Paul', 'id': 'duchapa01', 'lastname': 'DuCharme'},
#  'points': 1}
# {'_id': {'firstName': '', 'id': 'leera01', 'lastname': 'Leerah'}, 'points': 1}
# {'_id': {'firstName': 'Jim', 'id': 'higgiji01', 'lastname': 'Higgins'},
#  'points': 1}
# {'_id': {'firstName': 'Sam', 'id': 'liebesa01', 'lastname': 'Lieberman'},
#  'points': 1}
# {'_id': {'firstName': 'Earnest', 'id': 'killuea01', 'lastname': 'Killum'},
#  'points': 1}
# {'_id': {'firstName': 'Thomas', 'id': 'edwarto01', 'lastname': 'Edwards'},
#  'points': 1}
# {'_id': {'firstName': 'Jim', 'id': 'quinlji01', 'lastname': 'Quinlan'},
#  'points': 1}
# {'_id': {'firstName': 'Lewis', 'id': 'spicelo01', 'lastname': 'Spicer'},
#  'points': 1}
# {'_id': {'firstName': 'Raymond', 'id': 'bellira01', 'lastname': 'Bellingham'},
#  'points': 1}
# {'_id': {'firstName': 'Louis', 'id': 'jagnolo01', 'lastname': 'Jagnow'},
#  'points': 1}
# {'_id': {'firstName': 'James', 'id': 'scottja01', 'lastname': 'Scott'},
#  'points': 1}
# {'_id': {'firstName': 'George', 'id': 'brownge01', 'lastname': 'Brown'},
#  'points': 1}
# {'_id': {'firstName': 'Ocie', 'id': 'richioc01', 'lastname': 'Richie'},
#  'points': 1}
# {'_id': {'firstName': 'Ernie', 'id': 'dibener01', 'lastname': 'DiBenedetto'},
#  'points': 1}
# {'_id': {'firstName': 'Harold', 'id': 'cihlaha01', 'lastname': 'Cihlar'},
#  'points': 1}
# {'_id': {'firstName': 'Warren', 'id': 'ajaxwa01', 'lastname': 'Ajax'},
#  'points': 1}
# {'_id': {'firstName': 'Malcolm', 'id': 'thomama01', 'lastname': 'Thomas'},
#  'points': 1}
# {'_id': {'firstName': 'Harmon', 'id': 'walteha01', 'lastname': 'Walters'},
#  'points': 0}
# {'_id': {'firstName': 'Dexter', 'id': 'shousde01', 'lastname': 'Shouse'},
#  'points': 0}
# {'_id': {'firstName': 'Mile', 'id': 'ilicmi01', 'lastname': 'Ilic'},
#  'points': 0}
# {'_id': {'firstName': 'Jack', 'id': 'oxenrja01', 'lastname': 'Oxenrider'},
#  'points': 0}
# {'_id': {'firstName': 'Stephen', 'id': 'fowdyst01', 'lastname': 'Fowdy'},
#  'points': 0}
# {'_id': {'firstName': '', 'id': 'sicky01', 'lastname': 'Sicky'}, 'points': 0}
# {'_id': {'firstName': 'John', 'id': 'sullijo01', 'lastname': 'Sullivan'},
#  'points': 0}
# {'_id': {'firstName': 'Derek', 'id': 'hoodde01', 'lastname': 'Hood'},
#  'points': 0}
# {'_id': {'firstName': 'Jarrett', 'id': 'durhaja01', 'lastname': 'Durham'},
#  'points': 0}
# {'_id': {'firstName': 'Larry', 'id': 'kennela01', 'lastname': 'Kenney'},
#  'points': 0}
# {'_id': {'firstName': 'Terrance', 'id': 'roberte01', 'lastname': 'Roberson'},
#  'points': 0}
# {'_id': {'firstName': 'Raymond', 'id': 'radzira01', 'lastname': 'Radziszewski'},
#  'points': 0}
# {'_id': {'firstName': 'Merle', 'id': 'alexame01', 'lastname': 'Alexander'},
#  'points': 0}
# {'_id': {'firstName': 'Dick', 'id': 'gatesdi01', 'lastname': 'Gates'},
#  'points': 0}
# {'_id': {'firstName': 'Don', 'id': 'cleardo01', 'lastname': 'Cleary'},
#  'points': 0}
# {'_id': {'firstName': 'Garmon', 'id': 'lewisga01', 'lastname': 'Lewis'},
#  'points': 0}
# {'_id': {'firstName': 'Lonnie', 'id': 'kluttlo01', 'lastname': 'Kluttz'},
#  'points': 0}
# {'_id': {'firstName': 'Edgar', 'id': 'saffeju01', 'lastname': 'Saffer'},
#  'points': 0}
# {'_id': {'firstName': 'Norman', 'id': 'grekino01', 'lastname': 'Grekin'},
#  'points': 0}
# {'_id': {'firstName': 'Adam', 'id': 'filipad01', 'lastname': 'Filipczak'},
#  'points': 0}
# {'_id': {'firstName': 'Tom', 'id': 'hovasto01', 'lastname': 'Hovasse'},
#  'points': 0}
# {'_id': {'firstName': 'Gaylord', 'id': 'woltzta01', 'lastname': 'Woltzen'},
#  'points': 0}
# {'_id': {'firstName': 'Edward', 'id': 'beached01', 'lastname': 'Beach'},
#  'points': 0}
# {'_id': {'firstName': '', 'id': 'riski01', 'lastname': 'Riskind'}, 'points': 0}
# {'_id': {'firstName': 'Tom', 'id': 'becketo01', 'lastname': 'Becker'},
#  'points': 0}
# {'_id': {'firstName': 'Bill', 'id': 'cramebi01', 'lastname': 'Cramer'},
#  'points': 0}
# {'_id': {'firstName': 'Pat', 'id': 'kennepa01', 'lastname': 'Kennelly'},
#  'points': 0}
# {'_id': {'firstName': 'Trevor', 'id': 'wintetr01', 'lastname': 'Winter'},
#  'points': 0}
# {'_id': {'firstName': 'Harold', 'id': 'englaha01', 'lastname': 'England'},
#  'points': 0}
# {'_id': {'firstName': 'Leon', 'id': 'brownle01', 'lastname': 'Brown'},
#  'points': 0}
# {'_id': {'firstName': 'Richard', 'id': 'leedi01', 'lastname': 'Lee'},
#  'points': 0}
# {'_id': {'firstName': 'James', 'id': 'mooneji01', 'lastname': 'Mooney'},
#  'points': 0}
# {'_id': {'firstName': 'Forest', 'id': 'ablefo01', 'lastname': 'Able'},
#  'points': 0}
# {'_id': {'firstName': 'Frank', 'id': 'otwayfr01', 'lastname': 'Otway'},
#  'points': 0}
# {'_id': {'firstName': 'Michael', 'id': 'mcdonmi01', 'lastname': 'McDonald'},
#  'points': 0}
# {'_id': {'firstName': 'Max', 'id': 'jamesma01', 'lastname': 'Jameson'},
#  'points': 0}
# {'_id': {'firstName': 'Zano', 'id': 'wastza01', 'lastname': 'Wast'},
#  'points': 0}
# {'_id': {'firstName': 'Norman', 'id': 'bakerno01', 'lastname': 'Baker'},
#  'points': 0}
# {'_id': {'firstName': 'John', 'id': 'pianaja01', 'lastname': 'Piana'},
#  'points': 0}
# {'_id': {'firstName': 'Ibrahim', 'id': 'kutluib01', 'lastname': 'Kutluay'},
#  'points': 0}
# {'_id': {'firstName': 'Brandin', 'id': 'knighbr02', 'lastname': 'Knight'},
#  'points': 0}
# {'_id': {'firstName': 'Paul', 'id': 'anthopa01', 'lastname': 'Anthony'},
#  'points': 0}
# {'_id': {'firstName': 'Vladimir', 'id': 'vranesl01', 'lastname': 'Vranes'},
#  'points': 0}
# {'_id': {'firstName': 'Carl', 'id': 'anderca01', 'lastname': 'Anderson'},
#  'points': 0}
# {'_id': {'firstName': 'Harold', 'id': 'swansha01', 'lastname': 'Swanson'},
#  'points': 0}
# {'_id': {'firstName': '', 'id': 'page01', 'lastname': 'Page'}, 'points': 0}
# {'_id': {'firstName': 'Edward', 'id': 'stegeed01', 'lastname': 'Stege'},
#  'points': 0}
# {'_id': {'firstName': '', 'id': 'hanis01', 'lastname': 'Hanisko'}, 'points': 0}
# {'_id': {'firstName': 'Lou', 'id': 'alixlo01', 'lastname': 'Alix'}, 'points': 0}
# {'_id': {'firstName': 'Abe', 'id': 'youriab01', 'lastname': 'Yourist'},
#  'points': 0}
# {'_id': {'firstName': 'William', 'id': 'downebi01', 'lastname': 'Downey'},
#  'points': 0}
# {'_id': {'firstName': 'LaMark', 'id': 'bakerla01', 'lastname': 'Baker'},
#  'points': 0}
# {'_id': {'firstName': 'Kenneth', 'id': 'corleke01', 'lastname': 'Corley'},
#  'points': 0}
# {'_id': {'firstName': 'Lyle', 'id': 'neatly01', 'lastname': 'Neat'},
#  'points': 0}
# {'_id': {'firstName': 'Ronald', 'id': 'creviro01', 'lastname': 'Crevier'},
#  'points': 0}
# {'_id': {'firstName': 'Gerald', 'id': 'mckeeje01', 'lastname': 'McKee'},
#  'points': 0}
# {'_id': {'firstName': 'Anthony', 'id': 'carpto01', 'lastname': 'Carp'},
#  'points': 0}
# {'_id': {'firstName': 'Gani', 'id': 'lawalga01', 'lastname': 'Lawal'},
#  'points': 0}
# {'_id': {'firstName': 'Tom', 'id': 'otoolto01', 'lastname': "O'Toole"},
#  'points': 0}
# {'_id': {'firstName': 'Emerald', 'id': 'lammebu01', 'lastname': 'Lamme'},
#  'points': 0}
# {'_id': {'firstName': 'Robert', 'id': 'rosero01', 'lastname': 'Rose'},
#  'points': 0}
# {'_id': {'firstName': 'Bill', 'id': 'anderbi01', 'lastname': 'Anderson'},
#  'points': 0}
# {'_id': {'firstName': 'Peter', 'id': 'hecompe01', 'lastname': 'Hecomovich'},
#  'points': 0}
# {'_id': {'firstName': 'Keith', 'id': 'bensoke02', 'lastname': 'Benson'},
#  'points': 0}
# {'_id': {'firstName': 'Harry', 'id': 'joyneha01', 'lastname': 'Joyner'},
#  'points': 0}
# {'_id': {'firstName': 'Louis', 'id': 'pressba01', 'lastname': 'Pressley'},
#  'points': 0}
# {'_id': {'firstName': 'Barry', 'id': 'sumptba01', 'lastname': 'Sumpter'},
#  'points': 0}
# {'_id': {'firstName': 'Ted', 'id': 'straite01', 'lastname': 'Strain'},
#  'points': 0}
# {'_id': {'firstName': 'Deng', 'id': 'gaide01', 'lastname': 'Gai'}, 'points': 0}
# {'_id': {'firstName': 'Larry', 'id': 'sykesla01', 'lastname': 'Sykes'},
#  'points': 0}
# {'_id': {'firstName': 'Bernard', 'id': 'voorhbe01', 'lastname': 'Voorheis'},
#  'points': 0}
# {'_id': {'firstName': '', 'id': 'mille01', 'lastname': 'Miller'}, 'points': 0}
# {'_id': {'firstName': 'Fred', 'id': 'arndtfr01', 'lastname': 'Arndt'},
#  'points': 0}
# {'_id': {'firstName': 'Paul', 'id': 'wallapa01', 'lastname': 'Wallace'},
#  'points': 0}
# {'_id': {'firstName': 'Robert', 'id': 'shaddbo01', 'lastname': 'Shaddock'},
#  'points': 0}
# {'_id': {'firstName': 'Jaak', 'id': 'ardonja01', 'lastname': 'Ardon'},
#  'points': 0}
# {'_id': {'firstName': 'Chris', 'id': 'mccrach01', 'lastname': 'McCray'},
#  'points': 0}
# {'_id': {'firstName': 'Jason', 'id': 'miskija01', 'lastname': 'Miskiri'},
#  'points': 0}
# {'_id': {'firstName': 'George', 'id': 'dayge01', 'lastname': 'Day'},
#  'points': 0}
# {'_id': {'firstName': 'Paul', 'id': 'nolenpa01', 'lastname': 'Nolen'},
#  'points': 0}
# {'_id': {'firstName': 'Gene', 'id': 'lathage02', 'lastname': 'Latham'},
#  'points': 0}
# {'_id': {'firstName': 'Eugene', 'id': 'willige01', 'lastname': 'Williams'},
#  'points': 0}
# {'_id': {'firstName': 'Emmet', 'id': 'birkem01', 'lastname': 'Birk'},
#  'points': 0}
# {'_id': {'firstName': 'Andrew', 'id': 'pankoan01', 'lastname': 'Panko'},
#  'points': 0}
# {'_id': {'firstName': '', 'id': 'morri01', 'lastname': 'Morris'}, 'points': 0}
# {'_id': {'firstName': 'Walter', 'id': 'graumwa01', 'lastname': 'Grauman'},
#  'points': 0}
# {'_id': {'firstName': 'Bill', 'id': 'lanebi01', 'lastname': 'Lane'},
#  'points': 0}
# {'_id': {'firstName': 'Max', 'id': 'biggsma01', 'lastname': 'Biggs'},
#  'points': 0}
# {'_id': {'firstName': 'Don', 'id': 'harvedo02', 'lastname': 'Harvey'},
#  'points': 0}
# {'_id': {'firstName': 'Ken', 'id': 'peterke01', 'lastname': 'Peterson'},
#  'points': 0}
# {'_id': {'firstName': 'Derrick', 'id': 'phelpde01', 'lastname': 'Phelps'},
#  'points': 0}
# {'_id': {'firstName': 'Stanley', 'id': 'washist01', 'lastname': 'Washington'},
#  'points': 0}
# {'_id': {'firstName': 'Marty', 'id': 'cullema01', 'lastname': 'Cullen'},
#  'points': 0}
# {'_id': {'firstName': 'Alvin', 'id': 'jacksal01', 'lastname': 'Jackson'},
#  'points': 0}
# {'_id': {'firstName': 'Guy', 'id': 'ruckegu01', 'lastname': 'Rucker'},
#  'points': 0}
# {'_id': {'firstName': 'Kenneth', 'id': 'rohloke01', 'lastname': 'Rohloff'},
#  'points': 0}
# {'_id': {'firstName': 'Chester', 'id': 'mcnabch01', 'lastname': 'McNabb'},
#  'points': 0}
# {'_id': {'firstName': 'Penny', 'id': 'earlype01', 'lastname': 'Early (Hill)'},
#  'points': 0}
# {'_id': {'firstName': 'Chester', 'id': 'strumch01', 'lastname': 'Strumillo'},
#  'points': 0}
# {'_id': {'firstName': 'JamesOn', 'id': 'curryja01', 'lastname': 'Curry'},
#  'points': 0}
# {'_id': {'firstName': 'Robert', 'id': 'weigabo01', 'lastname': 'Weigandt'},
#  'points': 0}
# {'_id': {'firstName': 'Tony', 'id': 'dibarto01', 'lastname': 'DiBartolo'},
#  'points': 0}
# {'_id': {'firstName': 'Lou', 'id': 'fitzglo01', 'lastname': 'Fitzgerald'},
#  'points': 0}
# {'_id': {'firstName': 'Maurice', 'id': 'bakerma01', 'lastname': 'Baker'},
#  'points': 0}
# {'_id': {'firstName': 'Charles', 'id': 'parksch01', 'lastname': 'Parks'},
#  'points': 0}
# {'_id': {'firstName': 'Bob', 'id': 'armstbo02', 'lastname': 'Armstrong'},
#  'points': 0}
# {'_id': {'firstName': 'Carl', 'id': 'bruchca01', 'lastname': 'Bruch'},
#  'points': 0}
# {'_id': {'firstName': 'William', 'id': 'krallbi01', 'lastname': 'Krall'},
#  'points': 0}
# {'_id': {'firstName': 'Ken', 'id': 'walteke01', 'lastname': 'Walters'},
#  'points': 0}
# {'_id': {'firstName': 'Cedric', 'id': 'huntece01', 'lastname': 'Hunter'},
#  'points': 0}
# {'_id': {'firstName': 'Alex', 'id': 'scaleal01', 'lastname': 'Scales'},
#  'points': 0}
# {'_id': {'firstName': '', 'id': 'mcnam01', 'lastname': 'McNamara'}, 'points': 0}
# {'_id': {'firstName': 'Donald', 'id': 'eliasdo01', 'lastname': 'Eliason'},
#  'points': 0}
# {'_id': {'firstName': 'Ron', 'id': 'sanforo01', 'lastname': 'Sanford'},
#  'points': 0}
# {'_id': {'firstName': 'Willie', 'id': 'youngwi01', 'lastname': 'Young'},
#  'points': 0}
# {'_id': {'firstName': 'Mike', 'id': 'champmi01', 'lastname': 'Champion'},
#  'points': 0}
# {'_id': {'firstName': 'Frank', 'id': 'vukosfr01', 'lastname': 'Vukosic'},
#  'points': 0}
# {'_id': {'firstName': 'Eddie', 'id': 'wolleed01', 'lastname': 'Wollen'},
#  'points': 0}
# {'_id': {'firstName': 'Bob', 'id': 'phillbo02', 'lastname': 'Phillips'},
#  'points': 0}
# {'_id': {'firstName': 'Jonathan', 'id': 'kernejo01', 'lastname': 'Kerner'},
#  'points': 0}
# {'_id': {'firstName': '', 'id': 'wille01', 'lastname': 'Willett'}, 'points': 0}
# {'_id': {'firstName': 'Carl', 'id': 'baerca01', 'lastname': 'Baer'},
#  'points': 0}
# {'_id': {'firstName': 'Joel', 'id': 'masonjo01', 'lastname': 'Mason'},
#  'points': 0}
# {'_id': {'firstName': 'Martynas',
#          'id': 'andrima01',
#          'lastname': 'Andriuskevicius'},
#  'points': 0}
# {'_id': {'firstName': 'John', 'id': 'lenhajo01', 'lastname': 'Lenhart'},
#  'points': 0}
# {'_id': {'firstName': 'Hugh', 'id': 'cartehu01', 'lastname': 'Carter'},
#  'points': 0}

# %%
listName
# Out:
# ['nixonno01',
#  'ratlith01',
#  'kenonla01',
#  'kirilan01',
#  'davisda01',
#  'barnedi01',
#  'dumarjo01',
#  'dantlad01',
#  'busedo01',
#  'cassesa01',
#  'armstbj01',
#  'hillty01',
#  'gallaha01',
#  'govange01',
#  'bridgbi01',
#  'howarju01',
#  'hudsolo01',
#  'johnske01',
#  'kojisdo01',
#  'kingji01',
#  'bingda01',
#  'leverfa01',
#  'barryri01',
#  'gasolpa01',
#  'jackslu01',
#  'mcglojo01',
#  'mchalke01',
#  'meschto01',
#  'mullich01',
#  'mcdanji01',
#  'brianfr01',
#  'mikange01',
#  'jordami01',
#  'floydsl01',
#  'brownfr01',
#  'moncrsi01',
#  'pollaji01',
#  'robinda01',
#  'russeca02',
#  'gervige01',
#  'abdursh01',
#  'paulch01',
#  'reedwi01',
#  'roberos01',
#  'silasja01',
#  'joneswi01',
#  'sikmaja01',
#  'stoudam01',
#  'vergabo01',
#  'hardati01',
#  'reganri01',
#  'scolafr01',
#  'walkeji01',
#  'wallara01',
#  'grangda01',
#  'embrywa01',
#  'pippesc01',
#  'theusre01',
#  'larusru01',
#  'beckear01',
#  'cliftna01',
#  'mcgratr01',
#  'lucasje01',
#  'scottch01',
#  'terrycl01',
#  'jonesed01',
#  'phillan01',
#  'rondora01',
#  'wisewi01',
#  'birdsot01',
#  'jonesla01',
#  'brandel01',
#  'finlemi01',
#  'johnsla01',
#  'wickssi01',
#  'rosede01',
#  'malonka01',
#  'marbust01',
#  'mournal01',
#  'gilmoar01',
#  'robincl02',
#  'clarkar01',
#  'cartege01',
#  'cebalce01',
#  'masonan01',
#  'sprewla01',
#  'walthpa01',
#  'abdulka01',
#  'ewingpa01',
#  'vandeki01',
#  'vanlino01',
#  'blaylmo01',
#  'smithad01',
#  'bakervi01',
#  'barklch01',
#  'barksdo01',
#  'imhofda01',
#  'greenmi01',
#  'macaued01',
#  'russeca01',
#  'schaufr01',
#  'twymaja01',
#  'wanzebo01',
#  'zasloma01',
#  'searske01',
#  'felixra01',
#  'freemdo01',
#  'olajuha01',
#  'tomjaru01',
#  'lovelcl01',
#  'arizipa01',
#  'mcclate01',
#  'colemde01',
#  'cartevi01',
#  'iversal01',
#  'priceji01',
#  'sampsra01',
#  'keyeju01',
#  'leecl01',
#  'barnema01',
#  'boshch01',
#  'hawkihe01',
#  'rochare01',
#  'jonessa01',
#  'somerwi01',
#  'tartle01',
#  'cheniph01',
#  'horfoal01',
#  'ervinju01',
#  'mcginge01',
#  'russebi01',
#  'thurmna01',
#  'smithst01',
#  'billuch01',
#  'reddmi01',
#  'heinsto01',
#  'vanardi01',
#  'whitejo01',
#  'aingeda01',
#  'parketo01',
#  'hundlro01',
#  'webbech01',
#  'georgja01',
#  'millebr01',
#  'gerargu01',
#  'jonesca01',
#  'carrau01',
#  'brownro01',
#  'cummite01',
#  'harribo02',
#  'mcdyean01',
#  'oaklech01',
#  'waltobi01',
#  'mutomdi01',
#  'mitchmi01',
#  'borylvi01',
#  'hollili01',
#  'collido01',
#  'kauffbo01',
#  'petrige01',
#  'davisba01',
#  'daviswa02',
#  'braunca01',
#  'laniebo01',
#  'mullije01',
#  'randoza01',
#  'hayesel01',
#  'roundda01',
#  'beardbu01',
#  'brownro02',
#  'hornaje01',
#  'westje01',
#  'kempsh01',
#  'onealje01',
#  'willide01',
#  'malonje01',
#  'noblech01',
#  'pricema01',
#  'westppa01',
#  'willike01',
#  'buncela01',
#  'hawkico01',
#  'gueriri01',
#  'johnsma02',
#  'foustla01',
#  'martike01',
#  'johnsne02',
#  'houstal01',
#  'tripuke01',
#  'malonmo01',
#  'szczewa01',
#  'richmmi01',
#  'roybr01',
#  'westda01',
#  'nancela01',
#  'chambto01',
#  'howelba01',
#  'colemja01',
#  'adamsal01',
#  'johnsed02',
#  'mannida01',
#  'schaydo01',
#  'willibu01',
#  'harride01',
#  'johnsjo02',
#  'willigu01',
#  'laettch01',
#  'anderke01',
#  'drexlcl01',
#  'freewo01',
#  'millere01',
#  'smitsri01',
#  'thompge01',
#  'maravpe01',
#  'lucasma01',
#  'ligongo01',
#  'robingl01',
#  'cheekma01',
#  'combsgl01',
#  'ilgauzy01',
#  'jonesbo01',
#  'divacvl01',
#  'kerrjo01',
#  'lewisfr01',
#  'paxsoji01',
#  'eddledi01',
#  'rodmade01',
#  'daviswa03',
#  'greenac01',
#  'mcadobo01',
#  'selvyfr01',
#  'bryanko01',
#  'huntele01',
#  'hamilri01',
#  'bradlbi01',
#  'greenri01',
#  'onealsh01',
#  'birdla01',
#  'boonero01',
#  'paultbi01',
#  'rulebo01',
#  'stockjo01',
#  'hardaan01',
#  'natersw01',
#  'stojape01',
#  'thomais01',
#  'daughbr01',
#  'hagancl01',
#  'jacksto01',
#  'guglito01',
#  'cousybo01',
#  'johnsne01',
#  'sauldwo01',
#  'sharmbi01',
#  'toneyan01',
#  'willich01',
#  'willich02',
#  'rulanje01',
#  'martisl01',
#  'washitr01',
#  'sloanje01',
#  'isselda01',
#  'sundedo01',
#  'washike01',
#  'yardlge01',
#  'thompda01',
#  'beckby01',
#  'blackro01',
#  'brownla01',
#  'francst01',
#  'lewisra01',
#  'piercri01',
#  'simonwa01',
#  'smithph01',
#  'fulksjo01',
#  'nattca01',
#  'jamesle01',
#  'arenagi01',
#  'gatlich01',
#  'thorpot01',
#  'bellawa01',
#  'anthoca01',
#  'caldwjo01',
#  'gaborbi01',
#  'davisan01',
#  'jacksme01',
#  'ellisda01',
#  'adamsmi01',
#  'ohldo01',
#  'piercpa01',
#  'robbire01',
#  'robinfl01',
#  'cunnibi01',
#  'hightwa01',
#  'archina01',
#  'rowecu01',
#  'schrede01',
#  'kiddja01',
#  'shuege01',
#  'taylobr01',
#  'johnsst03',
#  'simpsra01',
#  'lewismi01',
#  'stackje01',
#  'artesro01',
#  'nowitdi01',
#  'towemo01',
#  'vanarto01',
#  'walkean01',
#  'wedmasc01',
#  'okurme01',
#  'wilkele01',
#  'lewisre01',
#  'grantho01',
#  'mingya01',
#  'willija01',
#  'boozebo01',
#  'haywosp01',
#  'hillgr01',
#  'danieme01',
#  'johnsma01',
#  'cartwbi01',
#  'jonesri01',
#  'leeda02',
#  'mikkeve01',
#  'moorege01',
#  'briskjo01',
#  'barroda01',
#  'shaffle01',
#  'dandrbo01',
#  'jacksma01',
#  'dukeswa01',
#  'mariosh01',
#  'garneke01',
#  'golato01',
#  'jabalwa01',
#  'blockjo01',
#  'eatonma01',
#  'goodrga01',
#  'lovebo01',
#  'brandte01',
#  'beasljo01',
#  'laceysa01',
#  'moedo01',
#  'dampilo01',
#  'butleca01',
#  'carrojo01',
#  'donalja01',
#  'robintr01',
#  'drewjo01',
#  'howardw01',
#  'daviebo01',
#  'silaspa01',
#  'havlijo01',
#  'nashst01',
#  'starkjo01',
#  'vanexni01',
#  'ricegl01',
#  'knighbi01',
#  'dischte01',
#  'wadedw01',
#  'debusda01',
#  'wintebr01',
#  'duncati01',
#  'mcdanxa01',
#  'netolbo01',
#  'roberal01',
#  'monroea01',
#  'fosteji01',
#  'ladnewe01',
#  'eakinji01',
#  'chambwi01',
#  'smithra01',
#  'stokema01',
#  'greenjo01',
#  'mixst01',
#  'willima01',
#  'wallabe01',
#  'johnsgu01',
#  'walkech01',
#  'carrida01',
#  'kamanch01',
#  'magloja01',
#  'wallage01',
#  'fraziwa01',
#  'barnhle01',
#  'rodgegu01',
#  'menyade01',
#  'naullwi01',
#  'milesed01',
#  'costela01',
#  'marinja01',
#  'paytoga01',
#  'chapple01',
#  'elliose01',
#  'johnsde01',
#  'portete01',
#  'majerda01',
#  'allenra02',
#  'laimbbi01',
#  'englial01',
#  'jonesst01',
#  'mahafra01',
#  'riverdo01',
#  'warlebe01',
#  'mashbja01',
#  'beatyze01',
#  'pettibo01',
#  'powelci01',
#  'sheltlo01',
#  'worthja01',
#  'seymopa01',
#  'richami01',
#  'risenar01',
#  'parisro01',
#  'duranke01',
#  'hutchme01',
#  'beardra01',
#  'grozaal01',
#  'vaughch01',
#  'thoresk01',
#  'jamisan01',
#  'bayloel01',
#  'johnsjo01',
#  'ginobem01',
#  'cowenda01',
#  'boozeca01',
#  'murphca01',
#  'howarjo01',
#  'aguirma01',
#  'twardda01',
#  'garmadi01',
#  'wilkeja01',
#  'wilkido01',
#  'calvima01',
#  'jonesji01',
#  'davisle01',
#  'unselwe01',
#  'melchbi01',
#  'kingbe01',
#  'duckwke01',
#  'mcguidi01',
#  'greerha01']

# %%
temp = db.collection_players_teams.aggregate([
        {"$match":{"playerID._id":{"$nin": listName}}},
        {"$group":{"_id":{"id": "$playerID._id","firstName":"$playerID.firstName","lastname":"$playerID.lastName"},"points":{"$sum":"$points"}}},
        {"$project":{"_id":1,"points":1}},
        {"$sort":{"points":-1}},
        ])

# %%
for i in temp:
    pprint(i)
# Out:
# {'_id': {'firstName': 'Edward', 'id': 'johnsed03', 'lastname': 'Johnson'},
#  'points': 19202}
# {'_id': {'firstName': 'Kevin', 'id': 'willike02', 'lastname': 'Willis'},
#  'points': 17253}
# {'_id': {'firstName': 'Jason', 'id': 'terryja01', 'lastname': 'Terry'},
#  'points': 16487}
# {'_id': {'firstName': 'Derek', 'id': 'harpede01', 'lastname': 'Harper'},
#  'points': 16006}
# {'_id': {'firstName': 'Samuel', 'id': 'perkisa01', 'lastname': 'Perkins'},
#  'points': 15324}
# {'_id': {'firstName': 'Antoine', 'id': 'walkean02', 'lastname': 'Walker'},
#  'points': 15279}
# {'_id': {'firstName': 'Byron', 'id': 'scottby01', 'lastname': 'Scott'},
#  'points': 15097}
# {'_id': {'firstName': 'Rashard', 'id': 'lewisra02', 'lastname': 'Lewis'},
#  'points': 15026}
# {'_id': {'firstName': 'James', 'id': 'edwarja01', 'lastname': 'Edwards'},
#  'points': 14862}
# {'_id': {'firstName': 'Andre', 'id': 'millean02', 'lastname': 'Miller'},
#  'points': 14710}
# {'_id': {'firstName': 'Michael', 'id': 'bibbymi01', 'lastname': 'Bibby'},
#  'points': 14698}
# {'_id': {'firstName': 'Purvis', 'id': 'shortpu01', 'lastname': 'Short'},
#  'points': 14607}
# {'_id': {'firstName': 'Rodney', 'id': 'stricro02', 'lastname': 'Strickland'},
#  'points': 14463}
# {'_id': {'firstName': 'Jason', 'id': 'richaja01', 'lastname': 'Richardson'},
#  'points': 14125}
# {'_id': {'firstName': 'Eddie', 'id': 'jonesed02', 'lastname': 'Jones'},
#  'points': 13979}
# {'_id': {'firstName': 'Ronald', 'id': 'harpero01', 'lastname': 'Harper'},
#  'points': 13910}
# {'_id': {'firstName': 'Chuck', 'id': 'persoch01', 'lastname': 'Person'},
#  'points': 13858}
# {'_id': {'firstName': 'Orlando', 'id': 'woolror01', 'lastname': 'Woolridge'},
#  'points': 13623}
# {'_id': {'firstName': 'Jalen', 'id': 'roseja01', 'lastname': 'Rose'},
#  'points': 13220}
# {'_id': {'firstName': 'Kevin', 'id': 'johnske02', 'lastname': 'Johnson'},
#  'points': 13127}
# {'_id': {'firstName': 'Corey', 'id': 'maggeco01', 'lastname': 'Maggette'},
#  'points': 13103}
# {'_id': {'firstName': 'Albert', 'id': 'harrial01', 'lastname': 'Harrington'},
#  'points': 12961}
# {'_id': {'firstName': 'Kendall', 'id': 'gillke01', 'lastname': 'Gill'},
#  'points': 12914}
# {'_id': {'firstName': 'Wayman', 'id': 'tisdawa01', 'lastname': 'Tisdale'},
#  'points': 12878}
# {'_id': {'firstName': 'Mychal', 'id': 'thompmy01', 'lastname': 'Thompson'},
#  'points': 12810}
# {'_id': {'firstName': 'Wallace', 'id': 'johnsmi01', 'lastname': 'Johnson'},
#  'points': 12748}
# {'_id': {'firstName': 'John', 'id': 'newmajo01', 'lastname': 'Newman'},
#  'points': 12740}
# {'_id': {'firstName': 'Armen', 'id': 'gilliar01', 'lastname': 'Gilliam'},
#  'points': 12700}
# {'_id': {'firstName': 'James', 'id': 'jacksji01', 'lastname': 'Jackson'},
#  'points': 12690}
# {'_id': {'firstName': 'Wardell', 'id': 'curryde01', 'lastname': 'Curry'},
#  'points': 12670}
# {'_id': {'firstName': 'Stephen', 'id': 'jacksst02', 'lastname': 'Jackson'},
#  'points': 12620}
# {'_id': {'firstName': 'Richard', 'id': 'jefferi01', 'lastname': 'Jefferson'},
#  'points': 12577}
# {'_id': {'firstName': 'Michael', 'id': 'newlimi01', 'lastname': 'Newlin'},
#  'points': 12507}
# {'_id': {'firstName': 'Lamar', 'id': 'odomla01', 'lastname': 'Odom'},
#  'points': 12451}
# {'_id': {'firstName': 'Aaron', 'id': 'crawfja01', 'lastname': 'Crawford'},
#  'points': 12409}
# {'_id': {'firstName': 'Darrell', 'id': 'griffda01', 'lastname': 'Griffith'},
#  'points': 12391}
# {'_id': {'firstName': 'John', 'id': 'longjo01', 'lastname': 'Long'},
#  'points': 12131}
# {'_id': {'firstName': 'Frederick', 'id': 'lewisfr02', 'lastname': 'Lewis'},
#  'points': 12033}
# {'_id': {'firstName': 'Cuttino', 'id': 'moblecu01', 'lastname': 'Mobley'},
#  'points': 11964}
# {'_id': {'firstName': 'Herbert', 'id': 'willihe01', 'lastname': 'Williams'},
#  'points': 11944}
# {'_id': {'firstName': 'David', 'id': 'wesleda01', 'lastname': 'Wesley'},
#  'points': 11842}
# {'_id': {'firstName': 'Thurl', 'id': 'baileth01', 'lastname': 'Bailey'},
#  'points': 11834}
# {'_id': {'firstName': 'Jerome', 'id': 'kerseje01', 'lastname': 'Kersey'},
#  'points': 11825}
# {'_id': {'firstName': 'Vincent', 'id': 'johnsvi01', 'lastname': 'Johnson'},
#  'points': 11825}
# {'_id': {'firstName': 'Damon', 'id': 'stoudda01', 'lastname': 'Stoudamire'},
#  'points': 11763}
# {'_id': {'firstName': 'Richard', 'id': 'snydedi01', 'lastname': 'Snyder'},
#  'points': 11755}
# {'_id': {'firstName': 'Gerald', 'id': 'wilkige01', 'lastname': 'Wilkins'},
#  'points': 11736}
# {'_id': {'firstName': 'John', 'id': 'scottra01', 'lastname': 'Scott'},
#  'points': 11629}
# {'_id': {'firstName': 'Kevin', 'id': 'loughke01', 'lastname': 'Loughery'},
#  'points': 11575}
# {'_id': {'firstName': 'Nelison', 'id': 'anderni01', 'lastname': 'Anderson'},
#  'points': 11529}
# {'_id': {'firstName': 'Ulysses', 'id': 'bridgju01', 'lastname': 'Bridgeman'},
#  'points': 11517}
# {'_id': {'firstName': 'Harold', 'id': 'hairsha01', 'lastname': 'Hairston'},
#  'points': 11505}
# {'_id': {'firstName': 'Larry', 'id': 'johnsla02', 'lastname': 'Johnson'},
#  'points': 11450}
# {'_id': {'firstName': 'Joseph', 'id': 'smithjo02', 'lastname': 'Smith'},
#  'points': 11203}
# {'_id': {'firstName': 'James', 'id': 'paxsoji02', 'lastname': 'Paxson'},
#  'points': 11199}
# {'_id': {'firstName': 'Michael', 'id': 'woodsmi01', 'lastname': 'Woodson'},
#  'points': 10981}
# {'_id': {'firstName': 'Michael', 'id': 'gminsmi01', 'lastname': 'Gminski'},
#  'points': 10953}
# {'_id': {'firstName': 'Vernon', 'id': 'maxweve01', 'lastname': 'Maxwell'},
#  'points': 10912}
# {'_id': {'firstName': 'Ricky', 'id': 'soberri01', 'lastname': 'Sobers'},
#  'points': 10902}
# {'_id': {'firstName': 'Donald', 'id': 'nelsodo01', 'lastname': 'Nelson'},
#  'points': 10898}
# {'_id': {'firstName': 'Robert', 'id': 'smithbi02', 'lastname': 'Smith'},
#  'points': 10882}
# {'_id': {'firstName': 'Clifford', 'id': 'robincl01', 'lastname': 'Robinson'},
#  'points': 10823}
# {'_id': {'firstName': 'Elden', 'id': 'campbel01', 'lastname': 'Campbell'},
#  'points': 10805}
# {'_id': {'firstName': 'Donyell', 'id': 'marshdo01', 'lastname': 'Marshall'},
#  'points': 10716}
# {'_id': {'firstName': 'Hidayet', 'id': 'turkohe01', 'lastname': 'Turkoglu'},
#  'points': 10643}
# {'_id': {'firstName': 'David', 'id': 'robisda01', 'lastname': 'Robisch'},
#  'points': 10581}
# {'_id': {'firstName': 'Stewart', 'id': 'johnsst01', 'lastname': 'Johnson'},
#  'points': 10538}
# {'_id': {'firstName': 'Clarence',
#          'id': 'weathcl01',
#          'lastname': 'Weatherspoon'},
#  'points': 10483}
# {'_id': {'firstName': 'Cedric', 'id': 'maxwece01', 'lastname': 'Maxwell'},
#  'points': 10465}
# {'_id': {'firstName': 'Robert', 'id': 'reidro01', 'lastname': 'Reid'},
#  'points': 10448}
# {'_id': {'firstName': 'Derrick', 'id': 'mckeyde01', 'lastname': 'McKey'},
#  'points': 10266}
# {'_id': {'firstName': 'Larry', 'id': 'hughela01', 'lastname': 'Hughes'},
#  'points': 10242}
# {'_id': {'firstName': 'Leroy', 'id': 'ellisle01', 'lastname': 'Ellis'},
#  'points': 10176}
# {'_id': {'firstName': 'Thomas', 'id': 'willira01', 'lastname': 'Williams'},
#  'points': 10158}
# {'_id': {'firstName': 'Vern', 'id': 'flemive01', 'lastname': 'Fleming'},
#  'points': 10125}
# {'_id': {'firstName': 'Derek', 'id': 'fishede01', 'lastname': 'Fisher'},
#  'points': 10113}
# {'_id': {'firstName': 'Rony', 'id': 'seikaro01', 'lastname': 'Seikaly'},
#  'points': 9991}
# {'_id': {'firstName': 'Gregory', 'id': 'ballagr01', 'lastname': 'Ballard'},
#  'points': 9953}
# {'_id': {'firstName': 'John', 'id': 'lucasjo01', 'lastname': 'Lucas'},
#  'points': 9953}
# {'_id': {'firstName': 'Michael', 'id': 'millemi01', 'lastname': 'Miller'},
#  'points': 9913}
# {'_id': {'firstName': 'Tyree', 'id': 'davisri01', 'lastname': 'Davis'},
#  'points': 9912}
# {'_id': {'firstName': 'Thomas', 'id': 'owensto01', 'lastname': 'Owens'},
#  'points': 9898}
# {'_id': {'firstName': 'Collier', 'id': 'brownpj01', 'lastname': 'Brown'},
#  'points': 9870}
# {'_id': {'firstName': 'James', 'id': 'choneji01', 'lastname': 'Chones'},
#  'points': 9821}
# {'_id': {'firstName': 'Toni', 'id': 'kukocto01', 'lastname': 'Kukoc'},
#  'points': 9810}
# {'_id': {'firstName': 'Benjamin', 'id': 'gordobe01', 'lastname': 'Gordon'},
#  'points': 9796}
# {'_id': {'firstName': 'John', 'id': 'williho01', 'lastname': 'Williams'},
#  'points': 9784}
# {'_id': {'firstName': 'Tyrone', 'id': 'corbity01', 'lastname': 'Corbin'},
#  'points': 9766}
# {'_id': {'firstName': 'Rex', 'id': 'chapmre01', 'lastname': 'Chapman'},
#  'points': 9731}
# {'_id': {'firstName': 'Johnny', 'id': 'davisjo01', 'lastname': 'Davis'},
#  'points': 9710}
# {'_id': {'firstName': 'Grant', 'id': 'longgr01', 'lastname': 'Long'},
#  'points': 9518}
# {'_id': {'firstName': 'Joseph', 'id': 'grabojo01', 'lastname': 'Graboski'},
#  'points': 9503}
# {'_id': {'firstName': 'Rodney', 'id': 'rogerro01', 'lastname': 'Rogers'},
#  'points': 9468}
# {'_id': {'firstName': 'Timothy', 'id': 'thomati01', 'lastname': 'Thomas'},
#  'points': 9454}
# {'_id': {'firstName': 'Andre', 'id': 'iguodan01', 'lastname': 'Iguodala'},
#  'points': 9422}
# {'_id': {'firstName': 'Lucius', 'id': 'allenlu01', 'lastname': 'Allen'},
#  'points': 9407}
# {'_id': {'firstName': 'Isaiah', 'id': 'rideris01', 'lastname': 'Rider'},
#  'points': 9405}
# {'_id': {'firstName': 'Kenneth', 'id': 'smithke01', 'lastname': 'Smith'},
#  'points': 9397}
# {'_id': {'firstName': 'Sedale', 'id': 'threase01', 'lastname': 'Threatt'},
#  'points': 9327}
# {'_id': {'firstName': 'Tayshaun', 'id': 'princta01', 'lastname': 'Prince'},
#  'points': 9311}
# {'_id': {'firstName': 'Douglas', 'id': 'chrisdo01', 'lastname': 'Christie'},
#  'points': 9301}
# {'_id': {'firstName': 'Frederick', 'id': 'cartefr01', 'lastname': 'Carter'},
#  'points': 9271}
# {'_id': {'firstName': 'Lenard', 'id': 'benjabe01', 'lastname': 'Benjamin'},
#  'points': 9223}
# {'_id': {'firstName': 'Marcus', 'id': 'cambyma01', 'lastname': 'Camby'},
#  'points': 9222}
# {'_id': {'firstName': 'Keith', 'id': 'vanhoke01', 'lastname': 'Van Horn'},
#  'points': 9206}
# {'_id': {'firstName': 'Walter', 'id': 'szczewa02', 'lastname': 'Szczerbiak'},
#  'points': 9189}
# {'_id': {'firstName': 'Antoine', 'id': 'carran01', 'lastname': 'Carr'},
#  'points': 9176}
# {'_id': {'firstName': 'Corliss', 'id': 'willico02', 'lastname': 'Williamson'},
#  'points': 9147}
# {'_id': {'firstName': 'Mahdi', 'id': 'abdulma01', 'lastname': 'Abdul-Rahman'},
#  'points': 9087}
# {'_id': {'firstName': 'Joshua', 'id': 'smithjo03', 'lastname': 'Smith'},
#  'points': 9044}
# {'_id': {'firstName': 'John', 'id': 'willijo01', 'lastname': 'Williamson'},
#  'points': 9017}
# {'_id': {'firstName': 'Rodney', 'id': 'mccraro01', 'lastname': 'McCray'},
#  'points': 9014}
# {'_id': {'firstName': 'Ulrich', 'id': 'foxri01', 'lastname': 'Fox'},
#  'points': 8966}
# {'_id': {'firstName': 'Mark', 'id': 'olberma01', 'lastname': 'Olberding'},
#  'points': 8940}
# {'_id': {'firstName': 'Al', 'id': 'jeffeal01', 'lastname': 'Jefferson'},
#  'points': 8927}
# {'_id': {'firstName': 'Kurt', 'id': 'thomaku01', 'lastname': 'Thomas'},
#  'points': 8876}
# {'_id': {'firstName': 'Terry', 'id': 'tylerte01', 'lastname': 'Tyler'},
#  'points': 8868}
# {'_id': {'firstName': 'Avery', 'id': 'johnsav01', 'lastname': 'Johnson'},
#  'points': 8817}
# {'_id': {'firstName': 'Daniel', 'id': 'schayda01', 'lastname': 'Schayes'},
#  'points': 8780}
# {'_id': {'firstName': 'John', 'id': 'humphja01', 'lastname': 'Humphries'},
#  'points': 8772}
# {'_id': {'firstName': 'Thomas', 'id': 'sandeto01', 'lastname': 'Sanders'},
#  'points': 8766}
# {'_id': {'firstName': 'Clem', 'id': 'haskicl01', 'lastname': 'Haskins'},
#  'points': 8743}
# {'_id': {'firstName': 'James', 'id': 'mcmilji01', 'lastname': 'McMillian'},
#  'points': 8736}
# {'_id': {'firstName': 'Darryl', 'id': 'dawkida01', 'lastname': 'Dawkins'},
#  'points': 8733}
# {'_id': {'firstName': 'Jay', 'id': 'vinceja01', 'lastname': 'Vincent'},
#  'points': 8729}
# {'_id': {'firstName': 'Kevin', 'id': 'martike02', 'lastname': 'Martin'},
#  'points': 8728}
# {'_id': {'firstName': 'Kenneth', 'id': 'normake01', 'lastname': 'Norman'},
#  'points': 8717}
# {'_id': {'firstName': 'Samuel', 'id': 'mitchsa01', 'lastname': 'Mitchell'},
#  'points': 8636}
# {'_id': {'firstName': 'Luol', 'id': 'denglu01', 'lastname': 'Deng'},
#  'points': 8609}
# {'_id': {'firstName': 'Michael', 'id': 'bantomi01', 'lastname': 'Bantom'},
#  'points': 8568}
# {'_id': {'firstName': 'Mahmoud', 'id': 'abdulma02', 'lastname': 'Abdul-Rauf'},
#  'points': 8553}
# {'_id': {'firstName': 'James', 'id': 'barneji02', 'lastname': 'Barnett'},
#  'points': 8536}
# {'_id': {'firstName': 'Reggie', 'id': 'willire01', 'lastname': 'Williams'},
#  'points': 8520}
# {'_id': {'firstName': 'Brent', 'id': 'barrybr01', 'lastname': 'Barry'},
#  'points': 8488}
# {'_id': {'firstName': 'Wilbert', 'id': 'joneswi02', 'lastname': 'Jones'},
#  'points': 8484}
# {'_id': {'firstName': 'Monta', 'id': 'ellismo01', 'lastname': 'Ellis'},
#  'points': 8457}
# {'_id': {'firstName': 'David', 'id': 'greenda01', 'lastname': 'Greenwood'},
#  'points': 8428}
# {'_id': {'firstName': 'Sherman', 'id': 'douglsh01', 'lastname': 'Douglas'},
#  'points': 8425}
# {'_id': {'firstName': 'Walter', 'id': 'williwa02', 'lastname': 'Williams'},
#  'points': 8385}
# {'_id': {'firstName': 'Frank', 'id': 'ramsefr01', 'lastname': 'Ramsey'},
#  'points': 8378}
# {'_id': {'firstName': 'Lamond', 'id': 'murrala01', 'lastname': 'Murray'},
#  'points': 8286}
# {'_id': {'firstName': 'Michael', 'id': 'cagemi01', 'lastname': 'Cage'},
#  'points': 8278}
# {'_id': {'firstName': 'Jason', 'id': 'willija02', 'lastname': 'Williams'},
#  'points': 8266}
# {'_id': {'firstName': 'Olden', 'id': 'polynol01', 'lastname': 'Polynice'},
#  'points': 8265}
# {'_id': {'firstName': 'Michael', 'id': 'dunlemi02', 'lastname': 'Dunleavy'},
#  'points': 8242}
# {'_id': {'firstName': 'Wesley', 'id': 'persowe01', 'lastname': 'Person'},
#  'points': 8192}
# {'_id': {'firstName': 'Christopher', 'id': 'morrich01', 'lastname': 'Morris'},
#  'points': 8184}
# {'_id': {'firstName': 'James', 'id': 'washiji01', 'lastname': 'Washington'},
#  'points': 8168}
# {'_id': {'firstName': 'Larry', 'id': 'drewla01', 'lastname': 'Drew'},
#  'points': 8110}
# {'_id': {'firstName': 'Charles', 'id': 'smithch01', 'lastname': 'Smith'},
#  'points': 8107}
# {'_id': {'firstName': 'Dennis', 'id': 'scottde01', 'lastname': 'Scott'},
#  'points': 8094}
# {'_id': {'firstName': 'Anthony', 'id': 'webbsp01', 'lastname': 'Webb'},
#  'points': 8072}
# {'_id': {'firstName': 'Andrew', 'id': 'goodedr01', 'lastname': 'Gooden'},
#  'points': 8059}
# {'_id': {'firstName': 'Quentin', 'id': 'richaqu01', 'lastname': 'Richardson'},
#  'points': 8027}
# {'_id': {'firstName': 'Anthony', 'id': 'peelean01', 'lastname': 'Peeler'},
#  'points': 8017}
# {'_id': {'firstName': 'Anthony', 'id': 'campbto01', 'lastname': 'Campbell'},
#  'points': 7994}
# {'_id': {'firstName': 'Stacey', 'id': 'augmost01', 'lastname': 'Augmon'},
#  'points': 7990}
# {'_id': {'firstName': 'Terry', 'id': 'teaglte01', 'lastname': 'Teagle'},
#  'points': 7982}
# {'_id': {'firstName': 'Lindsey', 'id': 'hunteli01', 'lastname': 'Hunter'},
#  'points': 7956}
# {'_id': {'firstName': 'Kirk', 'id': 'hinriki01', 'lastname': 'Hinrich'},
#  'points': 7956}
# {'_id': {'firstName': 'Brian', 'id': 'grantbr01', 'lastname': 'Grant'},
#  'points': 7933}
# {'_id': {'firstName': 'Conrad', 'id': 'dierkco01', 'lastname': 'Dierking'},
#  'points': 7915}
# {'_id': {'firstName': 'Bradley', 'id': 'davisbr01', 'lastname': 'Davis'},
#  'points': 7866}
# {'_id': {'firstName': 'Rudy', 'id': 'gayru01', 'lastname': 'Gay'},
#  'points': 7839}
# {'_id': {'firstName': 'Calbert', 'id': 'cheanca01', 'lastname': 'Cheaney'},
#  'points': 7826}
# {'_id': {'firstName': 'Kenneth', 'id': 'carrke01', 'lastname': 'Carr'},
#  'points': 7813}
# {'_id': {'firstName': 'LaSalle', 'id': 'thompla01', 'lastname': 'Thompson'},
#  'points': 7806}
# {'_id': {'firstName': 'Troy', 'id': 'murphtr01', 'lastname': 'Murphy'},
#  'points': 7792}
# {'_id': {'firstName': 'Harvey', 'id': 'grantha01', 'lastname': 'Grant'},
#  'points': 7781}
# {'_id': {'firstName': 'Artis', 'id': 'coopewa01', 'lastname': 'Cooper'},
#  'points': 7777}
# {'_id': {'firstName': 'Jerome', 'id': 'hendege01', 'lastname': 'Henderson'},
#  'points': 7773}
# {'_id': {'firstName': 'Desmond', 'id': 'masonde01', 'lastname': 'Mason'},
#  'points': 7767}
# {'_id': {'firstName': 'Derrick', 'id': 'mahorri01', 'lastname': 'Mahorn'},
#  'points': 7763}
# {'_id': {'firstName': 'LaMarcus', 'id': 'aldrila01', 'lastname': 'Aldridge'},
#  'points': 7738}
# {'_id': {'firstName': 'Michael', 'id': 'coopemi01', 'lastname': 'Cooper'},
#  'points': 7729}
# {'_id': {'firstName': 'Robert', 'id': 'horryro01', 'lastname': 'Horry'},
#  'points': 7715}
# {'_id': {'firstName': 'Darrell', 'id': 'armstda01', 'lastname': 'Armstrong'},
#  'points': 7712}
# {'_id': {'firstName': 'Nathaniel', 'id': 'willina01', 'lastname': 'Williams'},
#  'points': 7709}
# {'_id': {'firstName': 'Paul', 'id': 'presspa01', 'lastname': 'Pressey'},
#  'points': 7664}
# {'_id': {'firstName': 'Matthew', 'id': 'harprma01', 'lastname': 'Harpring'},
#  'points': 7645}
# {'_id': {'firstName': 'Kevin', 'id': 'porteke01', 'lastname': 'Porter'},
#  'points': 7645}
# {'_id': {'firstName': 'Shane', 'id': 'battish01', 'lastname': 'Battier'},
#  'points': 7638}
# {'_id': {'firstName': 'David', 'id': 'gambeda01', 'lastname': 'Gambee'},
#  'points': 7632}
# {'_id': {'firstName': 'Morris', 'id': 'petermo01', 'lastname': 'Peterson'},
#  'points': 7628}
# {'_id': {'firstName': 'David', 'id': 'corzida01', 'lastname': 'Corzine'},
#  'points': 7615}
# {'_id': {'firstName': 'Theodore', 'id': 'edwarbl01', 'lastname': 'Edwards'},
#  'points': 7585}
# {'_id': {'firstName': 'Rory', 'id': 'sparrro01', 'lastname': 'Sparrow'},
#  'points': 7557}
# {'_id': {'firstName': 'Howard', 'id': 'komivho01', 'lastname': 'Komives'},
#  'points': 7550}
# {'_id': {'firstName': 'Elmore', 'id': 'smithel01', 'lastname': 'Smith'},
#  'points': 7541}
# {'_id': {'firstName': 'Joel', 'id': 'ehlocr01', 'lastname': 'Ehlo'},
#  'points': 7492}
# {'_id': {'firstName': 'Quintin', 'id': 'dailequ01', 'lastname': 'Dailey'},
#  'points': 7470}
# {'_id': {'firstName': 'James', 'id': 'poseyja01', 'lastname': 'Posey'},
#  'points': 7419}
# {'_id': {'firstName': 'LaPhonso', 'id': 'ellisla01', 'lastname': 'Ellis'},
#  'points': 7410}
# {'_id': {'firstName': 'Kevin', 'id': 'greveke01', 'lastname': 'Grevey'},
#  'points': 7364}
# {'_id': {'firstName': 'Derek', 'id': 'anderde01', 'lastname': 'Anderson'},
#  'points': 7357}
# {'_id': {'firstName': 'Leandro', 'id': 'barbole01', 'lastname': 'Barbosa'},
#  'points': 7351}
# {'_id': {'firstName': 'Bobby', 'id': 'jacksbo01', 'lastname': 'Jackson'},
#  'points': 7344}
# {'_id': {'firstName': 'Christopher', 'id': 'fordch01', 'lastname': 'Ford'},
#  'points': 7314}
# {'_id': {'firstName': 'Erick', 'id': 'dampier01', 'lastname': 'Dampier'},
#  'points': 7309}
# {'_id': {'firstName': 'Francis', 'id': 'brickfr01', 'lastname': 'Brickowski'},
#  'points': 7302}
# {'_id': {'firstName': 'Keith', 'id': 'erickke01', 'lastname': 'Erickson'},
#  'points': 7251}
# {'_id': {'firstName': 'Philip', 'id': 'hubbaph01', 'lastname': 'Hubbard'},
#  'points': 7228}
# {'_id': {'firstName': 'Roy', 'id': 'hinsoro01', 'lastname': 'Hinson'},
#  'points': 7206}
# {'_id': {'firstName': 'Terry', 'id': 'millste01', 'lastname': 'Mills'},
#  'points': 7175}
# {'_id': {'firstName': 'John', 'id': 'salmojo01', 'lastname': 'Salmons'},
#  'points': 7175}
# {'_id': {'firstName': 'Kerry', 'id': 'kittlke01', 'lastname': 'Kittles'},
#  'points': 7165}
# {'_id': {'firstName': 'Raymond', 'id': 'feltora01', 'lastname': 'Felton'},
#  'points': 7159}
# {'_id': {'firstName': 'Neal', 'id': 'walkne01', 'lastname': 'Walk'},
#  'points': 7157}
# {'_id': {'firstName': 'Gawen', 'id': 'wellsbo01', 'lastname': 'Wells'},
#  'points': 7147}
# {'_id': {'firstName': 'Jerome', 'id': 'richapo01', 'lastname': 'Richardson'},
#  'points': 7083}
# {'_id': {'firstName': 'Ronald', 'id': 'anderro01', 'lastname': 'Anderson'},
#  'points': 7056}
# {'_id': {'firstName': 'Vincent', 'id': 'delnevi01', 'lastname': 'Del Negro'},
#  'points': 7038}
# {'_id': {'firstName': '', 'id': 'hilarne01', 'lastname': 'Nene'},
#  'points': 7027}
# {'_id': {'firstName': 'Billy', 'id': 'owensbi01', 'lastname': 'Owens'},
#  'points': 7026}
# {'_id': {'firstName': 'Roderick', 'id': 'higgiro01', 'lastname': 'Higgins'},
#  'points': 7011}
# {'_id': {'firstName': 'Raja', 'id': 'bellra01', 'lastname': 'Bell'},
#  'points': 6998}
# {'_id': {'firstName': 'Loy', 'id': 'vaughlo01', 'lastname': 'Vaught'},
#  'points': 6984}
# {'_id': {'firstName': 'Ruben', 'id': 'patteru01', 'lastname': 'Patterson'},
#  'points': 6953}
# {'_id': {'firstName': 'James', 'id': 'foxji01', 'lastname': 'Fox'},
#  'points': 6945}
# {'_id': {'firstName': 'George', 'id': 'mccloge01', 'lastname': 'McCloud'},
#  'points': 6925}
# {'_id': {'firstName': 'Kenneth', 'id': 'atkinch01', 'lastname': 'Atkins'},
#  'points': 6863}
# {'_id': {'firstName': 'Tyrone', 'id': 'boguemu01', 'lastname': 'Bogues'},
#  'points': 6858}
# {'_id': {'firstName': 'Garfield', 'id': 'heardga01', 'lastname': 'Heard'},
#  'points': 6828}
# {'_id': {'firstName': 'Eddy', 'id': 'curryed01', 'lastname': 'Curry'},
#  'points': 6811}
# {'_id': {'firstName': 'Rafer', 'id': 'alstora01', 'lastname': 'Alston'},
#  'points': 6799}
# {'_id': {'firstName': 'Stuart', 'id': 'lantzst01', 'lastname': 'Lantz'},
#  'points': 6782}
# {'_id': {'firstName': 'Willie', 'id': 'anderwi01', 'lastname': 'Anderson'},
#  'points': 6771}
# {'_id': {'firstName': 'Michael', 'id': 'carrml01', 'lastname': 'Carr'},
#  'points': 6759}
# {'_id': {'firstName': 'DeCovan', 'id': 'brownde01', 'lastname': 'Brown'},
#  'points': 6758}
# {'_id': {'firstName': 'Shawn', 'id': 'bradlsh01', 'lastname': 'Bradley'},
#  'points': 6752}
# {'_id': {'firstName': 'Voshon', 'id': 'lenarvo01', 'lastname': 'Lenard'},
#  'points': 6745}
# {'_id': {'firstName': 'Michael', 'id': 'conlemi01', 'lastname': 'Conley'},
#  'points': 6740}
# {'_id': {'firstName': 'Earl', 'id': 'smithjr01', 'lastname': 'Smith'},
#  'points': 6725}
# {'_id': {'firstName': 'Allen', 'id': 'leaveal01', 'lastname': 'Leavell'},
#  'points': 6684}
# {'_id': {'firstName': 'Wali', 'id': 'joneswa02', 'lastname': 'Jones'},
#  'points': 6672}
# {'_id': {'firstName': 'Thomas', 'id': 'hawkito01', 'lastname': 'Hawkins'},
#  'points': 6672}
# {'_id': {'firstName': 'Darnell', 'id': 'hillmda01', 'lastname': 'Hillman'},
#  'points': 6666}
# {'_id': {'firstName': 'Donald', 'id': 'chanedo01', 'lastname': 'Chaney'},
#  'points': 6663}
# {'_id': {'firstName': 'Bryon', 'id': 'russebr01', 'lastname': 'Russell'},
#  'points': 6663}
# {'_id': {'firstName': 'Scott', 'id': 'skilesc01', 'lastname': 'Skiles'},
#  'points': 6652}
# {'_id': {'firstName': 'Vernell', 'id': 'colesbi01', 'lastname': 'Coles'},
#  'points': 6628}
# {'_id': {'firstName': 'Antonio', 'id': 'daniean01', 'lastname': 'Daniels'},
#  'points': 6626}
# {'_id': {'firstName': 'Larry', 'id': 'siegfla01', 'lastname': 'Siegfried'},
#  'points': 6599}
# {'_id': {'firstName': 'Kevin', 'id': 'edwarke01', 'lastname': 'Edwards'},
#  'points': 6596}
# {'_id': {'firstName': 'Lawrence', 'id': 'millela01', 'lastname': 'Miller'},
#  'points': 6595}
# {'_id': {'firstName': 'William', 'id': 'kellebi01', 'lastname': 'Keller'},
#  'points': 6588}
# {'_id': {'firstName': 'Brian', 'id': 'shawbr01', 'lastname': 'Shaw'},
#  'points': 6547}
# {'_id': {'firstName': 'Jameer', 'id': 'nelsoja01', 'lastname': 'Nelson'},
#  'points': 6542}
# {'_id': {'firstName': 'Patrick', 'id': 'cummipa01', 'lastname': 'Cummings'},
#  'points': 6529}
# {'_id': {'firstName': 'Terry', 'id': 'catlete01', 'lastname': 'Catledge'},
#  'points': 6520}
# {'_id': {'firstName': 'Mel', 'id': 'countme01', 'lastname': 'Counts'},
#  'points': 6516}
# {'_id': {'firstName': 'Chukwuemeka', 'id': 'okafoem01', 'lastname': 'Okafor'},
#  'points': 6491}
# {'_id': {'firstName': 'Jeffery', 'id': 'westdo01', 'lastname': 'West'},
#  'points': 6477}
# {'_id': {'firstName': 'Albert', 'id': 'kingal01', 'lastname': 'King'},
#  'points': 6470}
# {'_id': {'firstName': 'Boris', 'id': 'diawbo01', 'lastname': 'Diaw-Riffiod'},
#  'points': 6454}
# {'_id': {'firstName': 'Daniel', 'id': 'ferryda01', 'lastname': 'Ferry'},
#  'points': 6439}
# {'_id': {'firstName': 'Darrell', 'id': 'walkeda01', 'lastname': 'Walker'},
#  'points': 6389}
# {'_id': {'firstName': 'Christopher', 'id': 'millsch01', 'lastname': 'Mills'},
#  'points': 6357}
# {'_id': {'firstName': 'Michael', 'id': 'riordmi01', 'lastname': 'Riordan'},
#  'points': 6334}
# {'_id': {'firstName': 'Alvin', 'id': 'attleal01', 'lastname': 'Attles'},
#  'points': 6328}
# {'_id': {'firstName': 'Kyle', 'id': 'korveky01', 'lastname': 'Korver'},
#  'points': 6307}
# {'_id': {'firstName': 'Lukas', 'id': 'ridnolu01', 'lastname': 'Ridnour'},
#  'points': 6307}
# {'_id': {'firstName': 'Alton', 'id': 'listeal01', 'lastname': 'Lister'},
#  'points': 6298}
# {'_id': {'firstName': 'Mario', 'id': 'eliema01', 'lastname': 'Elie'},
#  'points': 6265}
# {'_id': {'firstName': 'Mark', 'id': 'westma01', 'lastname': 'West'},
#  'points': 6259}
# {'_id': {'firstName': 'Herman', 'id': 'gillihe01', 'lastname': 'Gilliam'},
#  'points': 6252}
# {'_id': {'firstName': 'Wayne', 'id': 'rollitr01', 'lastname': 'Rollins'},
#  'points': 6249}
# {'_id': {'firstName': 'Kelvin', 'id': 'tucketr01', 'lastname': 'Tucker'},
#  'points': 6237}
# {'_id': {'firstName': 'Dwight', 'id': 'jonesdw01', 'lastname': 'Jones'},
#  'points': 6230}
# {'_id': {'firstName': 'John', 'id': 'mengejo01', 'lastname': 'Mengelt'},
#  'points': 6218}
# {'_id': {'firstName': 'Michael', 'id': 'galemi01', 'lastname': 'Gale'},
#  'points': 6203}
# {'_id': {'firstName': 'Richard', 'id': 'kelleri01', 'lastname': 'Kelley'},
#  'points': 6199}
# {'_id': {'firstName': 'Tyson', 'id': 'chandty01', 'lastname': 'Chandler'},
#  'points': 6193}
# {'_id': {'firstName': 'Lorenzen', 'id': 'wrighlo02', 'lastname': 'Wright'},
#  'points': 6191}
# {'_id': {'firstName': 'Michael', 'id': 'bensoke01', 'lastname': 'Benson'},
#  'points': 6168}
# {'_id': {'firstName': 'Kevin', 'id': 'gamblke01', 'lastname': 'Gamble'},
#  'points': 6154}
# {'_id': {'firstName': 'Andrea', 'id': 'bargnan01', 'lastname': 'Bargnani'},
#  'points': 6138}
# {'_id': {'firstName': 'Thomas', 'id': 'hendeto01', 'lastname': 'Henderson'},
#  'points': 6088}
# {'_id': {'firstName': 'Johnny', 'id': 'neumajo01', 'lastname': 'Neumann'},
#  'points': 6022}
# {'_id': {'firstName': 'Robert', 'id': 'weissbo01', 'lastname': 'Weiss'},
#  'points': 5989}
# {'_id': {'firstName': 'Johnny', 'id': 'dawkijo01', 'lastname': 'Dawkins'},
#  'points': 5984}
# {'_id': {'firstName': 'Ronald', 'id': 'brewero01', 'lastname': 'Brewer'},
#  'points': 5971}
# {'_id': {'firstName': 'Frederick', 'id': 'roberfr01', 'lastname': 'Roberts'},
#  'points': 5962}
# {'_id': {'firstName': 'Bryant', 'id': 'stithbr01', 'lastname': 'Stith'},
#  'points': 5946}
# {'_id': {'firstName': 'Tracy', 'id': 'murratr01', 'lastname': 'Murray'},
#  'points': 5943}
# {'_id': {'firstName': 'Craig', 'id': 'hodgecr01', 'lastname': 'Hodges'},
#  'points': 5940}
# {'_id': {'firstName': 'John', 'id': 'barnhjo01', 'lastname': 'Barnhill'},
#  'points': 5937}
# {'_id': {'firstName': 'William', 'id': 'bucknqu01', 'lastname': 'Buckner'},
#  'points': 5929}
# {'_id': {'firstName': 'Russell', 'id': 'westbru01', 'lastname': 'Westbrook'},
#  'points': 5929}
# {'_id': {'firstName': 'Eric', 'id': 'piatker01', 'lastname': 'Piatkowski'},
#  'points': 5919}
# {'_id': {'firstName': 'Todd', 'id': 'dayto01', 'lastname': 'Day'},
#  'points': 5917}
# {'_id': {'firstName': 'Charles', 'id': 'mcmilto01', 'lastname': 'McMillen'},
#  'points': 5914}
# {'_id': {'firstName': 'Larry', 'id': 'smithla01', 'lastname': 'Smith'},
#  'points': 5904}
# {'_id': {'firstName': 'Ronald', 'id': 'mercero01', 'lastname': 'Mercer'},
#  'points': 5892}
# {'_id': {'firstName': 'Maurice', 'id': 'tayloma01', 'lastname': 'Taylor'},
#  'points': 5889}
# {'_id': {'firstName': 'Clifford', 'id': 'levincl01', 'lastname': 'Levingston'},
#  'points': 5888}
# {'_id': {'firstName': 'Kenneth', 'id': 'thomake01', 'lastname': 'Thomas'},
#  'points': 5876}
# {'_id': {'firstName': 'Aaron', 'id': 'mckieaa01', 'lastname': 'McKie'},
#  'points': 5871}
# {'_id': {'firstName': 'Vladimir', 'id': 'radmavl01', 'lastname': 'Radmanovic'},
#  'points': 5848}
# {'_id': {'firstName': 'Samuel', 'id': 'dalemsa01', 'lastname': 'Dalembert'},
#  'points': 5844}
# {'_id': {'firstName': 'Lionel', 'id': 'simmoli01', 'lastname': 'Simmons'},
#  'points': 5833}
# {'_id': {'firstName': 'Clifford', 'id': 'raycl01', 'lastname': 'Ray'},
#  'points': 5821}
# {'_id': {'firstName': 'Darwin', 'id': 'cookda01', 'lastname': 'Cook'},
#  'points': 5820}
# {'_id': {'firstName': 'John', 'id': 'baglejo01', 'lastname': 'Bagley'},
#  'points': 5802}
# {'_id': {'firstName': 'Earl', 'id': 'boykiea01', 'lastname': 'Boykins'},
#  'points': 5791}
# {'_id': {'firstName': 'Eric', 'id': 'snower01', 'lastname': 'Snow'},
#  'points': 5791}
# {'_id': {'firstName': 'Lucious', 'id': 'harrilu01', 'lastname': 'Harris'},
#  'points': 5784}
# {'_id': {'firstName': 'Robert', 'id': 'ferrybo01', 'lastname': 'Ferry'},
#  'points': 5780}
# {'_id': {'firstName': 'Charles', 'id': 'bibbyhe01', 'lastname': 'Bibby'},
#  'points': 5775}
# {'_id': {'firstName': 'Steven', 'id': 'hawesst01', 'lastname': 'Hawes'},
#  'points': 5768}
# {'_id': {'firstName': 'Jack', 'id': 'morelja01', 'lastname': 'Moreland'},
#  'points': 5730}
# {'_id': {'firstName': 'Jarrett', 'id': 'jackja01', 'lastname': 'Jack'},
#  'points': 5726}
# {'_id': {'firstName': 'Raef', 'id': 'lafrera01', 'lastname': 'LaFrentz'},
#  'points': 5690}
# {'_id': {'firstName': 'Herman', 'id': 'reidjr01', 'lastname': 'Reid'},
#  'points': 5680}
# {'_id': {'firstName': 'Udonis', 'id': 'hasleud01', 'lastname': 'Haslem'},
#  'points': 5664}
# {'_id': {'firstName': 'Robert', 'id': 'surabo01', 'lastname': 'Sura'},
#  'points': 5654}
# {'_id': {'firstName': 'DeShawn', 'id': 'stevede01', 'lastname': 'Stevenson'},
#  'points': 5643}
# {'_id': {'firstName': 'Eric', 'id': 'willier01', 'lastname': 'Williams'},
#  'points': 5642}
# {'_id': {'firstName': 'Arvydas', 'id': 'sabonar01', 'lastname': 'Sabonis'},
#  'points': 5629}
# {'_id': {'firstName': 'Otto', 'id': 'mooreot01', 'lastname': 'Moore'},
#  'points': 5616}
# {'_id': {'firstName': 'Marvin', 'id': 'willima02', 'lastname': 'Williams'},
#  'points': 5616}
# {'_id': {'firstName': 'Luis', 'id': 'scolalu01', 'lastname': 'Scola Balvoa'},
#  'points': 5597}
# {'_id': {'firstName': 'Phil', 'id': 'fordph01', 'lastname': 'Ford'},
#  'points': 5594}
# {'_id': {'firstName': 'Hubert', 'id': 'davishu01', 'lastname': 'Davis'},
#  'points': 5583}
# {'_id': {'firstName': 'Michael', 'id': 'jamesmi01', 'lastname': 'James'},
#  'points': 5579}
# {'_id': {'firstName': 'Paul', 'id': 'millspa01', 'lastname': 'Millsap'},
#  'points': 5573}
# {'_id': {'firstName': 'Samuel', 'id': 'bowiesa01', 'lastname': 'Bowie'},
#  'points': 5564}
# {'_id': {'firstName': 'John', 'id': 'paxsojo01', 'lastname': 'Paxson'},
#  'points': 5560}
# {'_id': {'firstName': 'Alfred', 'id': 'biancal01', 'lastname': 'Bianchi'},
#  'points': 5550}
# {'_id': {'firstName': 'Louis', 'id': 'orrlo01', 'lastname': 'Orr'},
#  'points': 5545}
# {'_id': {'firstName': 'William', 'id': 'robinbi01', 'lastname': 'Robinzine'},
#  'points': 5541}
# {'_id': {'firstName': 'Charlie', 'id': 'villach01', 'lastname': 'Villanueva'},
#  'points': 5525}
# {'_id': {'firstName': 'John', 'id': 'eganjo01', 'lastname': 'Egan'},
#  'points': 5521}
# {'_id': {'firstName': 'Radoslav', 'id': 'nestera01', 'lastname': 'Nesterovic'},
#  'points': 5519}
# {'_id': {'firstName': 'Cornelius', 'id': 'simmoco01', 'lastname': 'Simmons'},
#  'points': 5513}
# {'_id': {'firstName': 'Nazr', 'id': 'mohamna01', 'lastname': 'Mohammed'},
#  'points': 5502}
# {'_id': {'firstName': 'Gregory', 'id': 'anthogr01', 'lastname': 'Anthony'},
#  'points': 5497}
# {'_id': {'firstName': 'Earl', 'id': 'watsoea01', 'lastname': 'Watson'},
#  'points': 5481}
# {'_id': {'firstName': 'Allan', 'id': 'bristal01', 'lastname': 'Bristow'},
#  'points': 5450}
# {'_id': {'firstName': 'Joe', 'id': 'meriwjo01', 'lastname': 'Meriweather'},
#  'points': 5439}
# {'_id': {'firstName': 'Stephen', 'id': 'kerrst01', 'lastname': 'Kerr'},
#  'points': 5437}
# {'_id': {'firstName': 'Arlen', 'id': 'bockhbu01', 'lastname': 'Bockhorn'},
#  'points': 5430}
# {'_id': {'firstName': 'Philip', 'id': 'jacksph01', 'lastname': 'Jackson'},
#  'points': 5428}
# {'_id': {'firstName': 'Robert', 'id': 'wilkebo01', 'lastname': 'Wilkerson'},
#  'points': 5424}
# {'_id': {'firstName': 'Andres', 'id': 'nocioan01', 'lastname': 'Nocioni'},
#  'points': 5414}
# {'_id': {'firstName': 'William', 'id': 'hanzlbi01', 'lastname': 'Hanzlik'},
#  'points': 5414}
# {'_id': {'firstName': 'James', 'id': 'cleamji01', 'lastname': 'Cleamons'},
#  'points': 5412}
# {'_id': {'firstName': 'Darnell', 'id': 'valenda01', 'lastname': 'Valentine'},
#  'points': 5400}
# {'_id': {'firstName': 'Jeffrey', 'id': 'mcinnje01', 'lastname': 'McInnis'},
#  'points': 5396}
# {'_id': {'firstName': 'Kelvin', 'id': 'ranseke01', 'lastname': 'Ransey'},
#  'points': 5380}
# {'_id': {'firstName': 'Edward', 'id': 'pincked01', 'lastname': 'Pinckney'},
#  'points': 5378}
# {'_id': {'firstName': 'Travis', 'id': 'besttr01', 'lastname': 'Best'},
#  'points': 5376}
# {'_id': {'firstName': 'Edward', 'id': 'houseed01', 'lastname': 'House'},
#  'points': 5356}
# {'_id': {'firstName': 'John', 'id': 'rochejo01', 'lastname': 'Roche'},
#  'points': 5345}
# {'_id': {'firstName': 'Brevin', 'id': 'knighbr01', 'lastname': 'Knight'},
#  'points': 5342}
# {'_id': {'firstName': 'Ollie', 'id': 'johnsol01', 'lastname': 'Johnson'},
#  'points': 5341}
# {'_id': {'firstName': 'John', 'id': 'battljo01', 'lastname': 'Battle'},
#  'points': 5338}
# {'_id': {'firstName': 'Shandon', 'id': 'andersh01', 'lastname': 'Anderson'},
#  'points': 5327}
# {'_id': {'firstName': 'Stephen', 'id': 'stipast01', 'lastname': 'Stipanovich'},
#  'points': 5323}
# {'_id': {'firstName': 'John', 'id': 'clemeba01', 'lastname': 'Clemens'},
#  'points': 5312}
# {'_id': {'firstName': 'Eugene', 'id': 'banksge01', 'lastname': 'Banks'},
#  'points': 5305}
# {'_id': {'firstName': 'Emanuel', 'id': 'leaksma01', 'lastname': 'Leaks'},
#  'points': 5302}
# {'_id': {'firstName': 'Bruce', 'id': 'bowenbr01', 'lastname': 'Bowen'},
#  'points': 5290}
# {'_id': {'firstName': 'Brendan', 'id': 'haywobr01', 'lastname': 'Haywood'},
#  'points': 5287}
# {'_id': {'firstName': 'Kyle', 'id': 'macyky01', 'lastname': 'Macy'},
#  'points': 5259}
# {'_id': {'firstName': 'Joseph', 'id': 'bryanjo01', 'lastname': 'Bryant'},
#  'points': 5252}
# {'_id': {'firstName': 'Rasual', 'id': 'butlera01', 'lastname': 'Butler'},
#  'points': 5252}
# {'_id': {'firstName': 'James', 'id': 'baileja01', 'lastname': 'Bailey'},
#  'points': 5246}
# {'_id': {'firstName': 'Derek', 'id': 'smithde02', 'lastname': 'Smith'},
#  'points': 5232}
# {'_id': {'firstName': 'John', 'id': 'sallejo01', 'lastname': 'Salley'},
#  'points': 5228}
# {'_id': {'firstName': 'Othella', 'id': 'harriot01', 'lastname': 'Harrington'},
#  'points': 5212}
# {'_id': {'firstName': 'Eric', 'id': 'moneyer01', 'lastname': 'Money'},
#  'points': 5211}
# {'_id': {'firstName': 'Mitchell', 'id': 'kupchmi01', 'lastname': 'Kupchak'},
#  'points': 5202}
# {'_id': {'firstName': 'Andrew', 'id': 'bogutan01', 'lastname': 'Bogut'},
#  'points': 5179}
# {'_id': {'firstName': 'Beno', 'id': 'udrihbe01', 'lastname': 'Udrih'},
#  'points': 5177}
# {'_id': {'firstName': 'Michael', 'id': 'sandemi01', 'lastname': 'Sanders'},
#  'points': 5162}
# {'_id': {'firstName': 'Louis', 'id': 'willilo02', 'lastname': 'Williams'},
#  'points': 5158}
# {'_id': {'firstName': 'Bobby', 'id': 'phillbo01', 'lastname': 'Phills'},
#  'points': 5153}
# {'_id': {'firstName': 'Coby', 'id': 'dietrco01', 'lastname': 'Dietrick'},
#  'points': 5140}
# {'_id': {'firstName': 'Lewis', 'id': 'lloydle01', 'lastname': 'Lloyd'},
#  'points': 5130}
# {'_id': {'firstName': 'McCoy', 'id': 'mclemmc01', 'lastname': 'McLemore'},
#  'points': 5130}
# {'_id': {'firstName': 'Ernest', 'id': 'grunfer01', 'lastname': 'Grunfeld'},
#  'points': 5124}
# {'_id': {'firstName': 'Blair', 'id': 'rasmubl01', 'lastname': 'Rasmussen'},
#  'points': 5119}
# {'_id': {'firstName': 'John', 'id': 'tresvjo01', 'lastname': 'Tresvant'},
#  'points': 5118}
# {'_id': {'firstName': 'Eric', 'id': 'murdoer01', 'lastname': 'Murdock'},
#  'points': 5118}
# {'_id': {'firstName': 'Howard', 'id': 'eisleho01', 'lastname': 'Eisley'},
#  'points': 5116}
# {'_id': {'firstName': 'George', 'id': 'lynchge01', 'lastname': 'Lynch'},
#  'points': 5109}
# {'_id': {'firstName': 'Roland', 'id': 'taylofa01', 'lastname': 'Taylor'},
#  'points': 5098}
# {'_id': {'firstName': 'Alan', 'id': 'hendeal01', 'lastname': 'Henderson'},
#  'points': 5094}
# {'_id': {'firstName': 'Demetrius', 'id': 'battito01', 'lastname': 'Battie'},
#  'points': 5082}
# {'_id': {'firstName': 'Sidney', 'id': 'greensi02', 'lastname': 'Green'},
#  'points': 5080}
# {'_id': {'firstName': 'Matthew', 'id': 'geigema01', 'lastname': 'Geiger'},
#  'points': 5059}
# {'_id': {'firstName': 'Nathaniel', 'id': 'robinna01', 'lastname': 'Robinson'},
#  'points': 5038}
# {'_id': {'firstName': 'Keyon', 'id': 'doolike01', 'lastname': 'Dooling'},
#  'points': 5036}
# {'_id': {'firstName': 'Theodore', 'id': 'dunntr01', 'lastname': 'Dunn'},
#  'points': 5033}
# {'_id': {'firstName': 'Willie', 'id': 'greenwi01', 'lastname': 'Green'},
#  'points': 5030}
# {'_id': {'firstName': 'Rodney', 'id': 'thornro01', 'lastname': 'Thorn'},
#  'points': 5012}
# {'_id': {'firstName': 'K.C.', 'id': 'joneskc01', 'lastname': 'Jones'},
#  'points': 5011}
# {'_id': {'firstName': 'Larry', 'id': 'steella01', 'lastname': 'Steele'},
#  'points': 5009}
# {'_id': {'firstName': 'Malik', 'id': 'rosema01', 'lastname': 'Rose'},
#  'points': 5003}
# {'_id': {'firstName': 'Walter', 'id': 'weslewa01', 'lastname': 'Wesley'},
#  'points': 5002}
# {'_id': {'firstName': 'Paul', 'id': 'neumapa01', 'lastname': 'Neumann'},
#  'points': 4989}
# {'_id': {'firstName': 'Charles', 'id': 'outlabo01', 'lastname': 'Outlaw'},
#  'points': 4970}
# {'_id': {'firstName': 'Michael', 'id': 'mcgeemi01', 'lastname': 'McGee'},
#  'points': 4968}
# {'_id': {'firstName': 'Tony', 'id': 'delkto01', 'lastname': 'Delk'},
#  'points': 4957}
# {'_id': {'firstName': 'Malik', 'id': 'sealyma01', 'lastname': 'Sealy'},
#  'points': 4955}
# {'_id': {'firstName': 'Gregory', 'id': 'andergr01', 'lastname': 'Anderson'},
#  'points': 4953}
# {'_id': {'firstName': 'Bryant', 'id': 'reevebr01', 'lastname': 'Reeves'},
#  'points': 4945}
# {'_id': {'firstName': 'Mark', 'id': 'blounma01', 'lastname': 'Blount'},
#  'points': 4941}
# {'_id': {'firstName': 'Franklin', 'id': 'johnsfr01', 'lastname': 'Johnson'},
#  'points': 4937}
# {'_id': {'firstName': 'Robert', 'id': 'packro01', 'lastname': 'Pack'},
#  'points': 4921}
# {'_id': {'firstName': 'Ryan', 'id': 'gomesry01', 'lastname': 'Gomes'},
#  'points': 4920}
# {'_id': {'firstName': 'Clark', 'id': 'kellocl01', 'lastname': 'Kellogg'},
#  'points': 4918}
# {'_id': {'firstName': 'Martin', 'id': 'woodal01', 'lastname': 'Wood'},
#  'points': 4902}
# {'_id': {'firstName': 'Benedict', 'id': 'poquebe01', 'lastname': 'Poquette'},
#  'points': 4899}
# {'_id': {'firstName': 'Edward', 'id': 'conlied01', 'lastname': 'Conlin'},
#  'points': 4891}
# {'_id': {'firstName': 'Chris', 'id': 'wilcoch01', 'lastname': 'Wilcox'},
#  'points': 4891}
# {'_id': {'firstName': 'John', 'id': 'moorejo01', 'lastname': 'Moore'},
#  'points': 4890}
# {'_id': {'firstName': 'David', 'id': 'stallda01', 'lastname': 'Stallworth'},
#  'points': 4860}
# {'_id': {'firstName': 'Lloyd', 'id': 'nealll01', 'lastname': 'Neal'},
#  'points': 4846}
# {'_id': {'firstName': 'Channing', 'id': 'fryech01', 'lastname': 'Frye'},
#  'points': 4833}
# {'_id': {'firstName': 'Philip', 'id': 'jordoph01', 'lastname': 'Jordon'},
#  'points': 4833}
# {'_id': {'firstName': 'Ronald', 'id': 'murraro01', 'lastname': 'Murray'},
#  'points': 4817}
# {'_id': {'firstName': 'Jack', 'id': 'nichoja01', 'lastname': 'Nichols'},
#  'points': 4806}
# {'_id': {'firstName': 'Winston', 'id': 'garlawi01', 'lastname': 'Garland'},
#  'points': 4799}
# {'_id': {'firstName': 'Ronald', 'id': 'williro01', 'lastname': 'Williams'},
#  'points': 4797}
# {'_id': {'firstName': 'Terrance', 'id': 'fordtj01', 'lastname': 'Ford'},
#  'points': 4797}
# {'_id': {'firstName': 'Ledell', 'id': 'eacklle01', 'lastname': 'Eackles'},
#  'points': 4783}
# {'_id': {'firstName': 'Hakim', 'id': 'warriha01', 'lastname': 'Warrick'},
#  'points': 4753}
# {'_id': {'firstName': 'Randall', 'id': 'dentora01', 'lastname': 'Denton'},
#  'points': 4749}
# {'_id': {'firstName': 'Freeman', 'id': 'willifr01', 'lastname': 'Williams'},
#  'points': 4738}
# {'_id': {'firstName': 'Jose',
#          'id': 'caldejo01',
#          'lastname': 'Calderon Borrallo'},
#  'points': 4735}
# {'_id': {'firstName': 'Ronald', 'id': 'franzro01', 'lastname': 'Franz'},
#  'points': 4733}
# {'_id': {'firstName': 'Nathaniel', 'id': 'mcmilna01', 'lastname': 'McMillan'},
#  'points': 4733}
# {'_id': {'firstName': 'Travis', 'id': 'outlatr01', 'lastname': 'Outlaw'},
#  'points': 4732}
# {'_id': {'firstName': 'Jon', 'id': 'barryjo01', 'lastname': 'Barry'},
#  'points': 4715}
# {'_id': {'firstName': 'Tyronn', 'id': 'luety01', 'lastname': 'Lue'},
#  'points': 4710}
# {'_id': {'firstName': 'Earl', 'id': 'lloydea01', 'lastname': 'Lloyd'},
#  'points': 4682}
# {'_id': {'firstName': 'Sean', 'id': 'rooksse01', 'lastname': 'Rooks'},
#  'points': 4676}
# {'_id': {'firstName': 'Joseph', 'id': 'kleinjo01', 'lastname': 'Kleine'},
#  'points': 4666}
# {'_id': {'firstName': 'Fred', 'id': 'hetzefr01', 'lastname': 'Hetzel'},
#  'points': 4658}
# {'_id': {'firstName': 'Kevin', 'id': 'loveke01', 'lastname': 'Love'},
#  'points': 4649}
# {'_id': {'firstName': 'Troy', 'id': 'hudsotr01', 'lastname': 'Hudson'},
#  'points': 4637}
# {'_id': {'firstName': 'Raimondas',
#          'id': 'marcisa01',
#          'lastname': 'Marciulionis'},
#  'points': 4631}
# {'_id': {'firstName': 'Joseph', 'id': 'ellisjo01', 'lastname': 'Ellis'},
#  'points': 4623}
# {'_id': {'firstName': 'Alfonso', 'id': 'johnsbu01', 'lastname': 'Johnson'},
#  'points': 4617}
# {'_id': {'firstName': 'Darrell', 'id': 'rambiku01', 'lastname': 'Rambis'},
#  'points': 4603}
# {'_id': {'firstName': 'Rodney', 'id': 'stuckro01', 'lastname': 'Stuckey'},
#  'points': 4603}
# {'_id': {'firstName': 'Kevin', 'id': 'kunneke01', 'lastname': 'Kunnert'},
#  'points': 4602}
# {'_id': {'firstName': 'Randall', 'id': 'breuera01', 'lastname': 'Breuer'},
#  'points': 4599}
# {'_id': {'firstName': 'Donald', 'id': 'adamsdo01', 'lastname': 'Adams'},
#  'points': 4598}
# {'_id': {'firstName': 'Andrew', 'id': 'bynuman01', 'lastname': 'Bynum'},
#  'points': 4597}
# {'_id': {'firstName': 'Thomas', 'id': 'boerwto01', 'lastname': 'Boerwinkle'},
#  'points': 4596}
# {'_id': {'firstName': 'Ovinton', 'id': 'mayooj01', 'lastname': 'Mayo'},
#  'points': 4584}
# {'_id': {'firstName': 'Stromile', 'id': 'swiftst01', 'lastname': 'Swift'},
#  'points': 4582}
# {'_id': {'firstName': 'Curtis', 'id': 'perrycu01', 'lastname': 'Perry'},
#  'points': 4578}
# {'_id': {'firstName': 'Robert', 'id': 'grossbo01', 'lastname': 'Gross'},
#  'points': 4567}
# {'_id': {'firstName': 'Marion', 'id': 'spearod01', 'lastname': 'Spears'},
#  'points': 4557}
# {'_id': {'firstName': 'Zaid', 'id': 'abdulza01', 'lastname': 'Abdul-Aziz'},
#  'points': 4557}
# {'_id': {'firstName': 'Bison', 'id': 'delebi01', 'lastname': 'Dele'},
#  'points': 4536}
# {'_id': {'firstName': 'Thaddeus', 'id': 'youngth01', 'lastname': 'Young'},
#  'points': 4534}
# {'_id': {'firstName': 'Micheal', 'id': 'willimi02', 'lastname': 'Williams'},
#  'points': 4533}
# {'_id': {'firstName': 'Michael', 'id': 'evansmi01', 'lastname': 'Evans'},
#  'points': 4531}
# {'_id': {'firstName': 'Mickael', 'id': 'pietrmi01', 'lastname': 'Pietrus'},
#  'points': 4529}
# {'_id': {'firstName': 'Randy', 'id': 'foyera01', 'lastname': 'Foye'},
#  'points': 4513}
# {'_id': {'firstName': 'Darius', 'id': 'milesda01', 'lastname': 'Miles'},
#  'points': 4507}
# {'_id': {'firstName': 'Trevor', 'id': 'arizatr01', 'lastname': 'Ariza'},
#  'points': 4501}
# {'_id': {'firstName': 'Mike', 'id': 'glennmi01', 'lastname': 'Glenn'},
#  'points': 4496}
# {'_id': {'firstName': 'Pervis', 'id': 'ellispe01', 'lastname': 'Ellison'},
#  'points': 4494}
# {'_id': {'firstName': 'Anthony', 'id': 'parkean01', 'lastname': 'Parker'},
#  'points': 4478}
# {'_id': {'firstName': 'Dwight', 'id': 'lamarbo01', 'lastname': 'Lamar'},
#  'points': 4478}
# {'_id': {'firstName': 'Austin', 'id': 'croshau01', 'lastname': 'Croshere'},
#  'points': 4475}
# {'_id': {'firstName': 'Robert', 'id': 'parkeso01', 'lastname': 'Parker'},
#  'points': 4471}
# {'_id': {'firstName': 'Drazen', 'id': 'petrodr01', 'lastname': 'Petrovic'},
#  'points': 4461}
# {'_id': {'firstName': 'George', 'id': 'lehmage01', 'lastname': 'Lehmann'},
#  'points': 4458}
# {'_id': {'firstName': 'William', 'id': 'averibi01', 'lastname': 'Averitt'},
#  'points': 4434}
# {'_id': {'firstName': 'Anthony', 'id': 'johnsan02', 'lastname': 'Johnson'},
#  'points': 4434}
# {'_id': {'firstName': 'Andrew', 'id': 'langan01', 'lastname': 'Lang'},
#  'points': 4431}
# {'_id': {'firstName': 'Jerome', 'id': 'whiteje01', 'lastname': 'Whitehead'},
#  'points': 4423}
# {'_id': {'firstName': 'Jamaal', 'id': 'tinslja01', 'lastname': 'Tinsley'},
#  'points': 4414}
# {'_id': {'firstName': 'John', 'id': 'willijo02', 'lastname': 'Williams'},
#  'points': 4406}
# {'_id': {'firstName': 'Charles', 'id': 'sharech01', 'lastname': 'Share'},
#  'points': 4403}
# {'_id': {'firstName': 'Ira', 'id': 'hargeir01', 'lastname': 'Harge'},
#  'points': 4396}
# {'_id': {'firstName': 'Geoffrey', 'id': 'hustoge01', 'lastname': 'Huston'},
#  'points': 4380}
# {'_id': {'firstName': 'Brook', 'id': 'lopezbr01', 'lastname': 'Lopez'},
#  'points': 4379}
# {'_id': {'firstName': 'Zaur', 'id': 'pachuza01', 'lastname': 'Pachulia'},
#  'points': 4378}
# {'_id': {'firstName': 'George', 'id': 'johnsge02', 'lastname': 'Johnson'},
#  'points': 4369}
# {'_id': {'firstName': 'Gary', 'id': 'grantga01', 'lastname': 'Grant'},
#  'points': 4368}
# {'_id': {'firstName': 'Jeffrey', 'id': 'greenje02', 'lastname': 'Green'},
#  'points': 4367}
# {'_id': {'firstName': 'Gary', 'id': 'trentga01', 'lastname': 'Trent'},
#  'points': 4366}
# {'_id': {'firstName': 'Steven', 'id': 'blakest01', 'lastname': 'Blake'},
#  'points': 4353}
# {'_id': {'firstName': 'Robert', 'id': 'warrebo01', 'lastname': 'Warren'},
#  'points': 4347}
# {'_id': {'firstName': 'Lester', 'id': 'connele01', 'lastname': 'Conner'},
#  'points': 4337}
# {'_id': {'firstName': 'Mark', 'id': 'bryanma01', 'lastname': 'Bryant'},
#  'points': 4313}
# {'_id': {'firstName': 'Marvin', 'id': 'webstma01', 'lastname': 'Webster'},
#  'points': 4302}
# {'_id': {'firstName': 'Damon', 'id': 'jonesda01', 'lastname': 'Jones'},
#  'points': 4299}
# {'_id': {'firstName': 'Matthew', 'id': 'guokama02', 'lastname': 'Guokas'},
#  'points': 4285}
# {'_id': {'firstName': 'Stanley', 'id': 'miasest01', 'lastname': 'Miasek'},
#  'points': 4253}
# {'_id': {'firstName': 'Donald', 'id': 'sidledo01', 'lastname': 'Sidle'},
#  'points': 4247}
# {'_id': {'firstName': 'Charles', 'id': 'johnsch01', 'lastname': 'Johnson'},
#  'points': 4241}
# {'_id': {'firstName': 'Tony', 'id': 'masseto01', 'lastname': 'Massenburg'},
#  'points': 4238}
# {'_id': {'firstName': 'John', 'id': 'mcmahja01', 'lastname': 'McMahon'},
#  'points': 4237}
# {'_id': {'firstName': 'Michael', 'id': 'beaslmi01', 'lastname': 'Beasley'},
#  'points': 4221}
# {'_id': {'firstName': 'George', 'id': 'kingge01', 'lastname': 'King'},
#  'points': 4219}
# {'_id': {'firstName': 'Howard', 'id': 'porteho01', 'lastname': 'Porter'},
#  'points': 4215}
# {'_id': {'firstName': 'George', 'id': 'johnsge03', 'lastname': 'Johnson'},
#  'points': 4214}
# {'_id': {'firstName': 'John', 'id': 'gianejo01', 'lastname': 'Gianelli'},
#  'points': 4210}
# {'_id': {'firstName': 'Nenad', 'id': 'krstine01', 'lastname': 'Krstic'},
#  'points': 4210}
# {'_id': {'firstName': 'William', 'id': 'leonasl01', 'lastname': 'Leonard'},
#  'points': 4204}
# {'_id': {'firstName': 'Clarence', 'id': 'walkefo01', 'lastname': 'Walker'},
#  'points': 4199}
# {'_id': {'firstName': 'Tommy', 'id': 'burleto01', 'lastname': 'Burleson'},
#  'points': 4190}
# {'_id': {'firstName': 'Bobby', 'id': 'simmobo01', 'lastname': 'Simmons'},
#  'points': 4189}
# {'_id': {'firstName': 'Delonte', 'id': 'westde01', 'lastname': 'West'},
#  'points': 4188}
# {'_id': {'firstName': 'Edward', 'id': 'sadowed01', 'lastname': 'Sadowski'},
#  'points': 4171}
# {'_id': {'firstName': 'David', 'id': 'wingada01', 'lastname': 'Wingate'},
#  'points': 4166}
# {'_id': {'firstName': 'Alvin', 'id': 'willial02', 'lastname': 'Williams'},
#  'points': 4161}
# {'_id': {'firstName': 'George', 'id': 'ratkoge01', 'lastname': 'Ratkovicz'},
#  'points': 4157}
# {'_id': {'firstName': 'Nicholas', 'id': 'collini01', 'lastname': 'Collison'},
#  'points': 4149}
# {'_id': {'firstName': 'James', 'id': 'hamiljo01', 'lastname': 'Hamilton'},
#  'points': 4145}
# {'_id': {'firstName': 'Jerry', 'id': 'sichtje01', 'lastname': 'Sichting'},
#  'points': 4141}
# {'_id': {'firstName': 'Michael', 'id': 'olowomi01', 'lastname': 'Olowokandi'},
#  'points': 4135}
# {'_id': {'firstName': 'James', 'id': 'krebsji01', 'lastname': 'Krebs'},
#  'points': 4128}
# {'_id': {'firstName': 'Clarence', 'id': 'brownch01', 'lastname': 'Brown'},
#  'points': 4125}
# {'_id': {'firstName': 'Aaron', 'id': 'williaa01', 'lastname': 'Williams'},
#  'points': 4120}
# {'_id': {'firstName': 'James', 'id': 'mcelrji01', 'lastname': 'McElroy'},
#  'points': 4120}
# ...
#  'points': 2}
# {'_id': {'firstName': 'Bill', 'id': 'summebi01', 'lastname': 'Summers'},
#  'points': 2}
# {'_id': {'firstName': 'David', 'id': 'scholda01', 'lastname': 'Scholz'},
#  'points': 2}
# {'_id': {'firstName': 'George', 'id': 'morsege01', 'lastname': 'Morse'},
#  'points': 2}
# {'_id': {'firstName': 'Trey', 'id': 'gildetr01', 'lastname': 'Gilder'},
#  'points': 2}
# {'_id': {'firstName': 'Richard', 'id': 'dumasri01', 'lastname': 'Dumas'},
#  'points': 2}
# {'_id': {'firstName': 'Warren', 'id': 'switzwa01', 'lastname': 'Switzer'},
#  'points': 2}
# {'_id': {'firstName': 'Dennis', 'id': 'vanzade01', 'lastname': 'Van Zant'},
#  'points': 2}
# {'_id': {'firstName': 'Bill', 'id': 'durkibi01', 'lastname': 'Durkin'},
#  'points': 2}
# {'_id': {'firstName': 'Jack', 'id': 'gilleja01', 'lastname': 'Gillespie'},
#  'points': 2}
# {'_id': {'firstName': 'Matthew', 'id': 'walshma01', 'lastname': 'Walsh'},
#  'points': 2}
# {'_id': {'firstName': 'William', 'id': 'gainebi01', 'lastname': 'Gaines'},
#  'points': 2}
# {'_id': {'firstName': 'George', 'id': 'conlela01', 'lastname': 'Conley'},
#  'points': 2}
# {'_id': {'firstName': 'Beryl', 'id': 'drummbe01', 'lastname': 'Drummond'},
#  'points': 2}
# {'_id': {'firstName': 'Jonathan', 'id': 'smartke01', 'lastname': 'Smart'},
#  'points': 2}
# {'_id': {'firstName': 'Marvin', 'id': 'stoutma01', 'lastname': 'Stout'},
#  'points': 2}
# {'_id': {'firstName': 'Julie', 'id': 'silveju01', 'lastname': 'Silverman'},
#  'points': 2}
# {'_id': {'firstName': 'Harold', 'id': 'jeterha01', 'lastname': 'Jeter'},
#  'points': 2}
# {'_id': {'firstName': 'Isaac', 'id': 'walthis01', 'lastname': 'Walthour'},
#  'points': 2}
# {'_id': {'firstName': 'Mortimer', 'id': 'hillmo01', 'lastname': 'Hill'},
#  'points': 2}
# {'_id': {'firstName': 'James', 'id': 'davisre01', 'lastname': 'Davis'},
#  'points': 2}
# {'_id': {'firstName': 'Carter', 'id': 'orourbu01', 'lastname': "O'Rourke"},
#  'points': 2}
# {'_id': {'firstName': 'Randy', 'id': 'holcora01', 'lastname': 'Holcomb'},
#  'points': 2}
# {'_id': {'firstName': 'Charlie', 'id': 'scrugch01', 'lastname': 'Scruggs'},
#  'points': 2}
# {'_id': {'firstName': 'Eugene', 'id': 'scholge01', 'lastname': 'Scholz'},
#  'points': 2}
# {'_id': {'firstName': 'Garth', 'id': 'josepga01', 'lastname': 'Joseph'},
#  'points': 2}
# {'_id': {'firstName': 'Frank', 'id': 'burksfr01', 'lastname': 'Burks'},
#  'points': 2}
# {'_id': {'firstName': 'Robert', 'id': 'lytlebo01', 'lastname': 'Lytle'},
#  'points': 2}
# {'_id': {'firstName': 'Anthony', 'id': 'jacksto02', 'lastname': 'Jackson'},
#  'points': 2}
# {'_id': {'firstName': 'Roger', 'id': 'powelro01', 'lastname': 'Powell'},
#  'points': 2}
# {'_id': {'firstName': 'Roger', 'id': 'stricro01', 'lastname': 'Strickland'},
#  'points': 2}
# {'_id': {'firstName': 'Thomas', 'id': 'kearnto01', 'lastname': 'Kearns'},
#  'points': 2}
# {'_id': {'firstName': 'Jimmy', 'id': 'joyceji01', 'lastname': 'Joyce'},
#  'points': 1}
# {'_id': {'firstName': 'Robert', 'id': 'naberbo01', 'lastname': 'Naber'},
#  'points': 1}
# {'_id': {'firstName': 'Michael', 'id': 'kearnmi01', 'lastname': 'Kearns'},
#  'points': 1}
# {'_id': {'firstName': 'David', 'id': 'dupeeda01', 'lastname': 'Dupee'},
#  'points': 1}
# {'_id': {'firstName': 'Irving', 'id': 'norenir01', 'lastname': 'Noren'},
#  'points': 1}
# {'_id': {'firstName': 'Frank', 'id': 'beatyfr01', 'lastname': 'Beaty'},
#  'points': 1}
# {'_id': {'firstName': 'Ruben', 'id': 'reiswru01', 'lastname': 'Reiswerg'},
#  'points': 1}
# {'_id': {'firstName': 'Erv', 'id': 'menceer01', 'lastname': 'Mencel'},
#  'points': 1}
# {'_id': {'firstName': 'Bernard', 'id': 'berenbe01', 'lastname': 'Berens'},
#  'points': 1}
# {'_id': {'firstName': 'Paul', 'id': 'duchapa01', 'lastname': 'DuCharme'},
#  'points': 1}
# {'_id': {'firstName': '', 'id': 'leera01', 'lastname': 'Leerah'}, 'points': 1}
# {'_id': {'firstName': 'Jim', 'id': 'higgiji01', 'lastname': 'Higgins'},
#  'points': 1}
# {'_id': {'firstName': 'Sam', 'id': 'liebesa01', 'lastname': 'Lieberman'},
#  'points': 1}
# {'_id': {'firstName': 'Earnest', 'id': 'killuea01', 'lastname': 'Killum'},
#  'points': 1}
# {'_id': {'firstName': 'Thomas', 'id': 'edwarto01', 'lastname': 'Edwards'},
#  'points': 1}
# {'_id': {'firstName': 'Jim', 'id': 'quinlji01', 'lastname': 'Quinlan'},
#  'points': 1}
# {'_id': {'firstName': 'Lewis', 'id': 'spicelo01', 'lastname': 'Spicer'},
#  'points': 1}
# {'_id': {'firstName': 'Raymond', 'id': 'bellira01', 'lastname': 'Bellingham'},
#  'points': 1}
# {'_id': {'firstName': 'Louis', 'id': 'jagnolo01', 'lastname': 'Jagnow'},
#  'points': 1}
# {'_id': {'firstName': 'James', 'id': 'scottja01', 'lastname': 'Scott'},
#  'points': 1}
# {'_id': {'firstName': 'George', 'id': 'brownge01', 'lastname': 'Brown'},
#  'points': 1}
# {'_id': {'firstName': 'Ocie', 'id': 'richioc01', 'lastname': 'Richie'},
#  'points': 1}
# {'_id': {'firstName': 'Ernie', 'id': 'dibener01', 'lastname': 'DiBenedetto'},
#  'points': 1}
# {'_id': {'firstName': 'Harold', 'id': 'cihlaha01', 'lastname': 'Cihlar'},
#  'points': 1}
# {'_id': {'firstName': 'Warren', 'id': 'ajaxwa01', 'lastname': 'Ajax'},
#  'points': 1}
# {'_id': {'firstName': 'Malcolm', 'id': 'thomama01', 'lastname': 'Thomas'},
#  'points': 1}
# {'_id': {'firstName': 'Harmon', 'id': 'walteha01', 'lastname': 'Walters'},
#  'points': 0}
# {'_id': {'firstName': 'Dexter', 'id': 'shousde01', 'lastname': 'Shouse'},
#  'points': 0}
# {'_id': {'firstName': 'Mile', 'id': 'ilicmi01', 'lastname': 'Ilic'},
#  'points': 0}
# {'_id': {'firstName': 'Jack', 'id': 'oxenrja01', 'lastname': 'Oxenrider'},
#  'points': 0}
# {'_id': {'firstName': 'Stephen', 'id': 'fowdyst01', 'lastname': 'Fowdy'},
#  'points': 0}
# {'_id': {'firstName': '', 'id': 'sicky01', 'lastname': 'Sicky'}, 'points': 0}
# {'_id': {'firstName': 'John', 'id': 'sullijo01', 'lastname': 'Sullivan'},
#  'points': 0}
# {'_id': {'firstName': 'Derek', 'id': 'hoodde01', 'lastname': 'Hood'},
#  'points': 0}
# {'_id': {'firstName': 'Jarrett', 'id': 'durhaja01', 'lastname': 'Durham'},
#  'points': 0}
# {'_id': {'firstName': 'Larry', 'id': 'kennela01', 'lastname': 'Kenney'},
#  'points': 0}
# {'_id': {'firstName': 'Terrance', 'id': 'roberte01', 'lastname': 'Roberson'},
#  'points': 0}
# {'_id': {'firstName': 'Raymond', 'id': 'radzira01', 'lastname': 'Radziszewski'},
#  'points': 0}
# {'_id': {'firstName': 'Merle', 'id': 'alexame01', 'lastname': 'Alexander'},
#  'points': 0}
# {'_id': {'firstName': 'Dick', 'id': 'gatesdi01', 'lastname': 'Gates'},
#  'points': 0}
# {'_id': {'firstName': 'Don', 'id': 'cleardo01', 'lastname': 'Cleary'},
#  'points': 0}
# {'_id': {'firstName': 'Garmon', 'id': 'lewisga01', 'lastname': 'Lewis'},
#  'points': 0}
# {'_id': {'firstName': 'Lonnie', 'id': 'kluttlo01', 'lastname': 'Kluttz'},
#  'points': 0}
# {'_id': {'firstName': 'Edgar', 'id': 'saffeju01', 'lastname': 'Saffer'},
#  'points': 0}
# {'_id': {'firstName': 'Norman', 'id': 'grekino01', 'lastname': 'Grekin'},
#  'points': 0}
# {'_id': {'firstName': 'Adam', 'id': 'filipad01', 'lastname': 'Filipczak'},
#  'points': 0}
# {'_id': {'firstName': 'Tom', 'id': 'hovasto01', 'lastname': 'Hovasse'},
#  'points': 0}
# {'_id': {'firstName': 'Gaylord', 'id': 'woltzta01', 'lastname': 'Woltzen'},
#  'points': 0}
# {'_id': {'firstName': 'Edward', 'id': 'beached01', 'lastname': 'Beach'},
#  'points': 0}
# {'_id': {'firstName': '', 'id': 'riski01', 'lastname': 'Riskind'}, 'points': 0}
# {'_id': {'firstName': 'Tom', 'id': 'becketo01', 'lastname': 'Becker'},
#  'points': 0}
# {'_id': {'firstName': 'Bill', 'id': 'cramebi01', 'lastname': 'Cramer'},
#  'points': 0}
# {'_id': {'firstName': 'Pat', 'id': 'kennepa01', 'lastname': 'Kennelly'},
#  'points': 0}
# {'_id': {'firstName': 'Trevor', 'id': 'wintetr01', 'lastname': 'Winter'},
#  'points': 0}
# {'_id': {'firstName': 'Harold', 'id': 'englaha01', 'lastname': 'England'},
#  'points': 0}
# {'_id': {'firstName': 'Leon', 'id': 'brownle01', 'lastname': 'Brown'},
#  'points': 0}
# {'_id': {'firstName': 'Richard', 'id': 'leedi01', 'lastname': 'Lee'},
#  'points': 0}
# {'_id': {'firstName': 'James', 'id': 'mooneji01', 'lastname': 'Mooney'},
#  'points': 0}
# {'_id': {'firstName': 'Forest', 'id': 'ablefo01', 'lastname': 'Able'},
#  'points': 0}
# {'_id': {'firstName': 'Frank', 'id': 'otwayfr01', 'lastname': 'Otway'},
#  'points': 0}
# {'_id': {'firstName': 'Michael', 'id': 'mcdonmi01', 'lastname': 'McDonald'},
#  'points': 0}
# {'_id': {'firstName': 'Max', 'id': 'jamesma01', 'lastname': 'Jameson'},
#  'points': 0}
# {'_id': {'firstName': 'Zano', 'id': 'wastza01', 'lastname': 'Wast'},
#  'points': 0}
# {'_id': {'firstName': 'Norman', 'id': 'bakerno01', 'lastname': 'Baker'},
#  'points': 0}
# {'_id': {'firstName': 'John', 'id': 'pianaja01', 'lastname': 'Piana'},
#  'points': 0}
# {'_id': {'firstName': 'Ibrahim', 'id': 'kutluib01', 'lastname': 'Kutluay'},
#  'points': 0}
# {'_id': {'firstName': 'Brandin', 'id': 'knighbr02', 'lastname': 'Knight'},
#  'points': 0}
# {'_id': {'firstName': 'Paul', 'id': 'anthopa01', 'lastname': 'Anthony'},
#  'points': 0}
# {'_id': {'firstName': 'Vladimir', 'id': 'vranesl01', 'lastname': 'Vranes'},
#  'points': 0}
# {'_id': {'firstName': 'Carl', 'id': 'anderca01', 'lastname': 'Anderson'},
#  'points': 0}
# {'_id': {'firstName': 'Harold', 'id': 'swansha01', 'lastname': 'Swanson'},
#  'points': 0}
# {'_id': {'firstName': '', 'id': 'page01', 'lastname': 'Page'}, 'points': 0}
# {'_id': {'firstName': 'Edward', 'id': 'stegeed01', 'lastname': 'Stege'},
#  'points': 0}
# {'_id': {'firstName': '', 'id': 'hanis01', 'lastname': 'Hanisko'}, 'points': 0}
# {'_id': {'firstName': 'Lou', 'id': 'alixlo01', 'lastname': 'Alix'}, 'points': 0}
# {'_id': {'firstName': 'Abe', 'id': 'youriab01', 'lastname': 'Yourist'},
#  'points': 0}
# {'_id': {'firstName': 'William', 'id': 'downebi01', 'lastname': 'Downey'},
#  'points': 0}
# {'_id': {'firstName': 'LaMark', 'id': 'bakerla01', 'lastname': 'Baker'},
#  'points': 0}
# {'_id': {'firstName': 'Kenneth', 'id': 'corleke01', 'lastname': 'Corley'},
#  'points': 0}
# {'_id': {'firstName': 'Lyle', 'id': 'neatly01', 'lastname': 'Neat'},
#  'points': 0}
# {'_id': {'firstName': 'Ronald', 'id': 'creviro01', 'lastname': 'Crevier'},
#  'points': 0}
# {'_id': {'firstName': 'Gerald', 'id': 'mckeeje01', 'lastname': 'McKee'},
#  'points': 0}
# {'_id': {'firstName': 'Anthony', 'id': 'carpto01', 'lastname': 'Carp'},
#  'points': 0}
# {'_id': {'firstName': 'Gani', 'id': 'lawalga01', 'lastname': 'Lawal'},
#  'points': 0}
# {'_id': {'firstName': 'Tom', 'id': 'otoolto01', 'lastname': "O'Toole"},
#  'points': 0}
# {'_id': {'firstName': 'Emerald', 'id': 'lammebu01', 'lastname': 'Lamme'},
#  'points': 0}
# {'_id': {'firstName': 'Robert', 'id': 'rosero01', 'lastname': 'Rose'},
#  'points': 0}
# {'_id': {'firstName': 'Bill', 'id': 'anderbi01', 'lastname': 'Anderson'},
#  'points': 0}
# {'_id': {'firstName': 'Peter', 'id': 'hecompe01', 'lastname': 'Hecomovich'},
#  'points': 0}
# {'_id': {'firstName': 'Keith', 'id': 'bensoke02', 'lastname': 'Benson'},
#  'points': 0}
# {'_id': {'firstName': 'Harry', 'id': 'joyneha01', 'lastname': 'Joyner'},
#  'points': 0}
# {'_id': {'firstName': 'Louis', 'id': 'pressba01', 'lastname': 'Pressley'},
#  'points': 0}
# {'_id': {'firstName': 'Barry', 'id': 'sumptba01', 'lastname': 'Sumpter'},
#  'points': 0}
# {'_id': {'firstName': 'Ted', 'id': 'straite01', 'lastname': 'Strain'},
#  'points': 0}
# {'_id': {'firstName': 'Deng', 'id': 'gaide01', 'lastname': 'Gai'}, 'points': 0}
# {'_id': {'firstName': 'Larry', 'id': 'sykesla01', 'lastname': 'Sykes'},
#  'points': 0}
# {'_id': {'firstName': 'Bernard', 'id': 'voorhbe01', 'lastname': 'Voorheis'},
#  'points': 0}
# {'_id': {'firstName': '', 'id': 'mille01', 'lastname': 'Miller'}, 'points': 0}
# {'_id': {'firstName': 'Fred', 'id': 'arndtfr01', 'lastname': 'Arndt'},
#  'points': 0}
# {'_id': {'firstName': 'Paul', 'id': 'wallapa01', 'lastname': 'Wallace'},
#  'points': 0}
# {'_id': {'firstName': 'Robert', 'id': 'shaddbo01', 'lastname': 'Shaddock'},
#  'points': 0}
# {'_id': {'firstName': 'Jaak', 'id': 'ardonja01', 'lastname': 'Ardon'},
#  'points': 0}
# {'_id': {'firstName': 'Chris', 'id': 'mccrach01', 'lastname': 'McCray'},
#  'points': 0}
# {'_id': {'firstName': 'Jason', 'id': 'miskija01', 'lastname': 'Miskiri'},
#  'points': 0}
# {'_id': {'firstName': 'George', 'id': 'dayge01', 'lastname': 'Day'},
#  'points': 0}
# {'_id': {'firstName': 'Paul', 'id': 'nolenpa01', 'lastname': 'Nolen'},
#  'points': 0}
# {'_id': {'firstName': 'Gene', 'id': 'lathage02', 'lastname': 'Latham'},
#  'points': 0}
# {'_id': {'firstName': 'Eugene', 'id': 'willige01', 'lastname': 'Williams'},
#  'points': 0}
# {'_id': {'firstName': 'Emmet', 'id': 'birkem01', 'lastname': 'Birk'},
#  'points': 0}
# {'_id': {'firstName': 'Andrew', 'id': 'pankoan01', 'lastname': 'Panko'},
#  'points': 0}
# {'_id': {'firstName': '', 'id': 'morri01', 'lastname': 'Morris'}, 'points': 0}
# {'_id': {'firstName': 'Walter', 'id': 'graumwa01', 'lastname': 'Grauman'},
#  'points': 0}
# {'_id': {'firstName': 'Bill', 'id': 'lanebi01', 'lastname': 'Lane'},
#  'points': 0}
# {'_id': {'firstName': 'Max', 'id': 'biggsma01', 'lastname': 'Biggs'},
#  'points': 0}
# {'_id': {'firstName': 'Don', 'id': 'harvedo02', 'lastname': 'Harvey'},
#  'points': 0}
# {'_id': {'firstName': 'Ken', 'id': 'peterke01', 'lastname': 'Peterson'},
#  'points': 0}
# {'_id': {'firstName': 'Derrick', 'id': 'phelpde01', 'lastname': 'Phelps'},
#  'points': 0}
# {'_id': {'firstName': 'Stanley', 'id': 'washist01', 'lastname': 'Washington'},
#  'points': 0}
# {'_id': {'firstName': 'Marty', 'id': 'cullema01', 'lastname': 'Cullen'},
#  'points': 0}
# {'_id': {'firstName': 'Alvin', 'id': 'jacksal01', 'lastname': 'Jackson'},
#  'points': 0}
# {'_id': {'firstName': 'Guy', 'id': 'ruckegu01', 'lastname': 'Rucker'},
#  'points': 0}
# {'_id': {'firstName': 'Kenneth', 'id': 'rohloke01', 'lastname': 'Rohloff'},
#  'points': 0}
# {'_id': {'firstName': 'Chester', 'id': 'mcnabch01', 'lastname': 'McNabb'},
#  'points': 0}
# {'_id': {'firstName': 'Penny', 'id': 'earlype01', 'lastname': 'Early (Hill)'},
#  'points': 0}
# {'_id': {'firstName': 'Chester', 'id': 'strumch01', 'lastname': 'Strumillo'},
#  'points': 0}
# {'_id': {'firstName': 'JamesOn', 'id': 'curryja01', 'lastname': 'Curry'},
#  'points': 0}
# {'_id': {'firstName': 'Robert', 'id': 'weigabo01', 'lastname': 'Weigandt'},
#  'points': 0}
# {'_id': {'firstName': 'Tony', 'id': 'dibarto01', 'lastname': 'DiBartolo'},
#  'points': 0}
# {'_id': {'firstName': 'Lou', 'id': 'fitzglo01', 'lastname': 'Fitzgerald'},
#  'points': 0}
# {'_id': {'firstName': 'Maurice', 'id': 'bakerma01', 'lastname': 'Baker'},
#  'points': 0}
# {'_id': {'firstName': 'Charles', 'id': 'parksch01', 'lastname': 'Parks'},
#  'points': 0}
# {'_id': {'firstName': 'Bob', 'id': 'armstbo02', 'lastname': 'Armstrong'},
#  'points': 0}
# {'_id': {'firstName': 'Carl', 'id': 'bruchca01', 'lastname': 'Bruch'},
#  'points': 0}
# {'_id': {'firstName': 'William', 'id': 'krallbi01', 'lastname': 'Krall'},
#  'points': 0}
# {'_id': {'firstName': 'Ken', 'id': 'walteke01', 'lastname': 'Walters'},
#  'points': 0}
# {'_id': {'firstName': 'Cedric', 'id': 'huntece01', 'lastname': 'Hunter'},
#  'points': 0}
# {'_id': {'firstName': 'Alex', 'id': 'scaleal01', 'lastname': 'Scales'},
#  'points': 0}
# {'_id': {'firstName': '', 'id': 'mcnam01', 'lastname': 'McNamara'}, 'points': 0}
# {'_id': {'firstName': 'Donald', 'id': 'eliasdo01', 'lastname': 'Eliason'},
#  'points': 0}
# {'_id': {'firstName': 'Ron', 'id': 'sanforo01', 'lastname': 'Sanford'},
#  'points': 0}
# {'_id': {'firstName': 'Willie', 'id': 'youngwi01', 'lastname': 'Young'},
#  'points': 0}
# {'_id': {'firstName': 'Mike', 'id': 'champmi01', 'lastname': 'Champion'},
#  'points': 0}
# {'_id': {'firstName': 'Frank', 'id': 'vukosfr01', 'lastname': 'Vukosic'},
#  'points': 0}
# {'_id': {'firstName': 'Eddie', 'id': 'wolleed01', 'lastname': 'Wollen'},
#  'points': 0}
# {'_id': {'firstName': 'Bob', 'id': 'phillbo02', 'lastname': 'Phillips'},
#  'points': 0}
# {'_id': {'firstName': 'Jonathan', 'id': 'kernejo01', 'lastname': 'Kerner'},
#  'points': 0}
# {'_id': {'firstName': '', 'id': 'wille01', 'lastname': 'Willett'}, 'points': 0}
# {'_id': {'firstName': 'Carl', 'id': 'baerca01', 'lastname': 'Baer'},
#  'points': 0}
# {'_id': {'firstName': 'Joel', 'id': 'masonjo01', 'lastname': 'Mason'},
#  'points': 0}
# {'_id': {'firstName': 'Martynas',
#          'id': 'andrima01',
#          'lastname': 'Andriuskevicius'},
#  'points': 0}
# {'_id': {'firstName': 'John', 'id': 'lenhajo01', 'lastname': 'Lenhart'},
#  'points': 0}
# {'_id': {'firstName': 'Hugh', 'id': 'cartehu01', 'lastname': 'Carter'},
#  'points': 0}
